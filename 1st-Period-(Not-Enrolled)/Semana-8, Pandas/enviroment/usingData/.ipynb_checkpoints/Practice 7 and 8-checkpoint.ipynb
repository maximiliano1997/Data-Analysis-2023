# %% [markdown]
# ## (Part 7): Sorting Data

# %%
people = {
    "first": ["Corey", "Jane", "Jhon","Adam"],
    "last": ["Schafer", "Doe", "Doe", "Doe"],
    "email": ["CoreyMSchager@gmail.com", "loco@gamil.com", "lineal@gmail.com", "A@email.com"],
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 1   Jane      Doe           loco@gamil.com
# 2   Jhon      Doe         lineal@gmail.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by='last', ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 1   Jane      Doe           loco@gamil.com
# 2   Jhon      Doe         lineal@gmail.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by=['last','first'], ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 2   Jhon      Doe         lineal@gmail.com
# 1   Jane      Doe           loco@gamil.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by=['last','first'], ascending=[False, True], inplace=True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 3   Adam      Doe              A@email.com
# 1   Jane      Doe           loco@gamil.com
# 2   Jhon      Doe         lineal@gmail.com

# %%
df.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 1   Jane      Doe           loco@gamil.com
# 2   Jhon      Doe         lineal@gmail.com
# 3   Adam      Doe              A@email.com

# %%
df['last'].sort_values()
# Out:
# 3        Doe
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: object

# %% [markdown]
# ## Working With StakOverflow Data

# %%
dfs = pd.read_csv('../data/survey_results_public.csv')
schema_dfs = pd.read_csv('../data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows', 50)
pd.set_option('display.min_rows', 50)
dfs.head()
# Out:
#    ResponseId                                         MainBranch
# 0           1                                      None of these  \
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork
# 0                  NaN                                   NaN  \
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities
# 0                                       NaN  \
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel
# 0                                              NaN  \
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode
# 0                                                NaN  \
# 1                                                NaN
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert
# 0                                                NaN                  NaN  \
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
# 4  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode YearsCodePro                                            DevType
# 0       NaN          NaN                                                NaN  \
# 1       NaN          NaN                                                NaN
# 2        14            5  Data scientist or machine learning specialist;...
# 3        20           17                              Developer, full-stack
# 4         8            3  Developer, front-end;Developer, full-stack;Dev...
#
#                 OrgSize      PurchaseInfluence
# 0                   NaN                    NaN  \
# 1                   NaN                    NaN
# 2    20 to 99 employees  I have some influence
# 3  100 to 499 employees  I have some influence
# 4    20 to 99 employees  I have some influence
#
#                                           BuyNewTool
# 0                                                NaN  \
# 1                                                NaN
# 2                                                NaN
# 3                            Other (please specify):
# 4  Start a free trial;Visit developer communities...
#
#                                              Country
# 0                                                NaN  \
# 1                                             Canada
# 2  United Kingdom of Great Britain and Northern I...
# 3                                             Israel
# 4                           United States of America
#
#                     Currency  CompTotal CompFreq
# 0                        NaN        NaN      NaN  \
# 1       CAD\tCanadian dollar        NaN      NaN
# 2        GBP\tPound sterling    32000.0   Yearly
# 3    ILS\tIsraeli new shekel    60000.0  Monthly
# 4  USD\tUnited States dollar        NaN      NaN
#
#                         LanguageHaveWorkedWith
# 0                                          NaN  \
# 1                        JavaScript;TypeScript
# 2            C#;C++;HTML/CSS;JavaScript;Python
# 3                 C#;JavaScript;SQL;TypeScript
# 4  C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#
#                        LanguageWantToWorkWith
# 0                                         NaN  \
# 1                             Rust;TypeScript
# 2       C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                           C#;SQL;TypeScript
# 4  C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
#
#                               DatabaseHaveWorkedWith
# 0                                                NaN  \
# 1                                                NaN
# 2                               Microsoft SQL Server
# 3                               Microsoft SQL Server
# 4  Cloud Firestore;Elasticsearch;Microsoft SQL Se...
#
#                               DatabaseWantToWorkWith
# 0                                                NaN  \
# 1                                                NaN
# 2                               Microsoft SQL Server
# 3                               Microsoft SQL Server
# 4  Cloud Firestore;Elasticsearch;Firebase Realtim...
#
#      PlatformHaveWorkedWith    PlatformWantToWorkWith
# 0                       NaN                       NaN  \
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4  Firebase;Microsoft Azure  Firebase;Microsoft Azure
#
#                          WebframeHaveWorkedWith
# 0                                           NaN  \
# 1                                           NaN
# 2                                    Angular.js
# 3                         ASP.NET;ASP.NET Core
# 4  Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
#
#                  WebframeWantToWorkWith MiscTechHaveWorkedWith
# 0                                   NaN                    NaN  \
# 1                                   NaN                    NaN
# 2                    Angular;Angular.js                 Pandas
# 3                 ASP.NET;ASP.NET Core                    .NET
# 4  Angular;ASP.NET Core ;Blazor;Node.js                   .NET
#
#   MiscTechWantToWorkWith ToolsTechHaveWorkedWith ToolsTechWantToWorkWith
# 0                    NaN                     NaN                     NaN  \
# 1                    NaN                     NaN                     NaN
# 2                   .NET                     NaN                     NaN
# 3                   .NET                     NaN                     NaN
# 4      .NET;Apache Kafka                     npm       Docker;Kubernetes
#
#                        NEWCollabToolsHaveWorkedWith
# 0                                               NaN  \
# 1                                               NaN
# 2                           Notepad++;Visual Studio
# 3        Notepad++;Visual Studio;Visual Studio Code
# 4  Notepad++;Visual Studio;Visual Studio Code;Xcode
#
#                  NEWCollabToolsWantToWorkWith OpSysProfessional use
# 0                                         NaN                   NaN  \
# 1                                         NaN                 macOS
# 2                     Notepad++;Visual Studio               Windows
# 3  Notepad++;Visual Studio;Visual Studio Code               Windows
# 4      Rider;Visual Studio;Visual Studio Code               Windows
#
#                    OpSysPersonal use         VersionControlSystem
# 0                                NaN                          NaN  \
# 1  Windows Subsystem for Linux (WSL)                          Git
# 2                            Windows                          Git
# 3                            Windows                          Git
# 4                      macOS;Windows  Git;Other (please specify):
#
#                                        VCInteraction  VCHostingPersonal use
# 0                                                NaN                    NaN  \
# 1                                                NaN                    NaN
# 2                                        Code editor                    NaN
# 3  Code editor;Command-line;Version control hosti...                    NaN
# 4                                        Code editor                    NaN
#
#    VCHostingProfessional use OfficeStackAsyncHaveWorkedWith
# 0                        NaN                            NaN  \
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN    Jira Work Management;Trello
# 4                        NaN                            NaN
#
#   OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith
# 0                            NaN                           NaN  \
# 1                            NaN                           NaN
# 2                            NaN               Microsoft Teams
# 3    Jira Work Management;Trello                    Slack;Zoom
# 4                            NaN          Microsoft Teams;Zoom
#
#   OfficeStackSyncWantToWorkWith        Blockchain
# 0                           NaN               NaN  \
# 1                           NaN  Very unfavorable
# 2               Microsoft Teams  Very unfavorable
# 3                    Slack;Zoom  Very unfavorable
# 4                           NaN       Unfavorable
#
#                                           NEWSOSites             SOVisitFreq
# 0                                                NaN                     NaN  \
# 1  Collectives on Stack Overflow;Stack Overflow f...   Daily or almost daily
# 2  Collectives on Stack Overflow;Stack Overflow;S...  Multiple times per day
# 3  Collectives on Stack Overflow;Stack Overflow f...   Daily or almost daily
# 4  Collectives on Stack Overflow;Stack Overflow f...  Multiple times per day
#
#   SOAccount              SOPartFreq           SOComm              Age Gender
# 0       NaN                     NaN              NaN              NaN    NaN  \
# 1       Yes   Daily or almost daily         Not sure              NaN    NaN
# 2       Yes  Multiple times per day          Neutral  25-34 years old    Man
# 3       Yes    A few times per week  Yes, definitely  35-44 years old    Man
# 4       Yes   Daily or almost daily  Yes, definitely  25-34 years old    NaN
#
#   Trans                Sexuality Ethnicity      Accessibility
# 0   NaN                      NaN       NaN                NaN  \
# 1   NaN                      NaN       NaN                NaN
# 2    No                 Bisexual     White  None of the above
# 3    No  Straight / Heterosexual     White  None of the above
# 4   NaN                      NaN       NaN                NaN
#
#                                         MentalHealth TBranch ICorPM  WorkExp
# 0                                                NaN     NaN    NaN      NaN  \
# 1                                                NaN      No    NaN      NaN
# 2  I have a mood or emotional disorder (e.g., dep...      No    NaN      NaN
# 3                                  None of the above      No    NaN      NaN
# 4                                                NaN      No    NaN      NaN
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5 Knowledge_6
# 0         NaN         NaN         NaN         NaN         NaN         NaN  \
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Knowledge_7 Frequency_1 Frequency_2 Frequency_3 TimeSearching TimeAnswering
# 0         NaN         NaN         NaN         NaN           NaN           NaN  \
# 1         NaN         NaN         NaN         NaN           NaN           NaN
# 2         NaN         NaN         NaN         NaN           NaN           NaN
# 3         NaN         NaN         NaN         NaN           NaN           NaN
# 4         NaN         NaN         NaN         NaN           NaN           NaN
#
#   Onboarding ProfessionalTech TrueFalse_1 TrueFalse_2 TrueFalse_3
# 0        NaN              NaN         NaN         NaN         NaN  \
# 1        NaN              NaN         NaN         NaN         NaN
# 2        NaN              NaN         NaN         NaN         NaN
# 3        NaN              NaN         NaN         NaN         NaN
# 4        NaN              NaN         NaN         NaN         NaN
#
#             SurveyLength                  SurveyEase  ConvertedCompYearly
# 0                    NaN                         NaN                  NaN
# 1               Too long                   Difficult                  NaN
# 2  Appropriate in length  Neither easy nor difficult              40205.0
# 3  Appropriate in length                        Easy             215232.0
# 4               Too long                        Easy                  NaN

# %%
dfs.sort_values(by=['Country', 'Currency', 'CompTotal'], ascending=[True, False, False], inplace=True)

# %%
dfs[['Country', 'Currency', 'CompTotal']].head(150)
# Out:
#            Country                         Currency   CompTotal
# 55665  Afghanistan        USD\tUnited States dollar       200.0
# 3641   Afghanistan        USD\tUnited States dollar         NaN
# 61617  Afghanistan        USD\tUnited States dollar         NaN
# 6891   Afghanistan                IRR\tIranian rial  55000000.0
# 58077  Afghanistan          BOB\tBolivian boliviano         NaN
# 42122  Afghanistan               BGN\tBulgarian lev         NaN
# 28582  Afghanistan                ALL\tAlbanian lek         NaN
# 38512  Afghanistan              AFN\tAfghan afghani   1200000.0
# 43639  Afghanistan              AFN\tAfghan afghani    700000.0
# 43690  Afghanistan              AFN\tAfghan afghani    100000.0
# 6242   Afghanistan              AFN\tAfghan afghani     40000.0
# 23223  Afghanistan              AFN\tAfghan afghani     40000.0
# 2737   Afghanistan              AFN\tAfghan afghani         0.0
# 4502   Afghanistan              AFN\tAfghan afghani         NaN
# 15607  Afghanistan              AFN\tAfghan afghani         NaN
# 17038  Afghanistan              AFN\tAfghan afghani         NaN
# 24812  Afghanistan              AFN\tAfghan afghani         NaN
# 53960  Afghanistan              AFN\tAfghan afghani         NaN
# 55393  Afghanistan              AFN\tAfghan afghani         NaN
# 56355  Afghanistan              AFN\tAfghan afghani         NaN
# 60146  Afghanistan              AFN\tAfghan afghani         NaN
# 2448   Afghanistan  AED United Arab Emirates dirham     40000.0
# 49273  Afghanistan  AED United Arab Emirates dirham      6000.0
# 3886   Afghanistan  AED United Arab Emirates dirham         1.0
# 5464   Afghanistan  AED United Arab Emirates dirham         1.0
# ...            ...                              ...         ...
# 68849      Albania                              NaN         NaN
# 68972      Albania                              NaN         NaN
# 72922      Albania                              NaN         NaN
# 23705      Algeria        USD\tUnited States dollar         NaN
# 68883      Algeria                EUR European Euro     18000.0
# 44969      Algeria                EUR European Euro      2500.0
# 23354      Algeria                EUR European Euro         NaN
# 6713       Algeria              DZD\tAlgerian dinar    330000.0
# 30328      Algeria              DZD\tAlgerian dinar     95000.0
# 6266       Algeria              DZD\tAlgerian dinar     90000.0
# 19840      Algeria              DZD\tAlgerian dinar     80000.0
# 50861      Algeria              DZD\tAlgerian dinar     75000.0
# 11326      Algeria              DZD\tAlgerian dinar     55000.0
# 54772      Algeria              DZD\tAlgerian dinar     42400.0
# 19902      Algeria              DZD\tAlgerian dinar         NaN
# 64553      Algeria              DZD\tAlgerian dinar         NaN
# 41372      Algeria               AMD\tArmenian dram         NaN
# 1453       Algeria                              NaN         NaN
# 11294      Algeria                              NaN         NaN
# 20704      Algeria                              NaN         NaN
# 21827      Algeria                              NaN         NaN
# 23857      Algeria                              NaN         NaN
# 24367      Algeria                              NaN         NaN
# 25537      Algeria                              NaN         NaN
# 25582      Algeria                              NaN         NaN
#
# [150 rows x 3 columns]

# %%
dfs['CompTotal'].nlargest(10)
# Out:
# 35786    9.000000e+56
# 3068     1.000000e+52
# 70597    1.000000e+22
# 17567    1.000000e+15
# 19244    5.000000e+12
# 24640    1.500070e+12
# 31190    1.000000e+12
# 71603    9.363220e+09
# 34411    7.200000e+09
# 49874    6.438169e+09
# Name: CompTotal, dtype: float64

# %%
dfs.nlargest(10, 'CompTotal')
# Out:
#        ResponseId                                         MainBranch
# 35786       35787                     I am a developer by profession  \
# 3068         3069                     I am a developer by profession
# 70597       70598                     I am a developer by profession
# 17567       17568                     I am a developer by profession
# 19244       19245  I am not primarily a developer, but I write co...
# 24640       24641                     I am a developer by profession
# 31190       31191                     I am a developer by profession
# 71603       71604                     I am a developer by profession
# 34411       34412                     I am a developer by profession
# 49874       49875                     I am a developer by profession
#
#                                               Employment
# 35786            Employed, full-time;Employed, part-time  \
# 3068                                 Employed, full-time
# 70597  Independent contractor, freelancer, or self-em...
# 17567                                Employed, full-time
# 19244  Independent contractor, freelancer, or self-em...
# 24640                                Employed, full-time
# 31190                                Employed, full-time
# 71603                                Employed, part-time
# 34411                                Employed, full-time
# 49874                                Employed, full-time
#
#                                  RemoteWork
# 35786  Hybrid (some remote, some in-person)  \
# 3068   Hybrid (some remote, some in-person)
# 70597                          Fully remote
# 17567  Hybrid (some remote, some in-person)
# 19244                          Fully remote
# 24640                        Full in-person
# 31190  Hybrid (some remote, some in-person)
# 71603                          Fully remote
# 34411  Hybrid (some remote, some in-person)
# 49874                          Fully remote
#
#                                         CodingActivities
# 35786                       I don’t code outside of work  \
# 3068   Hobby;Contribute to open-source projects;Boots...
# 70597           Hobby;Contribute to open-source projects
# 17567  Hobby;Contribute to open-source projects;Freel...
# 19244  Hobby;Contribute to open-source projects;Freel...
# 24640  Hobby;Contribute to open-source projects;Boots...
# 31190                       I don’t code outside of work
# 71603                                              Hobby
# 34411   Bootstrapping a business;Freelance/contract work
# 49874                 Contribute to open-source projects
#
#                                                  EdLevel
# 35786  Secondary school (e.g. American high school, G...  \
# 3068        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 70597       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17567  Secondary school (e.g. American high school, G...
# 19244    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 24640  Secondary school (e.g. American high school, G...
# 31190         Other doctoral degree (Ph.D., Ed.D., etc.)
# 71603                                     Something else
# 34411    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49874                          Primary/elementary school
#
#                                                LearnCode
# 35786                                          Colleague  \
# 3068   School (i.e., University, College, etc);Other ...
# 70597  Books / Physical media;Other online resources ...
# 17567  Other online resources (e.g., videos, blogs, f...
# 19244  Books / Physical media;Friend or family member...
# 24640                             Books / Physical media
# 31190  Books / Physical media;Friend or family member...
# 71603                            Other (please specify):
# 34411  Books / Physical media;Other online resources ...
# 49874  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline
# 35786                                                NaN  \
# 3068                                                 NaN
# 70597  Technical documentation;Blogs;Written Tutorial...
# 17567  Technical documentation;Stack Overflow;Online ...
# 19244  Technical documentation;Programming Games;Writ...
# 24640                                                NaN
# 31190  Technical documentation;Blogs;Programming Game...
# 71603                                                NaN
# 34411  Technical documentation;Blogs;Stack Overflow;V...
# 49874  Technical documentation;Blogs;Programming Game...
#
#                                     LearnCodeCoursesCert YearsCode
# 35786                                                NaN         4  \
# 3068                                                 NaN        10
# 70597                                                NaN        20
# 17567                                                NaN        10
# 19244                                                NaN        15
# 24640                                                NaN         2
# 31190  Coursera;Udemy;Codecademy;Pluralsight;edX;Udac...        10
# 71603                                                NaN         4
# 34411                          Udemy;Pluralsight;Udacity        16
# 49874  Coursera;Udemy;Codecademy;Pluralsight;edX;Udac...        19
#
#            YearsCodePro                                            DevType
# 35786                16          Developer, full-stack;Academic researcher  \
# 3068                  2                      Developer, back-end;Scientist
# 70597                19  Developer, front-end;Developer, full-stack;Dev...
# 17567                 6  Developer, front-end;Developer, full-stack;Dev...
# 19244                10  Developer, front-end;Engineer, data;Developer,...
# 24640               NaN                                    Project manager
# 31190  Less than 1 year  Data scientist or machine learning specialist;...
# 71603               NaN                                          Scientist
# 34411                12  Developer, full-stack;Developer, desktop or en...
# 49874                10  Data scientist or machine learning specialist;...
#
#                                                  OrgSize
# 35786  Just me - I am a freelancer, sole proprietor, ...  \
# 3068                            10,000 or more employees
# 70597  Just me - I am a freelancer, sole proprietor, ...
# 17567                                 10 to 19 employees
# 19244                                 10 to 19 employees
# 24640  Just me - I am a freelancer, sole proprietor, ...
# 31190                                       I don’t know
# 71603  Just me - I am a freelancer, sole proprietor, ...
# 34411                                 20 to 99 employees
# 49874                           1,000 to 4,999 employees
#
#                       PurchaseInfluence
# 35786  I have a great deal of influence  \
# 3068              I have some influence
# 70597  I have a great deal of influence
# 17567             I have some influence
# 19244     I have little or no influence
# 24640  I have a great deal of influence
# 31190  I have a great deal of influence
# 71603     I have little or no influence
# 34411             I have some influence
# 49874     I have little or no influence
#
#                                               BuyNewTool
# 35786    Visit developer communities like Stack Overflow  \
# 3068                                                 NaN
# 70597                            Other (please specify):
# 17567  Visit developer communities like Stack Overflo...
# 19244  Other (please specify):;Visit developer commun...
# 24640  Read ratings or reviews on third party sites l...
# 31190  Other (please specify):;Start a free trial;Vis...
# 71603                                 Start a free trial
# 34411  Start a free trial;Visit developer communities...
# 49874  Other (please specify):;Start a free trial;Vis...
#
#                             Country                   Currency     CompTotal
# 35786                       Ecuador        DOP\tDominican peso  9.000000e+56  \
# 3068       United States of America  USD\tUnited States dollar  1.000000e+52
# 70597      United States of America         ZMW Zambian kwacha  1.000000e+22
# 17567                         Italy          EUR European Euro  1.000000e+15
# 19244                    Kyrgyzstan       KGS\tKyrgyzstani som  5.000000e+12
# 24640                       Nigeria        NGN\tNigerian naira  1.500070e+12
# 31190      United States of America  USD\tUnited States dollar  1.000000e+12
# 71603  Iran, Islamic Republic of...  USD\tUnited States dollar  9.363220e+09
# 34411  Iran, Islamic Republic of...          IRR\tIranian rial  7.200000e+09
# 49874                        Angola          INR\tIndian rupee  6.438169e+09
#
#       CompFreq                             LanguageHaveWorkedWith
# 35786   Weekly                                    APL;COBOL;Scala  \
# 3068    Weekly                    C;C++;Fortran;Java;Python;Scala
# 70597   Yearly        Bash/Shell;HTML/CSS;JavaScript;Perl;PHP;SQL
# 17567  Monthly                        HTML/CSS;JavaScript;PHP;SQL
# 19244   Yearly  Bash/Shell;C++;Go;HTML/CSS;JavaScript;MATLAB;P...
# 24640   Weekly          HTML/CSS;JavaScript;PowerShell;TypeScript
# 31190  Monthly  APL;Assembly;Bash/Shell;C;C#;C++;Clojure;COBOL...
# 71603  Monthly                                                APL
# 34411  Monthly                 C;C#;JavaScript;PHP;SQL;TypeScript
# 49874  Monthly  APL;Assembly;Bash/Shell;C#;C++;Clojure;COBOL;C...
#
#                                   LanguageWantToWorkWith
# 35786                                C++;Dart;MATLAB;VBA  \
# 3068                                   Python;Rust;Scala
# 70597                                                NaN
# 17567  C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;R;SQ...
# 19244  Bash/Shell;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 24640                                                NaN
# 31190  APL;Assembly;Bash/Shell;C;C#;C++;Clojure;COBOL...
# 71603                                                NaN
# 34411            C#;Dart;F#;Go;JavaScript;SQL;TypeScript
# 49874  APL;Assembly;Bash/Shell;C#;C++;Clojure;COBOL;C...
#
#                                   DatabaseHaveWorkedWith
# 35786                                            IBM DB2  \
# 3068                   Cassandra;PostgreSQL;Redis;SQLite
# 70597                                      MariaDB;MySQL
# 17567                       MariaDB;MongoDB;MySQL;SQLite
# 19244  Elasticsearch;MariaDB;MongoDB;MySQL;Oracle;Pos...
# 24640  Cloud Firestore;Microsoft SQL Server;Firebase ...
# 31190  Cassandra;Couchbase;CouchDB;Cloud Firestore;Dy...
# 71603                                          Cassandra
# 34411                  Microsoft SQL Server;MySQL;Oracle
# 49874  Cassandra;Couchbase;Cloud Firestore;DynamoDB;E...
#
#                                   DatabaseWantToWorkWith
# 35786                                        Neo4j;Redis  \
# 3068                   Cassandra;PostgreSQL;Redis;SQLite
# 70597                                                NaN
# 17567                       MariaDB;MongoDB;MySQL;SQLite
# 19244                        Elasticsearch;MariaDB;MySQL
# 24640                                                NaN
# 31190  Cassandra;Couchbase;CouchDB;Cloud Firestore;Dy...
# 71603                                                NaN
# 34411  Cassandra;Elasticsearch;Microsoft SQL Server;P...
# 49874  Cassandra;Couchbase;Cloud Firestore;DynamoDB;E...
#
#                                   PlatformHaveWorkedWith
# 35786                                       DigitalOcean  \
# 3068                                                 AWS
# 70597                                                NaN
# 17567                   AWS;DigitalOcean;Managed Hosting
# 19244  DigitalOcean;Firebase;Google Cloud;Oracle Clou...
# 24640  DigitalOcean;Google Cloud;Microsoft Azure;Open...
# 31190  AWS;Colocation;DigitalOcean;Firebase;Google Cl...
# 71603                                                NaN
# 34411                                                NaN
# 49874  AWS;Colocation;Microsoft Azure;Oracle Cloud In...
#
#                                   PlatformWantToWorkWith
# 35786                                             Heroku  \
# 3068                                                 NaN
# 70597                                                NaN
# 17567  AWS;DigitalOcean;Google Cloud;Managed Hosting;...
# 19244                              DigitalOcean;Firebase
# 24640  DigitalOcean;Google Cloud;Microsoft Azure;Open...
# 31190  AWS;Colocation;DigitalOcean;Firebase;Google Cl...
# 71603                                                NaN
# 34411                                                NaN
# 49874  AWS;Colocation;Microsoft Azure;Oracle Cloud In...
#
#                                   WebframeHaveWorkedWith
# 35786                                            Angular  \
# 3068                                               Flask
# 70597                                             jQuery
# 17567           Angular.js;jQuery;Laravel;Node.js;Vue.js
# 19244  Angular;Django;Drupal;Gatsby;jQuery;Laravel;No...
# 24640                                    ASP.NET;Express
# 31190  Angular;Angular.js;ASP.NET;ASP.NET Core ;Blazo...
# 71603                                                NaN
# 34411  Angular;Angular.js;ASP.NET;ASP.NET Core ;jQuer...
# 49874  Angular;ASP.NET;ASP.NET Core ;Ruby on Rails;Sv...
#
#                                   WebframeWantToWorkWith
# 35786                                      Blazor;Svelte  \
# 3068                                               Flask
# 70597                                                NaN
# 17567  Angular;Angular.js;jQuery;Laravel;Node.js;Reac...
# 19244                                     Angular;Vue.js
# 24640                                                NaN
# 31190  Angular;Angular.js;ASP.NET;ASP.NET Core ;Blazo...
# 71603                                                NaN
# 34411               Angular;ASP.NET Core ;Node.js;Vue.js
# 49874  Angular;ASP.NET Core ;Ruby on Rails;Svelte;Sym...
#
#                                   MiscTechHaveWorkedWith
# 35786                                       Scikit-learn  \
# 3068                           Apache Kafka;Apache Spark
# 70597                                                NaN
# 17567                                                NaN
# 19244  Apache Kafka;Apache Spark;React Native;Torch/P...
# 24640                                       .NET;Flutter
# 31190  .NET;Apache Kafka;Apache Spark;Capacitor;Cordo...
# 71603                                                NaN
# 34411            .NET;Cordova;Ionic;React Native;Xamarin
# 49874  .NET;Capacitor;Electron;Flutter;GTK;Hadoop;Ion...
#
#                                   MiscTechWantToWorkWith
# 35786                                          Tidyverse  \
# 3068                           Apache Kafka;Apache Spark
# 70597                                                NaN
# 17567                                                NaN
# 19244                                                NaN
# 24640                                                NaN
# 31190  .NET;Apache Kafka;Apache Spark;Capacitor;Cordo...
# 71603                                                NaN
# 34411                       .NET;Capacitor;Flutter;Ionic
# 49874  .NET;Capacitor;Electron;Flutter;GTK;Hadoop;Ion...
#
#                                  ToolsTechHaveWorkedWith
# 35786                                             Puppet  \
# 3068                                   Docker;Kubernetes
# 70597                                                NaN
# 17567                                Docker;Homebrew;npm
# 19244                                             Docker
# 24640                                     Flow;Terraform
# 31190  Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;n...
# 71603                                                NaN
# 34411                                           npm;Yarn
# 49874                         Ansible;Unreal Engine;Yarn
#
#                                  ToolsTechWantToWorkWith
# 35786                                               Yarn  \
# 3068                                   Docker;Kubernetes
# 70597                                                NaN
# 17567                                Docker;Homebrew;npm
# 19244  Ansible;Docker;Flow;Kubernetes;npm;Puppet;Unit...
# 24640                                                NaN
# 31190  Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;n...
# 71603                                                NaN
# 34411                         Docker;Kubernetes;npm;Yarn
# 49874                         Ansible;Unreal Engine;Yarn
#
#                             NEWCollabToolsHaveWorkedWith
# 35786                                     Android Studio  \
# 3068                                IntelliJ;PyCharm;Vim
# 70597                                               Nano
# 17567                                  Nano;PhpStorm;Vim
# 19244  Android Studio;Atom;IntelliJ;NetBeans;Neovim;N...
# 24640              Eclipse;NetBeans;Notepad++;Qt Creator
# 31190  Atom;CLion;Eclipse;Emacs;GoLand;IntelliJ;IPyth...
# 71603                                                NaN
# 34411                   Visual Studio;Visual Studio Code
# 49874                           Android Studio;Vim;Xcode
#
#                             NEWCollabToolsWantToWorkWith
# 35786                                     Android Studio  \
# 3068                                IntelliJ;PyCharm;Vim
# 70597                                                NaN
# 17567                                  Nano;PhpStorm;Vim
# 19244                    Atom;Notepad++;PhpStorm;PyCharm
# 24640                                                NaN
# 31190  Atom;CLion;Eclipse;Emacs;GoLand;IntelliJ;IPyth...
# 71603                                                NaN
# 34411                   Visual Studio;Visual Studio Code
# 49874                           Android Studio;Vim;Xcode
#
#                                    OpSysProfessional use
# 35786                                            Windows  \
# 3068                                         Linux-based
# 70597                                    BSD;Linux-based
# 17567                                              macOS
# 19244                                        Linux-based
# 24640                                                NaN
# 31190  BSD;Linux-based;macOS;Windows;Windows Subsyste...
# 71603                            Other (please specify):
# 34411                                            Windows
# 49874              BSD;Windows Subsystem for Linux (WSL)
#
#                                        OpSysPersonal use
# 35786                                                BSD  \
# 3068                                 Linux-based;Windows
# 70597                                        Linux-based
# 17567                                Linux-based;Windows
# 19244  BSD;Linux-based;Windows;Windows Subsystem for ...
# 24640                                            Windows
# 31190  BSD;Linux-based;macOS;Windows;Windows Subsyste...
# 71603                                                NaN
# 34411                                            Windows
# 49874              BSD;Windows Subsystem for Linux (WSL)
#
#                     VersionControlSystem
# 35786  Other (please specify):;Mercurial  \
# 3068                                 Git
# 70597                            Git;SVN
# 17567                                Git
# 19244                                Git
# 24640                    I don't use one
# 31190                    I don't use one
# 71603                                NaN
# 34411                                Git
# 49874                  Git;Mercurial;SVN
#
#                                            VCInteraction
# 35786                                       Command-line  \
# 3068   Command-line;Version control hosting service w...
# 70597                                       Command-line
# 17567                           Code editor;Command-line
# 19244  Code editor;Command-line;Version control hosti...
# 24640                                                NaN
# 31190                                                NaN
# 71603                                       Command-line
# 34411                           Code editor;Command-line
# 49874  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use
# 35786                    NaN                        NaN  \
# 3068                     NaN                        NaN
# 70597                    NaN                        NaN
# 17567                    NaN                        NaN
# 19244                    NaN                        NaN
# 24640                    NaN                        NaN
# 31190                    NaN                        NaN
# 71603                    NaN                        NaN
# 34411                    NaN                        NaN
# 49874                    NaN                        NaN
#
#                           OfficeStackAsyncHaveWorkedWith
# 35786                                           Airtable  \
# 3068                                          Confluence
# 70597                                                NaN
# 17567                                             Trello
# 19244                           Microsoft Planner;Trello
# 24640  Adobe Workfront;Microsoft Planner;Microsoft Lists
# 31190  Adobe Workfront;Airtable;Asana;Cerri;ClickUp;C...
# 71603                                                NaN
# 34411                               Jira Work Management
# 49874  Airtable;Asana;Cerri;ClickUp;Confluence;DingTa...
#
#                           OfficeStackAsyncWantToWorkWith
# 35786                  Planview Projectplace or Clarizen  \
# 3068                                          Confluence
# 70597                                                NaN
# 17567                                                NaN
# 19244                                                NaN
# 24640                           Stack Overflow for Teams
# 31190  Adobe Workfront;Airtable;Asana;Cerri;ClickUp;C...
# 71603                                                NaN
# 34411                               Jira Work Management
# 49874  Airtable;Asana;Cerri;ClickUp;Confluence;DingTa...
#
#                            OfficeStackSyncHaveWorkedWith
# 35786                                        Google Chat  \
# 3068                          Microsoft Teams;Rocketchat
# 70597                                                NaN
# 17567             Google Chat;Microsoft Teams;Slack;Zoom
# 19244         Google Chat;Rocketchat;Slack;Symphony;Zoom
# 24640                                                NaN
# 31190  Cisco Webex Teams;Coolfire Core;Google Chat;Ma...
# 71603                                    Microsoft Teams
# 34411                                    Microsoft Teams
# 49874                             Cisco Webex Teams;Zoom
#
#                            OfficeStackSyncWantToWorkWith      Blockchain
# 35786                                        RingCentral     Indifferent  \
# 3068                                          Rocketchat          Unsure
# 70597                                                NaN     Unfavorable
# 17567             Google Chat;Microsoft Teams;Slack;Zoom     Indifferent
# 19244                                                NaN       Favorable
# 24640                                                NaN     Unfavorable
# 31190  Cisco Webex Teams;Coolfire Core;Google Chat;Ma...  Very favorable
# 71603                  Google Chat;Microsoft Teams;Wickr          Unsure
# 34411                               Microsoft Teams;Zoom       Favorable
# 49874                             Cisco Webex Teams;Zoom     Indifferent
#
#                                               NEWSOSites
# 35786  Stack Overflow for Teams (private knowledge sh...  \
# 3068                       Stack Overflow;Stack Exchange
# 70597                      Stack Overflow;Stack Exchange
# 17567  Collectives on Stack Overflow;Stack Overflow;S...
# 19244                      Stack Overflow;Stack Exchange
# 24640  Stack Overflow for Teams (private knowledge sh...
# 31190  Collectives on Stack Overflow;Stack Overflow f...
# 71603                                     Stack Exchange
# 34411                      Stack Overflow;Stack Exchange
# 49874  I have never visited Stack Overflow or the Sta...
#
#                                SOVisitFreq SOAccount
# 35786                 A few times per week        No  \
# 3068                 Daily or almost daily       Yes
# 70597                 A few times per week       Yes
# 17567               Multiple times per day       Yes
# 19244                Daily or almost daily       Yes
# 24640                 A few times per week        No
# 31190                Daily or almost daily       Yes
# 71603  Less than once per month or monthly        No
# 34411               Multiple times per day       Yes
# 49874                                  NaN       Yes
#
#                                 SOPartFreq           SOComm
# 35786                                  NaN   No, not really  \
# 3068   Less than once per month or monthly   No, not at all
# 70597  Less than once per month or monthly   No, not really
# 17567                 A few times per week    Yes, somewhat
# 19244                Daily or almost daily  Yes, definitely
# 24640                                  NaN          Neutral
# 31190                Daily or almost daily              NaN
# 71603                                  NaN          Neutral
# 34411  Less than once per month or monthly  Yes, definitely
# 49874      A few times per month or weekly    Yes, somewhat
#
#                      Age                                             Gender
# 35786  65 years or older  Man;Woman;Non-binary, genderqueer, or gender n...  \
# 3068     18-24 years old                                                Man
# 70597                NaN                                                NaN
# 17567    25-34 years old                                                Man
# 19244    35-44 years old                         Man;Or, in your own words:
# 24640    18-24 years old                                                Man
# 31190    25-34 years old                             Or, in your own words:
# 71603    35-44 years old                                  Prefer not to say
# 34411    35-44 years old                                                Man
# 49874    45-54 years old  Man;Woman;Non-binary, genderqueer, or gender n...
#
#                         Trans
# 35786                      No  \
# 3068   Or, in your own words:
# 70597                     NaN
# 17567                      No
# 19244  Or, in your own words:
# 24640                      No
# 31190                      No
# 71603                      No
# 34411                      No
# 49874                     Yes
#
#                                                Sexuality
# 35786                            Straight / Heterosexual  \
# 3068                            Prefer to self-describe:
# 70597                                                NaN
# 17567                            Straight / Heterosexual
# 19244   Straight / Heterosexual;Prefer to self-describe:
# 24640                      Straight / Heterosexual;Queer
# 31190                            Straight / Heterosexual
# 71603                                                NaN
# 34411                            Straight / Heterosexual
# 49874  Bisexual;Straight / Heterosexual;Gay or Lesbia...
#
#                                                Ethnicity
# 35786  White;Indian;European;North American;Middle Ea...  \
# 3068                              Or, in your own words:
# 70597                                                NaN
# 17567                                           European
# 19244              White;Asian;Multiracial;Central Asian
# 24640                             African;South American
# 31190  White;Indian;European;North American;Middle Ea...
# 71603                                              Asian
# 34411                                     Middle Eastern
# 49874  White;Indian;European;North American;Middle Ea...
#
#                                            Accessibility
# 35786  I am deaf / hard of hearing;I am blind / have ...  \
# 3068                              Or, in your own words:
# 70597                                                NaN
# 17567                                  None of the above
# 19244  Or, in your own words:;I am deaf / hard of hea...
# 24640                                  None of the above
# 31190                                  Prefer not to say
# 71603                                  None of the above
# 34411                                  None of the above
# 49874  I am deaf / hard of hearing;I am blind / have ...
#
#                                             MentalHealth TBranch
# 35786  I have a mood or emotional disorder (e.g., dep...     Yes  \
# 3068                              Or, in your own words:      No
# 70597                                                NaN     NaN
# 17567                                  None of the above     Yes
# 19244                             Or, in your own words:      No
# 24640                                  None of the above     Yes
# 31190  I have a concentration and/or memory disorder ...     Yes
# 71603                                                NaN     NaN
# 34411                                  None of the above     Yes
# 49874  I have a mood or emotional disorder (e.g., dep...     Yes
#
#                         ICorPM  WorkExp        Knowledge_1
# 35786           People manager     50.0           Disagree  \
# 3068                       NaN      NaN                NaN
# 70597                      NaN      NaN                NaN
# 17567  Independent contributor      8.0     Strongly agree
# 19244                      NaN      NaN                NaN
# 24640  Independent contributor      9.0           Disagree
# 31190           People manager     15.0     Strongly agree
# 71603                      NaN      NaN                NaN
# 34411           People manager     16.0              Agree
# 49874  Independent contributor     45.0  Strongly disagree
#
#                       Knowledge_2        Knowledge_3     Knowledge_4
# 35786  Neither agree nor disagree              Agree  Strongly agree  \
# 3068                          NaN                NaN             NaN
# 70597                         NaN                NaN             NaN
# 17567  Neither agree nor disagree     Strongly agree  Strongly agree
# 19244                         NaN                NaN             NaN
# 24640                       Agree              Agree           Agree
# 31190           Strongly disagree     Strongly agree  Strongly agree
# 71603                         NaN                NaN             NaN
# 34411  Neither agree nor disagree              Agree           Agree
# 49874           Strongly disagree  Strongly disagree        Disagree
#
#           Knowledge_5                 Knowledge_6                 Knowledge_7
# 35786           Agree  Neither agree nor disagree                    Disagree  \
# 3068              NaN                         NaN                         NaN
# 70597             NaN                         NaN                         NaN
# 17567  Strongly agree  Neither agree nor disagree                       Agree
# 19244             NaN                         NaN                         NaN
# 24640           Agree                       Agree                       Agree
# 31190  Strongly agree              Strongly agree              Strongly agree
# 71603             NaN                         NaN                         NaN
# 34411             NaN                       Agree  Neither agree nor disagree
# 49874           Agree  Neither agree nor disagree                       Agree
#
#             Frequency_1       Frequency_2        Frequency_3
# 35786  10+ times a week  10+ times a week   10+ times a week  \
# 3068                NaN               NaN                NaN
# 70597               NaN               NaN                NaN
# 17567             Never             Never              Never
# 19244               NaN               NaN                NaN
# 24640  1-2 times a week               NaN                NaN
# 31190             Never  1-2 times a week   1-2 times a week
# 71603               NaN               NaN                NaN
# 34411  1-2 times a week  1-2 times a week              Never
# 49874             Never  1-2 times a week  6-10 times a week
#
#                 TimeSearching               TimeAnswering      Onboarding
# 35786  Over 120 minutes a day      Over 120 minutes a day      Just right  \
# 3068                      NaN                         NaN             NaN
# 70597                     NaN                         NaN             NaN
# 17567     15-30 minutes a day  Less than 15 minutes a day  Somewhat short
# 19244                     NaN                         NaN             NaN
# 24640  Over 120 minutes a day  Less than 15 minutes a day  Somewhat short
# 31190    60-120 minutes a day        60-120 minutes a day      Very short
# 71603                     NaN                         NaN             NaN
# 34411     30-60 minutes a day         15-30 minutes a day   Somewhat long
# 49874     30-60 minutes a day         30-60 minutes a day  Somewhat short
#
#                                         ProfessionalTech TrueFalse_1
# 35786                  DevOps function;Automated testing         Yes  \
# 3068                                                 NaN         NaN
# 70597                                                NaN         NaN
# 17567  DevOps function;Microservices;Continuous integ...         Yes
# 19244                                                NaN         NaN
# 24640                                    DevOps function         Yes
# 31190  Innersource initiative;DevOps function;Microse...         Yes
# 71603                                                NaN         NaN
# 34411  DevOps function;Microservices;Continuous integ...         Yes
# 49874  Innersource initiative;DevOps function;Microse...         Yes
#
#       TrueFalse_2 TrueFalse_3           SurveyLength
# 35786          No         Yes               Too long  \
# 3068          NaN         NaN  Appropriate in length
# 70597         NaN         NaN                    NaN
# 17567         Yes         Yes               Too long
# 19244         NaN         NaN  Appropriate in length
# 24640         Yes         Yes  Appropriate in length
# 31190         Yes         Yes  Appropriate in length
# 71603         NaN         NaN               Too long
# 34411         Yes         Yes  Appropriate in length
# 49874         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 35786                   Difficult                  NaN
# 3068                    Difficult                  NaN
# 70597                         NaN                  NaN
# 17567  Neither easy nor difficult                  NaN
# 19244  Neither easy nor difficult                  NaN
# 24640  Neither easy nor difficult                  NaN
# 31190  Neither easy nor difficult                  NaN
# 71603  Neither easy nor difficult                  NaN
# 34411                        Easy            2042400.0
# 49874                   Difficult                  NaN

# %%
dfs.nsmallest(10, 'CompTotal')
# Out:
#        ResponseId                                         MainBranch
# 2737         2738                     I am a developer by profession  \
# 67666       67667                     I am a developer by profession
# 22777       22778                     I am a developer by profession
# 58996       58997                     I am a developer by profession
# 27810       27811                     I am a developer by profession
# 57028       57029  I am not primarily a developer, but I write co...
# 64663       64664                     I am a developer by profession
# 30854       30855                     I am a developer by profession
# 15640       15641  I am not primarily a developer, but I write co...
# 51758       51759                     I am a developer by profession
#
#                                               Employment
# 2737                                 Employed, full-time  \
# 67666                                Employed, full-time
# 22777                                Employed, full-time
# 58996  Independent contractor, freelancer, or self-em...
# 27810                                I prefer not to say
# 57028                                            Retired
# 64663  Independent contractor, freelancer, or self-em...
# 30854  Independent contractor, freelancer, or self-em...
# 15640  Independent contractor, freelancer, or self-em...
# 51758  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork
# 2737                           Fully remote  \
# 67666                          Fully remote
# 22777                          Fully remote
# 58996                          Fully remote
# 27810                                   NaN
# 57028                                   NaN
# 64663                          Fully remote
# 30854  Hybrid (some remote, some in-person)
# 15640                          Fully remote
# 51758                          Fully remote
#
#                                         CodingActivities
# 2737   Hobby;Contribute to open-source projects;Freel...  \
# 67666                                                NaN
# 22777  Hobby;Contribute to open-source projects;Freel...
# 58996   Bootstrapping a business;Freelance/contract work
# 27810                                                NaN
# 57028                                                NaN
# 64663                     Hobby;Bootstrapping a business
# 30854                                              Hobby
# 15640  Hobby;Contribute to open-source projects;Boots...
# 51758                            Freelance/contract work
#
#                                                  EdLevel
# 2737     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  \
# 67666                                     Something else
# 22777    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 58996  Some college/university study without earning ...
# 27810  Some college/university study without earning ...
# 57028         Other doctoral degree (Ph.D., Ed.D., etc.)
# 64663       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 30854    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 15640       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51758       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode
# 2737   Books / Physical media;School (i.e., Universit...  \
# 67666  Books / Physical media;Other online resources ...
# 22777  Other online resources (e.g., videos, blogs, f...
# 58996  Books / Physical media;Other online resources ...
# 27810  Books / Physical media;School (i.e., Universit...
# 57028                   Books / Physical media;Colleague
# 64663  Books / Physical media;Other online resources ...
# 30854  School (i.e., University, College, etc);Other ...
# 15640  Other online resources (e.g., videos, blogs, f...
# 51758  Other online resources (e.g., videos, blogs, f...
#
#                                          LearnCodeOnline LearnCodeCoursesCert
# 2737                                                 NaN                  NaN  \
# 67666  Technical documentation;Blogs;Written Tutorial...        Udemy;Udacity
# 22777  Technical documentation;Stack Overflow;Online ...    Udemy;Pluralsight
# 58996             Technical documentation;Stack Overflow                  NaN
# 27810                                                NaN                Other
# 57028                                                NaN                  NaN
# 64663  Technical documentation;Blogs;Written Tutorial...                  NaN
# 30854                                                NaN                  NaN
# 15640  Technical documentation;Blogs;Written Tutorial...                  NaN
# 51758  Technical documentation;Blogs;Stack Overflow;V...   Coursera;Udemy;edX
#
#                 YearsCode YearsCodePro
# 2737                   17           13  \
# 67666                  15          NaN
# 22777                  18           12
# 58996                  22           22
# 27810                  41           41
# 57028  More than 50 years           48
# 64663                  30           15
# 30854                  12            2
# 15640                   5            1
# 51758                   5            4
#
#                                                  DevType
# 2737   Engineer, site reliability;Developer, back-end...  \
# 67666                                                NaN
# 22777                              Developer, full-stack
# 58996  Developer, front-end;Developer, full-stack;Dev...
# 27810                                                NaN
# 57028                                                NaN
# 64663                        Developer, game or graphics
# 30854  Developer, front-end;Developer, QA or test;Dev...
# 15640  Developer, full-stack;Developer, back-end;Proj...
# 51758          Developer, full-stack;Developer, back-end
#
#                                                  OrgSize
# 2737                                100 to 499 employees  \
# 67666                                                NaN
# 22777                           5,000 to 9,999 employees
# 58996                                   2 to 9 employees
# 27810  Just me - I am a freelancer, sole proprietor, ...
# 57028  Just me - I am a freelancer, sole proprietor, ...
# 64663  Just me - I am a freelancer, sole proprietor, ...
# 30854                                   2 to 9 employees
# 15640                                   2 to 9 employees
# 51758  Just me - I am a freelancer, sole proprietor, ...
#
#                       PurchaseInfluence
# 2737              I have some influence  \
# 67666     I have little or no influence
# 22777     I have little or no influence
# 58996  I have a great deal of influence
# 27810  I have a great deal of influence
# 57028  I have a great deal of influence
# 64663  I have a great deal of influence
# 30854  I have a great deal of influence
# 15640  I have a great deal of influence
# 51758  I have a great deal of influence
#
#                                               BuyNewTool      Country
# 2737   Start a free trial;Ask developers I know/work ...  Afghanistan  \
# 67666                                 Start a free trial  Afghanistan
# 22777    Visit developer communities like Stack Overflow    Argentina
# 58996  Start a free trial;Ask developers I know/work ...    Australia
# 27810  Start a free trial;Visit developer communities...    Australia
# 57028  Start a free trial;Ask developers I know/work ...    Australia
# 64663  Start a free trial;Visit developer communities...    Australia
# 30854  Start a free trial;Visit developer communities...      Belgium
# 15640  Start a free trial;Visit developer communities...       Brazil
# 51758  Start a free trial;Visit developer communities...       Brazil
#
#                               Currency  CompTotal CompFreq
# 2737               AFN\tAfghan afghani        0.0  Monthly  \
# 67666  AED United Arab Emirates dirham        0.0      NaN
# 22777              ARS\tArgentine peso        0.0  Monthly
# 58996        USD\tUnited States dollar        0.0   Yearly
# 27810           AUD\tAustralian dollar        0.0   Yearly
# 57028           AUD\tAustralian dollar        0.0   Yearly
# 64663           AUD\tAustralian dollar        0.0   Yearly
# 30854                EUR European Euro        0.0      NaN
# 15640              BRL\tBrazilian real        0.0  Monthly
# 51758              BRL\tBrazilian real        0.0   Yearly
#
#                                   LanguageHaveWorkedWith
# 2737   Assembly;Bash/Shell;C;C#;C++;Java;JavaScript;K...  \
# 67666                   HTML/CSS;Java;JavaScript;PHP;SQL
# 22777                                    Java;JavaScript
# 58996   C++;JavaScript;Kotlin;Perl;PHP;SAS;SQL;Swift;VBA
# 27810                                      Delphi;Python
# 57028                                             Delphi
# 64663                                        C#;HTML/CSS
# 30854                         HTML/CSS;JavaScript;Python
# 15640                   JavaScript;Python;SQL;TypeScript
# 51758                              HTML/CSS;JavaScript;R
#
#                                   LanguageWantToWorkWith
# 2737   Assembly;Bash/Shell;C;C#;C++;Java;JavaScript;K...  \
# 67666                   HTML/CSS;Java;JavaScript;PHP;SQL
# 22777                                    Java;JavaScript
# 58996                                                NaN
# 27810                                                NaN
# 57028                                             Delphi
# 64663                                    C#;C++;HTML/CSS
# 30854                   C;C++;HTML/CSS;JavaScript;Python
# 15640           Go;JavaScript;Python;Rust;SQL;TypeScript
# 51758                                       JavaScript;R
#
#                                   DatabaseHaveWorkedWith
# 2737               Elasticsearch;PostgreSQL;Redis;SQLite  \
# 67666                                      MariaDB;MySQL
# 22777  Couchbase;CouchDB;Microsoft SQL Server;MySQL;O...
# 58996                 MariaDB;Microsoft SQL Server;MySQL
# 27810                                       MySQL;SQLite
# 57028                                                NaN
# 64663                                                NaN
# 30854                                         PostgreSQL
# 15640             Elasticsearch;MongoDB;PostgreSQL;Redis
# 51758                           MongoDB;PostgreSQL;Redis
#
#                       DatabaseWantToWorkWith
# 2737   Elasticsearch;PostgreSQL;Redis;SQLite  \
# 67666                          MariaDB;MySQL
# 22777                 MySQL;PostgreSQL;Redis
# 58996                                    NaN
# 27810                                    NaN
# 57028                                    NaN
# 64663                                    NaN
# 30854            DynamoDB;MongoDB;PostgreSQL
# 15640     Couchbase;CouchDB;PostgreSQL;Redis
# 51758               MongoDB;PostgreSQL;Redis
#
#                   PlatformHaveWorkedWith   PlatformWantToWorkWith
# 2737   AWS;DigitalOcean;Google Cloud;OVH             Google Cloud  \
# 67666                                NaN                      NaN
# 22777            AWS;Google Cloud;Heroku  AWS;Google Cloud;Heroku
# 58996      Linode;Managed Hosting;VMware                      NaN
# 27810                                NaN                      NaN
# 57028                                NaN                      NaN
# 64663                    Microsoft Azure          Microsoft Azure
# 30854                                AWS                      AWS
# 15640      AWS;DigitalOcean;Google Cloud   DigitalOcean;OpenStack
# 51758                                AWS                      AWS
#
#                  WebframeHaveWorkedWith
# 2737      Angular;FastAPI;Flask;Node.js  \
# 67666                    jQuery;Symfony
# 22777               Angular.js;React.js
# 58996                            Drupal
# 27810                            jQuery
# 57028                               NaN
# 64663                            Blazor
# 30854                   Django;React.js
# 15640            FastAPI;Flask;React.js
# 51758  Express;Next.js;Node.js;React.js
#
#                       WebframeWantToWorkWith
# 2737   Angular;FastAPI;Flask;Next.js;Node.js  \
# 67666                                Symfony
# 22777                               React.js
# 58996                                    NaN
# 27810                                    NaN
# 57028                                    NaN
# 64663                                 Blazor
# 30854                        Django;React.js
# 15640               FastAPI;Node.js;React.js
# 51758                   Deno;Next.js;Node.js
#
#                   MiscTechHaveWorkedWith             MiscTechWantToWorkWith
# 2737   Apache Kafka;Qt;Spring;TensorFlow  Apache Kafka;Qt;Spring;TensorFlow  \
# 67666                                NaN                                NaN
# 22777           .NET;React Native;Spring                React Native;Spring
# 58996                                NaN                                NaN
# 27810                               .NET                                NaN
# 57028                                NaN                                NaN
# 64663                               .NET                               .NET
# 30854                                NaN                                NaN
# 15640                             Pandas       Apache Kafka;Electron;Pandas
# 51758                          Tidyverse               Tidyverse;TensorFlow
#
#                                  ToolsTechHaveWorkedWith
# 2737        Docker;Homebrew;Kubernetes;npm;Unreal Engine  \
# 67666                                         Docker;npm
# 22777                    Docker;Homebrew;Kubernetes;Yarn
# 58996                                                NaN
# 27810                                                NaN
# 57028                                                NaN
# 64663                                      Unreal Engine
# 30854                                        Docker;Yarn
# 15640  Ansible;Docker;Homebrew;Kubernetes;Terraform;Yarn
# 51758                                         Docker;npm
#
#                                  ToolsTechWantToWorkWith
# 2737        Docker;Homebrew;Kubernetes;npm;Unreal Engine  \
# 67666                                         Docker;npm
# 22777                    Docker;Homebrew;Kubernetes;Yarn
# 58996                                                NaN
# 27810                                                NaN
# 57028                                                NaN
# 64663                                      Unreal Engine
# 30854                                        Docker;Yarn
# 15640  Ansible;Docker;Homebrew;Kubernetes;Terraform;Yarn
# 51758                              Docker;Kubernetes;npm
#
#                             NEWCollabToolsHaveWorkedWith
# 2737   Android Studio;Atom;CLion;IntelliJ;Vim;Visual ...  \
# 67666  IntelliJ;NetBeans;Notepad++;PhpStorm;Visual St...
# 22777  Eclipse;IntelliJ;NetBeans;Notepad++;Sublime Te...
# 58996     Android Studio;Eclipse;Notepad++;Visual Studio
# 27810                                                NaN
# 57028                   RAD Studio (Delphi, C++ Builder)
# 64663                                      Visual Studio
# 30854               Notepad++;PyCharm;Visual Studio Code
# 15640  IntelliJ;IPython/Jupyter;PyCharm;Sublime Text;...
# 51758                                 Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith
# 2737   Android Studio;Atom;CLion;IntelliJ;Qt Creator;...  \
# 67666                        IntelliJ;Notepad++;PhpStorm
# 22777     IntelliJ;Sublime Text;Visual Studio Code;Xcode
# 58996                                                NaN
# 27810                                                NaN
# 57028                   RAD Studio (Delphi, C++ Builder)
# 64663                                      Visual Studio
# 30854         CLion;Notepad++;PyCharm;Visual Studio Code
# 15640                 IPython/Jupyter;Visual Studio Code
# 51758                         RStudio;Visual Studio Code
#
#                            OpSysProfessional use
# 2737                   Linux-based;macOS;Windows  \
# 67666                        Linux-based;Windows
# 22777                  Linux-based;macOS;Windows
# 58996                                        NaN
# 27810                                        NaN
# 57028                                    Windows
# 64663                                    Windows
# 30854  Windows;Windows Subsystem for Linux (WSL)
# 15640                                      macOS
# 51758          Windows Subsystem for Linux (WSL)
#
#                                        OpSysPersonal use VersionControlSystem
# 2737                                               macOS                  Git  \
# 67666                                Linux-based;Windows                  Git
# 22777                          Linux-based;macOS;Windows                  Git
# 58996                          Linux-based;macOS;Windows      I don't use one
# 27810  Linux-based;macOS;Windows;Other (please specify):      I don't use one
# 57028                                            Windows      I don't use one
# 64663                                            Windows      I don't use one
# 30854          Windows;Windows Subsystem for Linux (WSL)                  Git
# 15640                                              macOS                  Git
# 51758                                            Windows                  Git
#
#                                            VCInteraction
# 2737                            Code editor;Command-line  \
# 67666                           Code editor;Command-line
# 22777                                       Command-line
# 58996                                                NaN
# 27810                                                NaN
# 57028                                                NaN
# 64663                                                NaN
# 30854  Version control hosting service web GUI;Dedica...
# 15640                           Code editor;Command-line
# 51758                                       Command-line
#
#        VCHostingPersonal use  VCHostingProfessional use
# 2737                     NaN                        NaN  \
# 67666                    NaN                        NaN
# 22777                    NaN                        NaN
# 58996                    NaN                        NaN
# 27810                    NaN                        NaN
# 57028                    NaN                        NaN
# 64663                    NaN                        NaN
# 30854                    NaN                        NaN
# 15640                    NaN                        NaN
# 51758                    NaN                        NaN
#
#                           OfficeStackAsyncHaveWorkedWith
# 2737                  Jira Work Management;Notion;Trello  \
# 67666                                                NaN
# 22777                      Airtable;Jira Work Management
# 58996                                                NaN
# 27810                                                NaN
# 57028                                                NaN
# 64663                                                NaN
# 30854                                             Trello
# 15640  Asana;ClickUp;Jira Work Management;monday.com;...
# 51758                                                NaN
#
#       OfficeStackAsyncWantToWorkWith
# 2737     Jira Work Management;Notion  \
# 67666                            NaN
# 22777  Airtable;Jira Work Management
# 58996                            NaN
# 27810                            NaN
# 57028                            NaN
# 64663                            NaN
# 30854                         Trello
# 15640    Jira Work Management;Notion
# 51758                            NaN
#
#                            OfficeStackSyncHaveWorkedWith
# 2737        Cisco Webex Teams;Microsoft Teams;Slack;Zoom  \
# 67666                                              Slack
# 22777  Cisco Webex Teams;Google Chat;Microsoft Teams;...
# 58996                                               Zoom
# 27810                                                NaN
# 57028                                                NaN
# 64663                                                NaN
# 30854                                              Slack
# 15640  Cisco Webex Teams;Google Chat;Microsoft Teams;...
# 51758                                                NaN
#
#                            OfficeStackSyncWantToWorkWith        Blockchain
# 2737                                          Slack;Zoom         Favorable  \
# 67666                                                NaN       Unfavorable
# 22777  Cisco Webex Teams;Google Chat;Microsoft Teams;...       Indifferent
# 58996                                                NaN  Very unfavorable
# 27810                                                NaN  Very unfavorable
# 57028                                                NaN       Unfavorable
# 64663                                                NaN       Unfavorable
# 30854                                              Slack         Favorable
# 15640                                   Rocketchat;Slack    Very favorable
# 51758                                                NaN         Favorable
#
#                                               NEWSOSites
# 2737                       Stack Overflow;Stack Exchange  \
# 67666                      Stack Overflow;Stack Exchange
# 22777       Collectives on Stack Overflow;Stack Overflow
# 58996                      Stack Overflow;Stack Exchange
# 27810                                     Stack Overflow
# 57028  I have never visited Stack Overflow or the Sta...
# 64663                                     Stack Overflow
# 30854                                     Stack Overflow
# 15640                      Stack Overflow;Stack Exchange
# 51758                      Stack Overflow;Stack Exchange
#
#                                SOVisitFreq SOAccount
# 2737                  A few times per week       Yes  \
# 67666                 A few times per week       Yes
# 22777                 A few times per week       Yes
# 58996      A few times per month or weekly       Yes
# 27810      A few times per month or weekly       Yes
# 57028                                  NaN        No
# 64663  Less than once per month or monthly       Yes
# 30854                 A few times per week       Yes
# 15640                Daily or almost daily       Yes
# 51758                Daily or almost daily       Yes
#
#                                               SOPartFreq          SOComm
# 2737                 Less than once per month or monthly         Neutral  \
# 67666                Less than once per month or monthly        Not sure
# 22777                Less than once per month or monthly   Yes, somewhat
# 58996                Less than once per month or monthly  No, not at all
# 27810                Less than once per month or monthly         Neutral
# 57028                                                NaN  No, not really
# 64663                Less than once per month or monthly  No, not at all
# 30854  I have never participated in Q&A on Stack Over...  No, not really
# 15640                    A few times per month or weekly   Yes, somewhat
# 51758                               A few times per week   Yes, somewhat
#
#                      Age                  Gender                   Trans
# 2737     25-34 years old                     Man                     NaN  \
# 67666  Prefer not to say  Or, in your own words:  Or, in your own words:
# 22777    35-44 years old                     Man                      No
# 58996  65 years or older                     Man                      No
# 27810  65 years or older                     Man                      No
# 57028  65 years or older                     Man                      No
# 64663    35-44 years old                     Man                      No
# 30854    25-34 years old                     Man                      No
# 15640    35-44 years old                     Man                      No
# 51758    25-34 years old                     Man                      No
#
#                       Sexuality             Ethnicity
# 2737                        NaN                   NaN  \
# 67666  Prefer to self-describe:        White;European
# 22777   Straight / Heterosexual  Hispanic or Latino/a
# 58996   Straight / Heterosexual                 White
# 27810   Straight / Heterosexual        White;European
# 57028   Straight / Heterosexual              European
# 64663   Straight / Heterosexual        White;European
# 30854   Straight / Heterosexual        White;European
# 15640   Straight / Heterosexual                 White
# 51758   Straight / Heterosexual           Multiracial
#
#                                            Accessibility
# 2737                                                 NaN  \
# 67666                                  Prefer not to say
# 22777                                  None of the above
# 58996                                  None of the above
# 27810  I am unable to / find it difficult to walk or ...
# 57028                                  None of the above
# 64663                                  None of the above
# 30854                                  None of the above
# 15640                                  None of the above
# 51758                                  None of the above
#
#                  MentalHealth TBranch                   ICorPM  WorkExp
# 2737                      NaN      No                      NaN      NaN  \
# 67666       Prefer not to say     Yes  Independent contributor      NaN
# 22777       None of the above     Yes  Independent contributor     12.0
# 58996       None of the above     Yes           People manager     50.0
# 27810  Or, in your own words:     NaN                      NaN      NaN
# 57028       None of the above     NaN                      NaN      NaN
# 64663       None of the above     NaN                      NaN      NaN
# 30854       None of the above     Yes  Independent contributor      3.0
# 15640       None of the above      No                      NaN      NaN
# 51758       None of the above     NaN                      NaN      NaN
#
#           Knowledge_1                 Knowledge_2                 Knowledge_3
# 2737              NaN                         NaN                         NaN  \
# 67666             NaN                         NaN                         NaN
# 22777             NaN                         NaN                         NaN
# 58996           Agree  Neither agree nor disagree  Neither agree nor disagree
# 27810             NaN                         NaN                         NaN
# 57028             NaN                         NaN                         NaN
# 64663             NaN                         NaN                         NaN
# 30854  Strongly agree           Strongly disagree                       Agree
# 15640             NaN                         NaN                         NaN
# 51758             NaN                         NaN                         NaN
#
#           Knowledge_4     Knowledge_5 Knowledge_6        Knowledge_7
# 2737              NaN             NaN         NaN                NaN  \
# 67666             NaN             NaN         NaN                NaN
# 22777             NaN             NaN         NaN                NaN
# 58996           Agree           Agree       Agree              Agree
# 27810             NaN             NaN         NaN                NaN
# 57028             NaN             NaN         NaN                NaN
# 64663             NaN             NaN         NaN                NaN
# 30854  Strongly agree  Strongly agree    Disagree  Strongly disagree
# 15640             NaN             NaN         NaN                NaN
# 51758             NaN             NaN         NaN                NaN
#
#             Frequency_1       Frequency_2 Frequency_3        TimeSearching
# 2737                NaN               NaN         NaN                  NaN  \
# 67666               NaN               NaN         NaN                  NaN
# 22777               NaN               NaN         NaN                  NaN
# 58996  1-2 times a week  1-2 times a week       Never  15-30 minutes a day
# 27810               NaN               NaN         NaN                  NaN
# 57028               NaN               NaN         NaN                  NaN
# 64663               NaN               NaN         NaN                  NaN
# 30854             Never  3-5 times a week       Never  15-30 minutes a day
# 15640               NaN               NaN         NaN                  NaN
# 51758               NaN               NaN         NaN                  NaN
#
#                     TimeAnswering     Onboarding
# 2737                          NaN            NaN  \
# 67666                         NaN            NaN
# 22777                         NaN            NaN
# 58996  Less than 15 minutes a day  Somewhat long
# 27810                         NaN            NaN
# 57028                         NaN            NaN
# 64663                         NaN            NaN
# 30854  Less than 15 minutes a day  Somewhat long
# 15640                         NaN            NaN
# 51758                         NaN            NaN
#
#                                         ProfessionalTech TrueFalse_1
# 2737                                                 NaN         NaN  \
# 67666                                                NaN         NaN
# 22777  Microservices;Continuous integration (CI) and ...          No
# 58996                                      None of these         Yes
# 27810                                                NaN         NaN
# 57028                                                NaN         NaN
# 64663                                                NaN         NaN
# 30854                             Innersource initiative         Yes
# 15640                                                NaN         NaN
# 51758                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength
# 2737          NaN         NaN               Too long  \
# 67666         NaN         NaN               Too long
# 22777          No          No               Too long
# 58996         Yes         Yes  Appropriate in length
# 27810         NaN         NaN               Too long
# 57028         NaN         NaN  Appropriate in length
# 64663         NaN         NaN  Appropriate in length
# 30854         Yes         Yes  Appropriate in length
# 15640         NaN         NaN  Appropriate in length
# 51758         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 2737                         Easy                  NaN
# 67666                   Difficult                  NaN
# 22777  Neither easy nor difficult                  NaN
# 58996  Neither easy nor difficult                  NaN
# 27810                        Easy                  NaN
# 57028  Neither easy nor difficult                  NaN
# 64663  Neither easy nor difficult                  NaN
# 30854  Neither easy nor difficult                  NaN
# 15640  Neither easy nor difficult                  NaN
# 51758                        Easy                  NaN

# %% [markdown]
# ## (Part 8) - Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
dfs.head()
# Out:
#        ResponseId                                         MainBranch
# 55665       55666                     I am a developer by profession  \
# 3641         3642                     I am a developer by profession
# 61617       61618  I am not primarily a developer, but I write co...
# 6891         6892                     I am a developer by profession
# 58077       58078                     I am a developer by profession
#
#                                               Employment
# 55665  Independent contractor, freelancer, or self-em...  \
# 3641                                 Employed, part-time
# 61617                                Employed, part-time
# 6891                                 Employed, full-time
# 58077                                Employed, full-time
#
#                                  RemoteWork
# 55665                        Full in-person  \
# 3641   Hybrid (some remote, some in-person)
# 61617                        Full in-person
# 6891                         Full in-person
# 58077  Hybrid (some remote, some in-person)
#
#                                         CodingActivities
# 55665  Hobby;Contribute to open-source projects;Freel...  \
# 3641                       Hobby;Freelance/contract work
# 61617                                              Hobby
# 6891   Contribute to open-source projects;Freelance/c...
# 58077                       I don’t code outside of work
#
#                                                  EdLevel
# 55665       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  \
# 3641        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 61617  Some college/university study without earning ...
# 6891        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 58077       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode
# 55665  Books / Physical media;Other online resources ...  \
# 3641   School (i.e., University, College, etc);On the...
# 61617                             Books / Physical media
# 6891   Other online resources (e.g., videos, blogs, f...
# 58077  Friend or family member;Other online resources...
#
#                                          LearnCodeOnline LearnCodeCoursesCert
# 55665     Written Tutorials;Stack Overflow;How-to videos                  NaN  \
# 3641                                                 NaN          Udemy;Other
# 61617                                                NaN                  NaN
# 6891   Technical documentation;Blogs;Written Tutorial...       Coursera;Udemy
# 58077  Technical documentation;Blogs;Written Tutorial...                Udemy
#
#       YearsCode YearsCodePro
# 55665         8            4  \
# 3641          3            1
# 61617        10            2
# 6891          3            1
# 58077        10            3
#
#                                                  DevType
# 55665  Data scientist or machine learning specialist;...  \
# 3641                           Student;Developer, mobile
# 61617                                           Designer
# 6891   Developer, full-stack;Developer, back-end;Deve...
# 58077  Developer, back-end;Database administrator;Dat...
#
#                                                  OrgSize
# 55665                                   2 to 9 employees  \
# 3641                                  10 to 19 employees
# 61617  Just me - I am a freelancer, sole proprietor, ...
# 6891                                  10 to 19 employees
# 58077                           1,000 to 4,999 employees
#
#                       PurchaseInfluence
# 55665             I have some influence  \
# 3641              I have some influence
# 61617     I have little or no influence
# 6891              I have some influence
# 58077  I have a great deal of influence
#
#                                               BuyNewTool      Country
# 55665                                 Start a free trial  Afghanistan  \
# 3641                                                 NaN  Afghanistan
# 61617  Start a free trial;Read ratings or reviews on ...  Afghanistan
# 6891   Start a free trial;Ask developers I know/work ...  Afghanistan
# 58077  Start a free trial;Ask developers I know/work ...  Afghanistan
#
#                         Currency   CompTotal CompFreq
# 55665  USD\tUnited States dollar       200.0  Monthly  \
# 3641   USD\tUnited States dollar         NaN  Monthly
# 61617  USD\tUnited States dollar         NaN  Monthly
# 6891           IRR\tIranian rial  55000000.0  Monthly
# 58077    BOB\tBolivian boliviano         NaN  Monthly
#
#                                  LanguageHaveWorkedWith
# 55665  C#;C++;Dart;HTML/CSS;Java;JavaScript;PHP;SQL;VBA  \
# 3641                      Dart;HTML/CSS;Java;JavaScript
# 61617                                    JavaScript;PHP
# 6891                                HTML/CSS;JavaScript
# 58077                           C#;HTML/CSS;PHP;SQL;VBA
#
#                                   LanguageWantToWorkWith
# 55665  C#;C++;Dart;HTML/CSS;Java;JavaScript;Kotlin;PH...  \
# 3641   Dart;HTML/CSS;JavaScript;Kotlin;Python;SQL;Typ...
# 61617                                                NaN
# 6891                   Go;HTML/CSS;JavaScript;TypeScript
# 58077                                       HTML/CSS;SQL
#
#                                   DatabaseHaveWorkedWith
# 55665  Microsoft SQL Server;MySQL;Oracle;Firebase Rea...  \
# 3641                                        MySQL;SQLite
# 61617                                            MariaDB
# 6891                                       MongoDB;MySQL
# 58077                 IBM DB2;Microsoft SQL Server;MySQL
#
#                                   DatabaseWantToWorkWith
# 55665  Microsoft SQL Server;MySQL;Oracle;Firebase Rea...  \
# 3641   Cloud Firestore;MongoDB;MySQL;PostgreSQL;Fireb...
# 61617                                                NaN
# 6891                   Elasticsearch;MongoDB;MySQL;Redis
# 58077                         Microsoft SQL Server;MySQL
#
#        PlatformHaveWorkedWith
# 55665   Firebase;Google Cloud  \
# 3641          Firebase;Heroku
# 61617     DigitalOcean;Linode
# 6891   Heroku;Managed Hosting
# 58077                     NaN
#
#                                   PlatformWantToWorkWith
# 55665  AWS;Firebase;Google Cloud;Microsoft Azure;Orac...  \
# 3641    AWS;Firebase;Google Cloud;Heroku;Microsoft Azure
# 61617                                                NaN
# 6891                              Heroku;Managed Hosting
# 58077                                                NaN
#
#               WebframeHaveWorkedWith            WebframeWantToWorkWith
# 55665                 ASP.NET;jQuery            ASP.NET;jQuery;Laravel  \
# 3641                        React.js  Express;Next.js;Node.js;React.js
# 61617                         jQuery                               NaN
# 6891        Next.js;Node.js;React.js        Deno;Django;FastAPI;Vue.js
# 58077  ASP.NET;ASP.NET Core ;Laravel             ASP.NET;ASP.NET Core
#
#       MiscTechHaveWorkedWith MiscTechWantToWorkWith ToolsTechHaveWorkedWith
# 55665           .NET;Flutter           .NET;Flutter                     NaN  \
# 3641    Flutter;React Native   Flutter;React Native                npm;Yarn
# 61617                Cordova                    NaN                  Docker
# 6891                     NaN                    NaN                npm;Yarn
# 58077                   .NET                   .NET              Docker;npm
#
#       ToolsTechWantToWorkWith
# 55665                     NaN  \
# 3641                 npm;Yarn
# 61617                     NaN
# 6891   Docker;Kubernetes;Yarn
# 58077                     NaN
#
#                             NEWCollabToolsHaveWorkedWith
# 55665  Android Studio;NetBeans;Visual Studio;Visual S...  \
# 3641                   Android Studio;Visual Studio Code
# 61617                                     Android Studio
# 6891                         Visual Studio Code;Webstorm
# 58077  Eclipse;IntelliJ;NetBeans;Notepad++;PhpStorm;S...
#
#                             NEWCollabToolsWantToWorkWith
# 55665  Android Studio;Eclipse;IntelliJ;PyCharm;Visual...  \
# 3641                   Android Studio;Visual Studio Code
# 61617                                                NaN
# 6891                         Visual Studio Code;Webstorm
# 58077  IntelliJ;Notepad++;PhpStorm;Sublime Text;Visua...
#
#       OpSysProfessional use OpSysPersonal use VersionControlSystem
# 55665         macOS;Windows           Windows                  Git  \
# 3641                Windows           Windows                  Git
# 61617         macOS;Windows     macOS;Windows      I don't use one
# 6891    Linux-based;Windows           Windows                  Git
# 58077               Windows           Windows      I don't use one
#
#                                            VCInteraction
# 55665  Code editor;Command-line;Version control hosti...  \
# 3641                                        Command-line
# 61617                                                NaN
# 6891                                        Command-line
# 58077                                                NaN
#
#        VCHostingPersonal use  VCHostingProfessional use
# 55665                    NaN                        NaN  \
# 3641                     NaN                        NaN
# 61617                    NaN                        NaN
# 6891                     NaN                        NaN
# 58077                    NaN                        NaN
#
#             OfficeStackAsyncHaveWorkedWith OfficeStackAsyncWantToWorkWith
# 55665                                  NaN                            NaN  \
# 3641                                   NaN                            NaN
# 61617                               Trello                            NaN
# 6891                                Trello                            NaN
# 58077  ClickUp;Jira Work Management;Trello           Jira Work Management
#
#                 OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith
# 55665                                     NaN                           NaN  \
# 3641                                     Zoom                          Zoom
# 61617                                    Zoom                           NaN
# 6891                                      NaN                           NaN
# 58077  Cisco Webex Teams;Microsoft Teams;Zoom        Cisco Webex Teams;Zoom
#
#              Blockchain                     NEWSOSites
# 55665            Unsure  Stack Overflow;Stack Exchange  \
# 3641          Favorable                 Stack Overflow
# 61617  Very unfavorable  Stack Overflow;Stack Exchange
# 6891          Favorable                 Stack Overflow
# 58077            Unsure  Stack Overflow;Stack Exchange
#
#                                SOVisitFreq                SOAccount
# 55665                Daily or almost daily                      Yes  \
# 3641                 Daily or almost daily                      Yes
# 61617  Less than once per month or monthly  Not sure/can't remember
# 6891                Multiple times per day                      Yes
# 58077                Daily or almost daily                      Yes
#
#                                 SOPartFreq           SOComm              Age
# 55665      A few times per month or weekly  Yes, definitely  25-34 years old  \
# 3641                  A few times per week  Yes, definitely  18-24 years old
# 61617                                  NaN   No, not at all  35-44 years old
# 6891       A few times per month or weekly    Yes, somewhat  18-24 years old
# 58077  Less than once per month or monthly    Yes, somewhat  18-24 years old
#
#       Gender Trans                Sexuality                        Ethnicity
# 55665    Man    No                 Bisexual  Asian;South Asian;Central Asian  \
# 3641     Man    No                      NaN                              NaN
# 61617    NaN   NaN                      NaN                              NaN
# 6891     Man    No  Straight / Heterosexual                            Asian
# 58077    Man    No                      NaN                         European
#
#            Accessibility                                       MentalHealth
# 55665  None of the above                                  None of the above  \
# 3641                 NaN                                                NaN
# 61617                NaN                                                NaN
# 6891   None of the above  I have a mood or emotional disorder (e.g., dep...
# 58077  None of the above                                  None of the above
#
#       TBranch                   ICorPM  WorkExp                 Knowledge_1
# 55665     Yes  Independent contributor     14.0                       Agree  \
# 3641      Yes  Independent contributor      2.0                       Agree
# 61617     NaN                      NaN      NaN                         NaN
# 6891      Yes  Independent contributor      2.0  Neither agree nor disagree
# 58077     Yes           People manager      3.0  Neither agree nor disagree
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4
# 55665                    Disagree           Strongly disagree  Strongly agree  \
# 3641                          NaN  Neither agree nor disagree           Agree
# 61617                         NaN                         NaN             NaN
# 6891   Neither agree nor disagree                    Disagree           Agree
# 58077                    Disagree                       Agree           Agree
#
#           Knowledge_5        Knowledge_6                 Knowledge_7
# 55665  Strongly agree     Strongly agree                    Disagree  \
# 3641   Strongly agree              Agree                       Agree
# 61617             NaN                NaN                         NaN
# 6891            Agree     Strongly agree  Neither agree nor disagree
# 58077             NaN  Strongly disagree                    Disagree
#
#             Frequency_1       Frequency_2       Frequency_3
# 55665  1-2 times a week  3-5 times a week             Never  \
# 3641   1-2 times a week  1-2 times a week               NaN
# 61617               NaN               NaN               NaN
# 6891   1-2 times a week  1-2 times a week  1-2 times a week
# 58077  1-2 times a week             Never             Never
#
#                 TimeSearching               TimeAnswering     Onboarding
# 55665     30-60 minutes a day         15-30 minutes a day  Somewhat long  \
# 3641      15-30 minutes a day  Less than 15 minutes a day  Somewhat long
# 61617                     NaN                         NaN            NaN
# 6891   Over 120 minutes a day  Less than 15 minutes a day  Somewhat long
# 58077     30-60 minutes a day      Over 120 minutes a day      Very long
#
#                                         ProfessionalTech TrueFalse_1
# 55665                                      None of these         Yes  \
# 3641                                                 NaN          No
# 61617                                                NaN         NaN
# 6891                                       None of these         Yes
# 58077  Microservices;Developer portal or other centra...          No
#
#       TrueFalse_2 TrueFalse_3           SurveyLength
# 55665          No         Yes               Too long  \
# 3641          Yes         Yes  Appropriate in length
# 61617         NaN         NaN                    NaN
# 6891          Yes         Yes               Too long
# 58077         Yes         Yes               Too long
#
#                        SurveyEase  ConvertedCompYearly
# 55665  Neither easy nor difficult               2400.0
# 3641   Neither easy nor difficult                  NaN
# 61617                   Difficult                  NaN
# 6891                         Easy              15600.0
# 58077  Neither easy nor difficult                  NaN

# %%
dfs['CompTotal'].head(15)
# Out:
# 55665         200.0
# 3641            NaN
# 61617           NaN
# 6891     55000000.0
# 58077           NaN
# 42122           NaN
# 28582           NaN
# 38512     1200000.0
# 43639      700000.0
# 43690      100000.0
# 6242        40000.0
# 23223       40000.0
# 2737            0.0
# 4502            NaN
# 15607           NaN
# Name: CompTotal, dtype: float64

# %%
dfs['CompTotal'].median()
# Out:
# 77500.0

# %%
dfs.describe()
# Out:
#          ResponseId     CompTotal  VCHostingPersonal use
# count  73268.000000  3.842200e+04                    0.0  \
# mean   36634.500000  2.342434e+52                    NaN
# std    21150.794099  4.591478e+54                    NaN
# min        1.000000  0.000000e+00                    NaN
# 25%    18317.750000  3.000000e+04                    NaN
# 50%    36634.500000  7.750000e+04                    NaN
# 75%    54951.250000  1.540000e+05                    NaN
# max    73268.000000  9.000000e+56                    NaN
#
#        VCHostingProfessional use       WorkExp  ConvertedCompYearly
# count                        0.0  36769.000000         3.807100e+04
# mean                         NaN     10.242378         1.707613e+05
# std                          NaN      8.706850         7.814132e+05
# min                          NaN      0.000000         1.000000e+00
# 25%                          NaN      4.000000         3.583200e+04
# 50%                          NaN      8.000000         6.784500e+04
# 75%                          NaN     15.000000         1.200000e+05
# max                          NaN     50.000000         5.000000e+07

# %%
dfs['CompTotal'].count()
# Out:
# 38422

# %%
dfs['SOAccount']
# Out:
# 55665                        Yes
# 3641                         Yes
# 61617    Not sure/can't remember
# 6891                         Yes
# 58077                        Yes
# 42122                         No
# 28582                        Yes
# 38512    Not sure/can't remember
# 43639                        Yes
# 43690                        Yes
# 6242                         Yes
# 23223                        Yes
# 2737                         Yes
# 4502                         Yes
# 15607                        Yes
# 17038                         No
# 24812                        Yes
# 53960                        Yes
# 55393                        Yes
# 56355                        Yes
# 60146                        Yes
# 2448     Not sure/can't remember
# 49273                        Yes
# 3886                         Yes
# 5464                         Yes
#                   ...
# 72193                        NaN
# 72371                        NaN
# 72397                        NaN
# 72401                        NaN
# 72474                        NaN
# 72493                        NaN
# 72525                        NaN
# 72626                        NaN
# 72635                        NaN
# 72660                        NaN
# 72666                        NaN
# 72700                        NaN
# 72794                        NaN
# 72913                        NaN
# 73003                        NaN
# 73004                        NaN
# 73031                        NaN
# 73043                        NaN
# 73059                        NaN
# 73076                        NaN
# 73109                        NaN
# 73157                        NaN
# 73201                        NaN
# 73215                        NaN
# 73243                        NaN
# Name: SOAccount, Length: 73268, dtype: object

# %%
dfs['SOAccount'].value_counts()
# Out:
# SOAccount
# Yes                        58519
# No                          8951
# Not sure/can't remember     4102
# Name: count, dtype: int64

# %%
dfs['Sexuality']
# Out:
# 55665                                             Bisexual
# 3641                                                   NaN
# 61617                                                  NaN
# 6891                               Straight / Heterosexual
# 58077                                                  NaN
# 42122                             Prefer to self-describe:
# 28582                                    Prefer not to say
# 38512    Bisexual;Straight / Heterosexual;Gay or Lesbia...
# 43639                              Straight / Heterosexual
# 43690                              Straight / Heterosexual
# 6242                                     Prefer not to say
# 23223                              Straight / Heterosexual
# 2737                                                   NaN
# 4502                               Straight / Heterosexual
# 15607                                    Prefer not to say
# 17038                                                  NaN
# 24812                                                  NaN
# 53960                              Straight / Heterosexual
# 55393                                                  NaN
# 56355                                             Bisexual
# 60146                                                  NaN
# 2448                              Prefer to self-describe:
# 49273                                                  NaN
# 3886                                     Prefer not to say
# 5464                                                   NaN
#                                ...
# 72193                                                  NaN
# 72371                                                  NaN
# 72397                                                  NaN
# 72401                                                  NaN
# 72474                                                  NaN
# 72493                                                  NaN
# 72525                                                  NaN
# 72626                                                  NaN
# 72635                                                  NaN
# 72660                                                  NaN
# 72666                                                  NaN
# 72700                                                  NaN
# 72794                                                  NaN
# 72913                                                  NaN
# 73003                                                  NaN
# 73004                                                  NaN
# 73031                                                  NaN
# 73043                                                  NaN
# 73059                                                  NaN
# 73076                                                  NaN
# 73109                                                  NaN
# 73157                                                  NaN
# 73201                                                  NaN
# 73215                                                  NaN
# 73243                                                  NaN
# Name: Sexuality, Length: 73268, dtype: object

# %%
schema_dfs.loc[47]
# Out:
# qid                                                      QID136
# qname                                                 Sexuality
# question      Which of the following describe you, if any? P...
# force_resp                                                False
# type                                                         MC
# selector                                                   MAVR
# Name: 47, dtype: object

# %%
dfs['Sexuality'].value_counts(normalize=True)
# Out:
# Sexuality
# Straight / Heterosexual                                                           0.829835
# Prefer not to say                                                                 0.065350
# Bisexual                                                                          0.040562
# Gay or Lesbian                                                                    0.020762
# Prefer to self-describe:                                                          0.016210
# Queer                                                                             0.005919
# Bisexual;Straight / Heterosexual                                                  0.005318
# Bisexual;Queer                                                                    0.004236
# Straight / Heterosexual;Prefer to self-describe:                                  0.002539
# Gay or Lesbian;Queer                                                              0.002253
# Straight / Heterosexual;Queer                                                     0.001187
# Bisexual;Gay or Lesbian                                                           0.001097
# Prefer to self-describe:;Queer                                                    0.000766
# Bisexual;Gay or Lesbian;Queer                                                     0.000661
# Bisexual;Straight / Heterosexual;Gay or Lesbian;Queer                             0.000541
# Bisexual;Prefer to self-describe:                                                 0.000451
# Bisexual;Prefer to self-describe:;Queer                                           0.000391
# Bisexual;Straight / Heterosexual;Prefer to self-describe:;Gay or Lesbian;Queer    0.000376
# Bisexual;Straight / Heterosexual;Gay or Lesbian                                   0.000315
# Bisexual;Straight / Heterosexual;Queer                                            0.000285
# Straight / Heterosexual;Gay or Lesbian                                            0.000180
# Prefer to self-describe:;Gay or Lesbian;Queer                                     0.000180
# Prefer to self-describe:;Gay or Lesbian                                           0.000180
# Bisexual;Straight / Heterosexual;Prefer to self-describe:                         0.000120
# Straight / Heterosexual;Prefer to self-describe:;Queer                            0.000105
# Bisexual;Prefer to self-describe:;Gay or Lesbian                                  0.000045
# Bisexual;Prefer to self-describe:;Gay or Lesbian;Queer                            0.000030
# Straight / Heterosexual;Gay or Lesbian;Queer                                      0.000030
# Bisexual;Straight / Heterosexual;Prefer to self-describe:;Gay or Lesbian          0.000030
# Bisexual;Straight / Heterosexual;Prefer to self-describe:;Queer                   0.000015
# Straight / Heterosexual;Prefer to self-describe:;Gay or Lesbian                   0.000015
# Straight / Heterosexual;Prefer to self-describe:;Gay or Lesbian;Queer             0.000015
# Name: proportion, dtype: float64

# %%
dfs['Country'].value_counts()
# Out:
# Country
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
# France                                                   2328
# Brazil                                                   2109
# Poland                                                   1732
# Netherlands                                              1555
# Spain                                                    1521
# Italy                                                    1514
# Australia                                                1462
# Russian Federation                                       1229
# Turkey                                                   1020
# Sweden                                                   1020
# Switzerland                                               932
# Austria                                                   833
# Israel                                                    795
# Iran, Islamic Republic of...                              723
# Pakistan                                                  711
# Czech Republic                                            692
# China                                                     632
# Belgium                                                   626
# Bangladesh                                                613
# Ukraine                                                   593
#                                                         ...
# Bahamas                                                     4
# Cape Verde                                                  4
# Belize                                                      3
# Haiti                                                       3
# Niger                                                       3
# Chad                                                        3
# Saint Lucia                                                 3
# Antigua and Barbuda                                         2
# Palau                                                       2
# Papua New Guinea                                            2
# Sierra Leone                                                2
# Gambia                                                      2
# Gabon                                                       2
# Mauritania                                                  2
# Fiji                                                        2
# Liberia                                                     2
# Lesotho                                                     2
# Brunei Darussalam                                           1
# Saint Kitts and Nevis                                       1
# San Marino                                                  1
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: count, Length: 180, dtype: int64

# %%
country_grp = dfs.groupby(dfs['Country'])

# %%
country_grp.get_group('Argentina')
# Out:
#        ResponseId                                         MainBranch
# 31989       31990                     I am a developer by profession  \
# 22167       22168                     I am a developer by profession
# 72625       72626                     I am a developer by profession
# 15470       15471  I am not primarily a developer, but I write co...
# 25468       25469                     I am a developer by profession
# 50184       50185                     I am a developer by profession
# 37211       37212                     I am a developer by profession
# 37306       37307                     I am a developer by profession
# 44577       44578                     I am a developer by profession
# 51868       51869                     I am a developer by profession
# 59937       59938                     I am a developer by profession
# 71358       71359                     I am a developer by profession
# 37852       37853                     I am a developer by profession
# 49727       49728                     I am a developer by profession
# 71619       71620                     I am a developer by profession
# 72190       72191                     I am a developer by profession
# 51992       51993                     I am a developer by profession
# 63569       63570                     I am a developer by profession
# 53870       53871                     I am a developer by profession
# 39102       39103                     I am a developer by profession
# 14786       14787                     I am a developer by profession
# 66323       66324                     I am a developer by profession
# 68411       68412                     I am a developer by profession
# 44249       44250                     I am a developer by profession
# 54303       54304                     I am a developer by profession
# ...           ...                                                ...
# 61406       61407                              I am learning to code
# 61801       61802                     I am a developer by profession
# 62024       62025  I am not primarily a developer, but I write co...
# 63608       63609                              I am learning to code
# 63914       63915                              I am learning to code
# 64379       64380                              I am learning to code
# 64649       64650                     I am a developer by profession
# 65739       65740                     I am a developer by profession
# 65864       65865                     I am a developer by profession
# 65973       65974                              I am learning to code
# 66607       66608                     I am a developer by profession
# 67995       67996                     I am a developer by profession
# 68173       68174                     I am a developer by profession
# 68582       68583                              I am learning to code
# 68665       68666                     I am a developer by profession
# 69512       69513                              I am learning to code
# 69642       69643                              I am learning to code
# 70322       70323                        I code primarily as a hobby
# 70602       70603                     I am a developer by profession
# 70606       70607                              I am learning to code
# 71613       71614                     I am a developer by profession
# 71738       71739  I am not primarily a developer, but I write co...
# 72875       72876                              I am learning to code
# 72981       72982                              I am learning to code
# 73140       73141                              I am learning to code
#
#                                               Employment
# 31989                                Employed, full-time  \
# 22167  Independent contractor, freelancer, or self-em...
# 72625                                Employed, full-time
# 15470  Employed, full-time;Independent contractor, fr...
# 25468  Employed, full-time;Independent contractor, fr...
# 50184                                Employed, full-time
# 37211  Employed, full-time;Independent contractor, fr...
# 37306                                Employed, full-time
# 44577  Independent contractor, freelancer, or self-em...
# 51868                                Employed, full-time
# 59937  Employed, full-time;Independent contractor, fr...
# 71358                                Employed, full-time
# 37852  Independent contractor, freelancer, or self-em...
# 49727                                Employed, full-time
# 71619                                Employed, full-time
# 72190  Employed, full-time;Independent contractor, fr...
# 51992  Employed, full-time;Independent contractor, fr...
# 63569                                Employed, full-time
# 53870  Independent contractor, freelancer, or self-em...
# 39102                                Employed, full-time
# 14786  Employed, full-time;Independent contractor, fr...
# 66323  Independent contractor, freelancer, or self-em...
# 68411  Employed, full-time;Independent contractor, fr...
# 44249                                Employed, full-time
# 54303  Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 61406  Student, part-time;Not employed, but looking f...
# 61801  Employed, full-time;Student, part-time;Indepen...
# 62024             Not employed, and not looking for work
# 63608                                 Student, full-time
# 63914                 Not employed, but looking for work
# 64379                                 Student, full-time
# 64649             Employed, full-time;Student, part-time
# 65739             Employed, full-time;Student, part-time
# 65864             Employed, full-time;Student, full-time
# 65973             Not employed, and not looking for work
# 66607  Student, full-time;Not employed, but looking f...
# 67995                                 Student, full-time
# 68173  Student, full-time;Independent contractor, fre...
# 68582                                Employed, full-time
# 68665  Employed, full-time;Student, part-time;Indepen...
# 69512             Student, full-time;Employed, part-time
# 69642  Independent contractor, freelancer, or self-em...
# 70322  Student, part-time;Not employed, and not looki...
# 70602  Employed, full-time;Student, part-time;Indepen...
# 70606                 Not employed, but looking for work
# 71613  Student, part-time;Independent contractor, fre...
# 71738                                 Student, part-time
# 72875                 Not employed, but looking for work
# 72981  Independent contractor, freelancer, or self-em...
# 73140                                 Student, full-time
#
#                                  RemoteWork
# 31989                          Fully remote  \
# 22167                          Fully remote
# 72625                          Fully remote
# 15470                          Fully remote
# 25468  Hybrid (some remote, some in-person)
# 50184                          Fully remote
# 37211                          Fully remote
# 37306                          Fully remote
# 44577                          Fully remote
# 51868                          Fully remote
# 59937                          Fully remote
# 71358                          Fully remote
# 37852                          Fully remote
# 49727                          Fully remote
# 71619                          Fully remote
# 72190                          Fully remote
# 51992                          Fully remote
# 63569                          Fully remote
# 53870                          Fully remote
# 39102                          Fully remote
# 14786                          Fully remote
# 66323                          Fully remote
# 68411                          Fully remote
# 44249                          Fully remote
# 54303                          Fully remote
# ...                                     ...
# 61406                                   NaN
# 61801                          Fully remote
# 62024                                   NaN
# 63608                                   NaN
# 63914                                   NaN
# 64379                                   NaN
# 64649  Hybrid (some remote, some in-person)
# 65739                          Fully remote
# 65864                          Fully remote
# 65973                                   NaN
# 66607                                   NaN
# 67995                                   NaN
# 68173                          Fully remote
# 68582                          Fully remote
# 68665                          Fully remote
# 69512  Hybrid (some remote, some in-person)
# 69642                          Fully remote
# 70322                                   NaN
# 70602                          Fully remote
# 70606                                   NaN
# 71613  Hybrid (some remote, some in-person)
# 71738                                   NaN
# 72875                                   NaN
# 72981                        Full in-person
# 73140                                   NaN
#
#                                         CodingActivities
# 31989                                              Hobby  \
# 22167                           Bootstrapping a business
# 72625                                              Hobby
# 15470                     Hobby;Bootstrapping a business
# 25468  Hobby;Contribute to open-source projects;Boots...
# 50184                       I don’t code outside of work
# 37211  Hobby;Contribute to open-source projects;Freel...
# 37306                       I don’t code outside of work
# 44577                      Hobby;Freelance/contract work
# 51868                                              Hobby
# 59937  Hobby;Contribute to open-source projects;Boots...
# 71358                                              Hobby
# 37852    Freelance/contract work;School or academic work
# 49727                                              Hobby
# 71619                                              Hobby
# 72190  Hobby;Contribute to open-source projects;Boots...
# 51992                     Hobby;Bootstrapping a business
# 63569                       I don’t code outside of work
# 53870                                              Hobby
# 39102                                              Hobby
# 14786  Hobby;Contribute to open-source projects;Freel...
# 66323                       I don’t code outside of work
# 68411                       I don’t code outside of work
# 44249                                              Hobby
# 54303                                              Hobby
# ...                                                  ...
# 61406                                                NaN
# 61801                            Freelance/contract work
# 62024                                                NaN
# 63608                                                NaN
# 63914                                                NaN
# 64379                                                NaN
# 64649                     Hobby;Bootstrapping a business
# 65739                      Hobby;School or academic work
# 65864                      Hobby;School or academic work
# 65973                                                NaN
# 66607                                                NaN
# 67995                                                NaN
# 68173                       I don’t code outside of work
# 68582                      Hobby;School or academic work
# 68665                                              Hobby
# 69512                      Hobby;Freelance/contract work
# 69642    Freelance/contract work;School or academic work
# 70322                                                NaN
# 70602                                              Hobby
# 70606                                                NaN
# 71613  Hobby;Bootstrapping a business;Freelance/contr...
# 71738                                                NaN
# 72875                                                NaN
# 72981                            School or academic work
# 73140                                                NaN
#
#                                                  EdLevel
# 31989  Secondary school (e.g. American high school, G...  \
# 22167       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 72625  Secondary school (e.g. American high school, G...
# 15470    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 25468    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 50184  Secondary school (e.g. American high school, G...
# 37211  Some college/university study without earning ...
# 37306                Associate degree (A.A., A.S., etc.)
# 44577       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51868       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 59937  Some college/university study without earning ...
# 71358  Some college/university study without earning ...
# 37852       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49727       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 71619  Some college/university study without earning ...
# 72190       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51992  Some college/university study without earning ...
# 63569       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 53870       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 39102  Some college/university study without earning ...
# 14786  Some college/university study without earning ...
# 66323  Secondary school (e.g. American high school, G...
# 68411                 Professional degree (JD, MD, etc.)
# 44249  Some college/university study without earning ...
# 54303    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                  ...
# 61406  Secondary school (e.g. American high school, G...
# 61801                 Professional degree (JD, MD, etc.)
# 62024         Other doctoral degree (Ph.D., Ed.D., etc.)
# 63608  Secondary school (e.g. American high school, G...
# 63914       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64379  Secondary school (e.g. American high school, G...
# 64649  Some college/university study without earning ...
# 65739    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65864  Some college/university study without earning ...
# 65973                 Professional degree (JD, MD, etc.)
# 66607  Some college/university study without earning ...
# 67995  Secondary school (e.g. American high school, G...
# 68173       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 68582       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 68665  Some college/university study without earning ...
# 69512  Secondary school (e.g. American high school, G...
# 69642                 Professional degree (JD, MD, etc.)
# 70322                          Primary/elementary school
# 70602                 Professional degree (JD, MD, etc.)
# 70606  Some college/university study without earning ...
# 71613                 Professional degree (JD, MD, etc.)
# 71738  Secondary school (e.g. American high school, G...
# 72875  Some college/university study without earning ...
# 72981  Secondary school (e.g. American high school, G...
# 73140  Secondary school (e.g. American high school, G...
#
#                                                LearnCode
# 31989                            Friend or family member  \
# 22167  Books / Physical media;School (i.e., Universit...
# 72625  Other online resources (e.g., videos, blogs, f...
# 15470  Books / Physical media;Other online resources ...
# 25468  Books / Physical media;Other online resources ...
# 50184  Books / Physical media;Friend or family member...
# 37211  Books / Physical media;Other online resources ...
# 37306  Books / Physical media;Other online resources ...
# 44577  Other online resources (e.g., videos, blogs, f...
# 51868  Books / Physical media;Other online resources ...
# 59937  Books / Physical media;School (i.e., Universit...
# 71358            School (i.e., University, College, etc)
# 37852  Other online resources (e.g., videos, blogs, f...
# 49727  Other online resources (e.g., videos, blogs, f...
# 71619  Books / Physical media;School (i.e., Universit...
# 72190  Books / Physical media;Friend or family member...
# 51992  Books / Physical media;Other online resources ...
# 63569  Books / Physical media;Other online resources ...
# 53870  Books / Physical media;Other online resources ...
# 39102  Books / Physical media;Other online resources ...
# 14786  Other online resources (e.g., videos, blogs, f...
# 66323  School (i.e., University, College, etc);Online...
# 68411  Other online resources (e.g., videos, blogs, f...
# 44249                             Books / Physical media
# 54303  School (i.e., University, College, etc);Online...
# ...                                                  ...
# 61406  Other online resources (e.g., videos, blogs, f...
# 61801  On the job training;Online Courses or Certific...
# 62024  Books / Physical media;Other online resources ...
# 63608            School (i.e., University, College, etc)
# 63914                    Online Courses or Certification
# 64379  Books / Physical media;Other online resources ...
# 64649  Other online resources (e.g., videos, blogs, f...
# 65739            School (i.e., University, College, etc)
# 65864  Books / Physical media;Other online resources ...
# 65973  Friend or family member;Other online resources...
# 66607                    Online Courses or Certification
# 67995  Other online resources (e.g., videos, blogs, f...
# 68173  Other online resources (e.g., videos, blogs, f...
# 68582                                    Coding Bootcamp
# 68665  Other online resources (e.g., videos, blogs, f...
# 69512  Friend or family member;Other online resources...
# 69642  Other online resources (e.g., videos, blogs, f...
# 70322  Other online resources (e.g., videos, blogs, f...
# 70602  Books / Physical media;Other online resources ...
# 70606  Other online resources (e.g., videos, blogs, f...
# 71613  Friend or family member;Other online resources...
# 71738  Other online resources (e.g., videos, blogs, f...
# 72875  Other online resources (e.g., videos, blogs, f...
# 72981  Books / Physical media;Other online resources ...
# 73140  Other online resources (e.g., videos, blogs, f...
#
#                                          LearnCodeOnline
# 31989                                                NaN  \
# 22167                                                NaN
# 72625  Technical documentation;Blogs;Written Tutorial...
# 15470  Technical documentation;Blogs;Written Tutorial...
# 25468  Technical documentation;Blogs;Programming Game...
# 50184  Technical documentation;Blogs;Written Tutorial...
# 37211  Technical documentation;Blogs;Written Tutorial...
# 37306       Technical documentation;Blogs;Stack Overflow
# 44577                      Technical documentation;Blogs
# 51868  Technical documentation;Blogs;Stack Overflow;O...
# 59937                                                NaN
# 71358                                                NaN
# 37852  Technical documentation;Blogs;Written Tutorial...
# 49727  Technical documentation;Blogs;Written Tutorial...
# 71619                                                NaN
# 72190  Technical documentation;Blogs;Programming Game...
# 51992  Technical documentation;Blogs;Stack Overflow;O...
# 63569  Technical documentation;Blogs;Written Tutorial...
# 53870  Technical documentation;Blogs;Written Tutorial...
# 39102  Technical documentation;Blogs;Programming Game...
# 14786  Technical documentation;Written Tutorials;Stac...
# 66323                                                NaN
# 68411  Technical documentation;Written Tutorials;Stac...
# 44249                                                NaN
# 54303                                                NaN
# ...                                                  ...
# 61406  Technical documentation;Blogs;Programming Game...
# 61801                                                NaN
# 62024  Technical documentation;Stack Overflow;Online ...
# 63608                                                NaN
# 63914                                                NaN
# 64379  Written Tutorials;Stack Overflow;Online books;...
# 64649  Technical documentation;Blogs;Stack Overflow;V...
# 65739                                                NaN
# 65864  Technical documentation;Blogs;Stack Overflow;O...
# 65973  Technical documentation;Blogs;Written Tutorial...
# 66607                                                NaN
# 67995  Technical documentation;Blogs;Programming Game...
# 68173  Technical documentation;Blogs;Written Tutorial...
# 68582                                                NaN
# 68665  Technical documentation;Blogs;Written Tutorial...
# 69512  Technical documentation;Blogs;Written Tutorial...
# 69642  Technical documentation;Blogs;Stack Overflow;V...
# 70322  Technical documentation;Blogs;Programming Game...
# 70602             Technical documentation;Stack Overflow
# 70606  Technical documentation;Stack Overflow;Video-b...
# 71613  Technical documentation;Stack Overflow;Online ...
# 71738  Technical documentation;Stack Overflow;Video-b...
# 72875  Technical documentation;Stack Overflow;Online ...
# 72981  Technical documentation;Online books;Video-bas...
# 73140  Technical documentation;Written Tutorials;Stac...
#
#                         LearnCodeCoursesCert         YearsCode YearsCodePro
# 31989                                    NaN                 2            2  \
# 22167                                    NaN                25           22
# 72625                                    NaN                22           18
# 15470                                    NaN                22           16
# 25468                                    NaN                10           10
# 50184                                  Udemy                25           12
# 37211           Codecademy;Pluralsight;Other                36           31
# 37306                                    NaN                30           22
# 44577                                    NaN                14           10
# 51868                                    NaN                 9            5
# 59937                                    NaN                12           10
# 71358                                    NaN                 4            3
# 37852                                    NaN                29           25
# 49727  Coursera;Udemy;Codecademy;edX;Udacity                 5            2
# 71619                                  Udemy                 6            4
# 72190      Coursera;Udemy;Codecademy;Udacity                18           15
# 51992                                  Udemy                14            7
# 63569                                  Udemy                18           11
# 53870                            Udemy;Other                26           17
# 39102             Coursera;Udemy;Pluralsight                20           15
# 14786                                    NaN                13           13
# 66323                                  Udemy                 8            7
# 68411                                    NaN                20           20
# 44249                                    NaN                25           20
# 54303                       Udemy;Codecademy                15           10
# ...                                      ...               ...          ...
# 61406                                  Other                 3          NaN
# 61801                              Udemy;edX                 2          NaN
# 62024                                    NaN                20          NaN
# 63608                                    NaN                 2          NaN
# 63914                                  Udemy                 1          NaN
# 64379                              Udemy;edX                 2          NaN
# 64649                       Udemy;Codecademy                 3          NaN
# 65739                                    NaN                10          NaN
# 65864                            Udemy;Other                 4          NaN
# 65973                                  Udemy  Less than 1 year          NaN
# 66607                                  Udemy                 2          NaN
# 67995                                  Udemy                 2          NaN
# 68173                    Udemy;Udacity;Other                 4          NaN
# 68582                                    NaN  Less than 1 year          NaN
# 68665              Coursera;Udemy;Codecademy                 8          NaN
# 69512                 Udemy;Codecademy;Other                 5          NaN
# 69642                                  Other                 2          NaN
# 70322                                    NaN                 1          NaN
# 70602                                    NaN               NaN          NaN
# 70606                                  Udemy                 2          NaN
# 71613                                    NaN                11          NaN
# 71738                                  Other                 2          NaN
# 72875                                    NaN                 3          NaN
# 72981                            Udemy;Other  Less than 1 year          NaN
# 73140                            Udemy;Other  Less than 1 year          NaN
#
#                                                  DevType
# 31989                                Academic researcher  \
# 22167  Developer, full-stack;Cloud infrastructure eng...
# 72625  Engineer, site reliability;Developer, full-sta...
# 15470        Developer, full-stack;Security professional
# 25468  Developer, front-end;Developer, full-stack;Dev...
# 50184                               Developer, front-end
# 37211  Developer, full-stack;Developer, back-end;Syst...
# 37306  Developer, front-end;Developer, full-stack;Dev...
# 44577              Developer, back-end;Developer, mobile
# 51868                                Developer, back-end
# 59937          Developer, full-stack;Developer, back-end
# 71358                                Developer, back-end
# 37852          Developer, full-stack;Educator;Blockchain
# 49727         Developer, front-end;Developer, full-stack
# 71619                     Developer, back-end;Blockchain
# 72190  Data scientist or machine learning specialist;...
# 51992  Developer, front-end;Developer, full-stack;Dev...
# 63569                                Developer, back-end
# 53870  Developer, front-end;Developer, full-stack;Dev...
# 39102          Developer, full-stack;Developer, back-end
# 14786  Developer, front-end;Developer, full-stack;Dev...
# 66323                                  Developer, mobile
# 68411  Data scientist or machine learning specialist;...
# 44249                              Developer, full-stack
# 54303  Developer, back-end;DevOps specialist;Cloud in...
# ...                                                  ...
# 61406  Developer, front-end;Developer, embedded appli...
# 61801                                Developer, back-end
# 62024                                                NaN
# 63608                                                NaN
# 63914                                                NaN
# 64379                                                NaN
# 64649  Developer, full-stack;Student;Educator;Project...
# 65739  Developer, back-end;Student;Cloud infrastructu...
# 65864                      Developer, full-stack;Student
# 65973                                                NaN
# 66607  Developer, front-end;Developer, full-stack;Blo...
# 67995                                                NaN
# 68173                          Student;Developer, mobile
# 68582                   Student;Data or business analyst
# 68665  Developer, front-end;Developer, full-stack;Dev...
# 69512                      Developer, full-stack;Student
# 69642             Developer, full-stack;Student;Educator
# 70322                                                NaN
# 70602                              Developer, full-stack
# 70606                                            Student
# 71613  Engineer, data;Developer, full-stack;Student;D...
# 71738                                                NaN
# 72875                        Developer, back-end;Student
# 72981                                            Student
# 73140                                                NaN
#
#                                                  OrgSize
# 31989                                 10 to 19 employees  \
# 22167  Just me - I am a freelancer, sole proprietor, ...
# 72625                                 20 to 99 employees
# 15470                                 20 to 99 employees
# 25468                                 20 to 99 employees
# 50184                               100 to 499 employees
# 37211                                   2 to 9 employees
# 37306                           5,000 to 9,999 employees
# 44577                               500 to 999 employees
# 51868                               100 to 499 employees
# 59937                               100 to 499 employees
# 71358                                 20 to 99 employees
# 37852  Just me - I am a freelancer, sole proprietor, ...
# 49727                                 20 to 99 employees
# 71619                                 20 to 99 employees
# 72190                                 20 to 99 employees
# 51992                                 20 to 99 employees
# 63569                           10,000 or more employees
# 53870                                 20 to 99 employees
# 39102                               100 to 499 employees
# 14786                           10,000 or more employees
# 66323                                 10 to 19 employees
# 68411                                   2 to 9 employees
# 44249                               100 to 499 employees
# 54303                                 10 to 19 employees
# ...                                                  ...
# 61406                                                NaN
# 61801                                                NaN
# 62024                                                NaN
# 63608                                                NaN
# 63914                                                NaN
# 64379                                                NaN
# 64649                                                NaN
# 65739                                                NaN
# 65864                                                NaN
# 65973                                                NaN
# 66607                                                NaN
# 67995                                                NaN
# 68173                                                NaN
# 68582                                                NaN
# 68665                                                NaN
# 69512                                                NaN
# 69642                                                NaN
# 70322                                                NaN
# 70602                                                NaN
# 70606                                                NaN
# 71613                                                NaN
# 71738                                                NaN
# 72875                                                NaN
# 72981                                                NaN
# 73140                                                NaN
#
#                       PurchaseInfluence
# 31989  I have a great deal of influence  \
# 22167  I have a great deal of influence
# 72625  I have a great deal of influence
# 15470             I have some influence
# 25468  I have a great deal of influence
# 50184  I have a great deal of influence
# 37211             I have some influence
# 37306     I have little or no influence
# 44577             I have some influence
# 51868             I have some influence
# 59937             I have some influence
# 71358             I have some influence
# 37852  I have a great deal of influence
# 49727             I have some influence
# 71619             I have some influence
# 72190             I have some influence
# 51992             I have some influence
# 63569     I have little or no influence
# 53870             I have some influence
# 39102     I have little or no influence
# 14786             I have some influence
# 66323             I have some influence
# 68411  I have a great deal of influence
# 44249     I have little or no influence
# 54303  I have a great deal of influence
# ...                                 ...
# 61406                               NaN
# 61801                               NaN
# 62024                               NaN
# 63608                               NaN
# 63914                               NaN
# 64379                               NaN
# 64649                               NaN
# 65739                               NaN
# 65864                               NaN
# 65973                               NaN
# 66607                               NaN
# 67995                               NaN
# 68173                               NaN
# 68582                               NaN
# 68665                               NaN
# 69512                               NaN
# 69642                               NaN
# 70322                               NaN
# 70602                               NaN
# 70606                               NaN
# 71613                               NaN
# 71738                               NaN
# 72875                               NaN
# 72981                               NaN
# 73140                               NaN
#
#                                               BuyNewTool    Country
# 31989                                 Start a free trial  Argentina  \
# 22167  Read ratings or reviews on third party sites l...  Argentina
# 72625  Start a free trial;Visit developer communities...  Argentina
# 15470  Start a free trial;Visit developer communities...  Argentina
# 25468  Visit developer communities like Stack Overflo...  Argentina
# 50184  Start a free trial;Ask developers I know/work ...  Argentina
# 37211  Start a free trial;Visit developer communities...  Argentina
# 37306  Start a free trial;Ask developers I know/work ...  Argentina
# 44577  Start a free trial;Visit developer communities...  Argentina
# 51868  Other (please specify):;Start a free trial;Vis...  Argentina
# 59937  Start a free trial;Ask developers I know/work ...  Argentina
# 71358                    Ask developers I know/work with  Argentina
# 37852                            Other (please specify):  Argentina
# 49727  Start a free trial;Visit developer communities...  Argentina
# 71619  Visit developer communities like Stack Overflo...  Argentina
# 72190    Visit developer communities like Stack Overflow  Argentina
# 51992  Start a free trial;Visit developer communities...  Argentina
# 63569  Start a free trial;Visit developer communities...  Argentina
# 53870  Start a free trial;Visit developer communities...  Argentina
# 39102  Visit developer communities like Stack Overflo...  Argentina
# 14786  Start a free trial;Visit developer communities...  Argentina
# 66323  Start a free trial;Visit developer communities...  Argentina
# 68411  Start a free trial;Visit developer communities...  Argentina
# 44249                                 Start a free trial  Argentina
# 54303  Visit developer communities like Stack Overflo...  Argentina
# ...                                                  ...        ...
# 61406  Start a free trial;Visit developer communities...  Argentina
# 61801  Visit developer communities like Stack Overflo...  Argentina
# 62024  Start a free trial;Research companies that hav...  Argentina
# 63608  Read ratings or reviews on third party sites l...  Argentina
# 63914                                                NaN  Argentina
# 64379  Start a free trial;Ask developers I know/work ...  Argentina
# 64649  Start a free trial;Visit developer communities...  Argentina
# 65739  Start a free trial;Visit developer communities...  Argentina
# 65864  Start a free trial;Ask developers I know/work ...  Argentina
# 65973                    Ask developers I know/work with  Argentina
# 66607  Start a free trial;Visit developer communities...  Argentina
# 67995  Visit developer communities like Stack Overflo...  Argentina
# 68173  Start a free trial;Visit developer communities...  Argentina
# 68582    Visit developer communities like Stack Overflow  Argentina
# 68665  Start a free trial;Visit developer communities...  Argentina
# 69512  Start a free trial;Visit developer communities...  Argentina
# 69642  Visit developer communities like Stack Overflo...  Argentina
# 70322  Visit developer communities like Stack Overflo...  Argentina
# 70602                                 Start a free trial  Argentina
# 70606    Visit developer communities like Stack Overflow  Argentina
# 71613  Visit developer communities like Stack Overflo...  Argentina
# 71738  Start a free trial;Ask developers I know/work ...  Argentina
# 72875                                 Start a free trial  Argentina
# 72981                                                NaN  Argentina
# 73140  Start a free trial;Visit developer communities...  Argentina
#
#                              Currency  CompTotal CompFreq
# 31989  XAF\tCentral African CFA franc    57899.0   Weekly  \
# 22167       USD\tUnited States dollar   150000.0   Yearly
# 72625       USD\tUnited States dollar   130000.0   Yearly
# 15470       USD\tUnited States dollar   120000.0  Monthly
# 25468       USD\tUnited States dollar   120000.0   Yearly
# 50184       USD\tUnited States dollar    95000.0   Yearly
# 37211       USD\tUnited States dollar    90000.0   Yearly
# 37306       USD\tUnited States dollar    90000.0   Yearly
# 44577       USD\tUnited States dollar    90000.0   Yearly
# 51868       USD\tUnited States dollar    90000.0   Yearly
# 59937       USD\tUnited States dollar    90000.0   Yearly
# 71358       USD\tUnited States dollar    90000.0   Yearly
# 37852       USD\tUnited States dollar    84000.0   Yearly
# 49727       USD\tUnited States dollar    80000.0   Yearly
# 71619       USD\tUnited States dollar    80000.0   Yearly
# 72190       USD\tUnited States dollar    70000.0   Yearly
# 51992       USD\tUnited States dollar    61136.0   Yearly
# 63569       USD\tUnited States dollar    60000.0   Yearly
# 53870       USD\tUnited States dollar    46000.0   Yearly
# 39102       USD\tUnited States dollar    45000.0   Yearly
# 14786       USD\tUnited States dollar    15000.0  Monthly
# 66323       USD\tUnited States dollar    15000.0  Monthly
# 68411       USD\tUnited States dollar    12000.0  Monthly
# 44249       USD\tUnited States dollar    11800.0  Monthly
# 54303       USD\tUnited States dollar    11000.0  Monthly
# ...                               ...        ...      ...
# 61406                             NaN        NaN      NaN
# 61801                             NaN        NaN      NaN
# 62024                             NaN        NaN      NaN
# 63608                             NaN        NaN      NaN
# 63914                             NaN        NaN      NaN
# 64379                             NaN        NaN      NaN
# 64649                             NaN        NaN      NaN
# 65739                             NaN        NaN      NaN
# 65864                             NaN        NaN      NaN
# 65973                             NaN        NaN      NaN
# 66607                             NaN        NaN      NaN
# 67995                             NaN        NaN      NaN
# 68173                             NaN        NaN      NaN
# 68582                             NaN        NaN      NaN
# 68665                             NaN        NaN      NaN
# 69512                             NaN        NaN      NaN
# 69642                             NaN        NaN      NaN
# 70322                             NaN        NaN      NaN
# 70602                             NaN        NaN      NaN
# 70606                             NaN        NaN      NaN
# 71613                             NaN        NaN      NaN
# 71738                             NaN        NaN      NaN
# 72875                             NaN        NaN      NaN
# 72981                             NaN        NaN      NaN
# 73140                             NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith
# 31989                                                APL  \
# 22167                                              Scala
# 72625  Bash/Shell;C;Elixir;Go;HTML/CSS;JavaScript;Kot...
# 15470  Bash/Shell;C#;Elixir;HTML/CSS;JavaScript;Pytho...
# 25468  C#;Haskell;HTML/CSS;JavaScript;MATLAB;Objectiv...
# 50184                HTML/CSS;JavaScript;Ruby;TypeScript
# 37211  Bash/Shell;C#;C++;HTML/CSS;JavaScript;PowerShe...
# 37306              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 44577  C#;HTML/CSS;Java;JavaScript;Kotlin;SQL;TypeScript
# 51868                                    Bash/Shell;Ruby
# 59937                                JavaScript;Ruby;SQL
# 71358             Go;JavaScript;Rust;Solidity;TypeScript
# 37852  Assembly;Bash/Shell;C;C#;C++;Dart;Delphi;Elixi...
# 49727                       JavaScript;Python;TypeScript
# 71619                         JavaScript;Rust;TypeScript
# 72190  Bash/Shell;C#;Go;HTML/CSS;Java;JavaScript;Powe...
# 51992  C#;HTML/CSS;JavaScript;Objective-C;Python;SQL;...
# 63569                                                 Go
# 53870  Bash/Shell;C#;HTML/CSS;Java;JavaScript;Kotlin;...
# 39102                               C#;Groovy;JavaScript
# 14786                       Dart;JavaScript;Kotlin;Swift
# 66323                                       Python;Swift
# 68411                                  HTML/CSS;Python;R
# 44249                        Crystal;Elixir;Haskell;Ruby
# 54303                  Bash/Shell;Java;JavaScript;Kotlin
# ...                                                  ...
# 61406                         HTML/CSS;JavaScript;Python
# 61801                                Java;SQL;TypeScript
# 62024                                           HTML/CSS
# 63608                                                C++
# 63914                                HTML/CSS;JavaScript
# 64379                                  Bash/Shell;Python
# 64649                        HTML/CSS;JavaScript;PHP;SQL
# 65739               Bash/Shell;JavaScript;SQL;TypeScript
# 65864            HTML/CSS;Java;JavaScript;SQL;TypeScript
# 65973                                                NaN
# 66607                                HTML/CSS;JavaScript
# 67995                HTML/CSS;JavaScript;Python;Solidity
# 68173                             Java;Objective-C;Swift
# 68582                                C;HTML/CSS;Java;SQL
# 68665  Bash/Shell;C;C++;HTML/CSS;JavaScript;Python;Ru...
# 69512                         C++;Kotlin;Python;Solidity
# 69642                 HTML/CSS;JavaScript;SAS;TypeScript
# 70322                                                 C#
# 70602                              JavaScript;TypeScript
# 70606                                HTML/CSS;JavaScript
# 71613       Bash/Shell;Go;JavaScript;PHP;Python;Ruby;SQL
# 71738                            HTML/CSS;JavaScript;SQL
# 72875                                C;HTML/CSS;Java;SQL
# 72981                                HTML/CSS;JavaScript
# 73140                                                NaN
#
#                                   LanguageWantToWorkWith
# 31989                                                APL  \
# 22167                     Elixir;Python;Scala;TypeScript
# 72625        Assembly;Bash/Shell;C;Elixir;Go;Kotlin;Ruby
# 15470      C#;Dart;F#;HTML/CSS;JavaScript;SQL;TypeScript
# 25468  Go;HTML/CSS;JavaScript;Solidity;SQL;Swift;Type...
# 50184          HTML/CSS;JavaScript;Ruby;Swift;TypeScript
# 37211  Bash/Shell;C#;C++;JavaScript;PowerShell;SQL;Ty...
# 37306                     HTML/CSS;JavaScript;TypeScript
# 44577  C#;F#;HTML/CSS;Java;JavaScript;Kotlin;SQL;Type...
# 51868                                Go;Python;Ruby;Rust
# 59937                       Ruby;Solidity;SQL;TypeScript
# 71358                JavaScript;Rust;Solidity;TypeScript
# 37852  Bash/Shell;Elixir;Erlang;JavaScript;Rust;Solid...
# 49727                                  Kotlin;TypeScript
# 71619                JavaScript;Rust;Solidity;TypeScript
# 72190  Bash/Shell;HTML/CSS;JavaScript;Rust;Solidity;T...
# 51992            C#;Clojure;Go;HTML/CSS;JavaScript;Scala
# 63569                                                 Go
# 53870  C#;HTML/CSS;Java;Kotlin;Ruby;Solidity;SQL;Swif...
# 39102                    C#;JavaScript;Python;TypeScript
# 14786                       Dart;JavaScript;Kotlin;Swift
# 66323                                       Python;Swift
# 68411                                                NaN
# 44249    Crystal;Dart;Elixir;JavaScript;Kotlin;Ruby;Rust
# 54303                             Bash/Shell;Java;Kotlin
# ...                                                  ...
# 61406              HTML/CSS;JavaScript;Python;TypeScript
# 61801                     Java;JavaScript;SQL;TypeScript
# 62024                                                NaN
# 63608                                             Python
# 63914                                HTML/CSS;JavaScript
# 64379                                   C;C++;Go;Haskell
# 64649                        Dart;Java;Python;TypeScript
# 65739                                                 Go
# 65864         Go;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 65973                                                NaN
# 66607                                  Go;SQL;TypeScript
# 67995                         JavaScript;Python;Solidity
# 68173                                                NaN
# 68582                                             Python
# 68665  C++;Dart;Go;HTML/CSS;Java;JavaScript;Kotlin;Py...
# 69512         HTML/CSS;Java;JavaScript;Kotlin;Python;SQL
# 69642  HTML/CSS;JavaScript;Python;Ruby;SAS;Solidity;T...
# 70322              HTML/CSS;JavaScript;Python;TypeScript
# 70602                              JavaScript;TypeScript
# 70606                                HTML/CSS;JavaScript
# 71613       Bash/Shell;Go;JavaScript;PHP;Python;Ruby;SQL
# 71738                            HTML/CSS;JavaScript;SQL
# 72875                                           Java;SQL
# 72981                     HTML/CSS;JavaScript;TypeScript
# 73140                                                NaN
#
#                                   DatabaseHaveWorkedWith
# 31989                                          Cassandra  \
# 22167                 Cassandra;Elasticsearch;PostgreSQL
# 72625                                   PostgreSQL;Redis
# 15470                                  PostgreSQL;SQLite
# 25468  Couchbase;CouchDB;Cloud Firestore;Elasticsearc...
# 50184                                                NaN
# 37211                         Microsoft SQL Server;MySQL
# ...
# 39102  1-2 times a week   1-2 times a week  6-10 times a week
# 14786  1-2 times a week   3-5 times a week   1-2 times a week
# 66323  3-5 times a week   1-2 times a week              Never
# 68411  1-2 times a week  6-10 times a week   1-2 times a week
# 44249               NaN                NaN                NaN
# 54303  1-2 times a week   3-5 times a week   1-2 times a week
# ...                 ...                ...                ...
# 61406               NaN                NaN                NaN
# 61801  3-5 times a week   10+ times a week   1-2 times a week
# 62024               NaN                NaN                NaN
# 63608               NaN                NaN                NaN
# 63914               NaN                NaN                NaN
# 64379               NaN                NaN                NaN
# 64649  1-2 times a week   1-2 times a week   1-2 times a week
# 65739  10+ times a week   10+ times a week   3-5 times a week
# 65864               NaN   1-2 times a week   1-2 times a week
# 65973               NaN                NaN                NaN
# 66607               NaN                NaN                NaN
# 67995               NaN                NaN                NaN
# 68173               NaN                NaN                NaN
# 68582               NaN                NaN                NaN
# 68665             Never   3-5 times a week              Never
# 69512               NaN                NaN                NaN
# 69642               NaN                NaN                NaN
# 70322               NaN                NaN                NaN
# 70602  1-2 times a week              Never   1-2 times a week
# 70606               NaN                NaN                NaN
# 71613               NaN                NaN                NaN
# 71738               NaN                NaN                NaN
# 72875               NaN                NaN                NaN
# 72981               NaN                NaN                NaN
# 73140               NaN                NaN                NaN
#
#                     TimeSearching               TimeAnswering      Onboarding
# 31989         30-60 minutes a day         30-60 minutes a day  Somewhat short  \
# 22167                         NaN                         NaN             NaN
# 72625        60-120 minutes a day        60-120 minutes a day   Somewhat long
# 15470         15-30 minutes a day  Less than 15 minutes a day  Somewhat short
# 25468         15-30 minutes a day         15-30 minutes a day      Just right
# 50184  Less than 15 minutes a day         15-30 minutes a day      Just right
# 37211         30-60 minutes a day         30-60 minutes a day       Very long
# 37306         30-60 minutes a day         30-60 minutes a day       Very long
# 44577                         NaN                         NaN             NaN
# 51868         15-30 minutes a day         15-30 minutes a day       Very long
# 59937        60-120 minutes a day         30-60 minutes a day      Just right
# 71358                         NaN                         NaN             NaN
# 37852                         NaN                         NaN             NaN
# 49727         15-30 minutes a day         30-60 minutes a day   Somewhat long
# 71619      Over 120 minutes a day  Less than 15 minutes a day   Somewhat long
# 72190  Less than 15 minutes a day  Less than 15 minutes a day      Very short
# 51992         30-60 minutes a day         30-60 minutes a day      Just right
# 63569         30-60 minutes a day         30-60 minutes a day      Just right
# 53870         30-60 minutes a day        60-120 minutes a day      Just right
# 39102         30-60 minutes a day         15-30 minutes a day  Somewhat short
# 14786  Less than 15 minutes a day  Less than 15 minutes a day      Just right
# 66323         15-30 minutes a day  Less than 15 minutes a day   Somewhat long
# 68411         15-30 minutes a day         30-60 minutes a day   Somewhat long
# 44249                         NaN                         NaN             NaN
# 54303         30-60 minutes a day        60-120 minutes a day      Just right
# ...                           ...                         ...             ...
# 61406                         NaN                         NaN             NaN
# 61801         30-60 minutes a day         15-30 minutes a day      Just right
# 62024                         NaN                         NaN             NaN
# 63608                         NaN                         NaN             NaN
# 63914                         NaN                         NaN             NaN
# 64379                         NaN                         NaN             NaN
# 64649         15-30 minutes a day         30-60 minutes a day       Very long
# 65739        60-120 minutes a day      Over 120 minutes a day       Very long
# 65864         15-30 minutes a day         30-60 minutes a day   Somewhat long
# 65973                         NaN                         NaN             NaN
# 66607                         NaN                         NaN             NaN
# 67995                         NaN                         NaN             NaN
# 68173                         NaN                         NaN             NaN
# 68582                         NaN                         NaN             NaN
# 68665      Over 120 minutes a day  Less than 15 minutes a day  Somewhat short
# 69512                         NaN                         NaN             NaN
# 69642                         NaN                         NaN             NaN
# 70322                         NaN                         NaN             NaN
# 70602         30-60 minutes a day         30-60 minutes a day      Just right
# 70606                         NaN                         NaN             NaN
# 71613                         NaN                         NaN             NaN
# 71738                         NaN                         NaN             NaN
# 72875                         NaN                         NaN             NaN
# 72981                         NaN                         NaN             NaN
# 73140                         NaN                         NaN             NaN
#
#                                         ProfessionalTech TrueFalse_1
# 31989  Developer portal or other central places to fi...         Yes  \
# 22167                                                NaN         NaN
# 72625  DevOps function;Microservices;Continuous integ...         Yes
# 15470                                                NaN         Yes
# 25468  DevOps function;Microservices;Developer portal...         Yes
# 50184  Developer portal or other central places to fi...         Yes
# 37211  Developer portal or other central places to fi...         Yes
# 37306  Developer portal or other central places to fi...         Yes
# 44577                                                NaN         NaN
# 51868  DevOps function;Microservices;Continuous integ...          No
# 59937  DevOps function;Continuous integration (CI) an...         Yes
# 71358                                                NaN         NaN
# 37852                                                NaN         NaN
# 49727  Continuous integration (CI) and (more often) c...         Yes
# 71619                                      Microservices         Yes
# 72190  DevOps function;Continuous integration (CI) an...         Yes
# 51992  DevOps function;Microservices;Continuous integ...          No
# 63569  DevOps function;Microservices;Continuous integ...         Yes
# 53870  DevOps function;Developer portal or other cent...         Yes
# 39102  DevOps function;Microservices;Continuous integ...         Yes
# 14786  Innersource initiative;DevOps function;Microse...         Yes
# 66323                                      None of these          No
# 68411                                      None of these         Yes
# 44249                                                NaN         NaN
# 54303  Microservices;Continuous integration (CI) and ...         Yes
# ...                                                  ...         ...
# 61406                                                NaN         NaN
# 61801  Microservices;Continuous integration (CI) and ...         Yes
# 62024                                                NaN         NaN
# 63608                                                NaN         NaN
# 63914                                                NaN         NaN
# 64379                                                NaN         NaN
# 64649  Continuous integration (CI) and (more often) c...         Yes
# 65739  DevOps function;Microservices;Continuous integ...         Yes
# 65864  Microservices;Continuous integration (CI) and ...         Yes
# 65973                                                NaN         NaN
# 66607                                                NaN         NaN
# 67995                                                NaN         NaN
# 68173                                                NaN         NaN
# 68582                                                NaN         NaN
# 68665  Developer portal or other central places to fi...         Yes
# 69512                                                NaN         NaN
# 69642                                                NaN         NaN
# 70322                                                NaN         NaN
# 70602  DevOps function;Microservices;Developer portal...          No
# 70606                                                NaN         NaN
# 71613                                                NaN         NaN
# 71738                                                NaN         NaN
# 72875                                                NaN         NaN
# 72981                                                NaN         NaN
# 73140                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength
# 31989         Yes         Yes  Appropriate in length  \
# 22167         NaN         NaN               Too long
# 72625          No          No  Appropriate in length
# 15470         Yes         Yes  Appropriate in length
# 25468         Yes         Yes               Too long
# 50184          No         Yes  Appropriate in length
# 37211         Yes         Yes  Appropriate in length
# 37306         Yes         Yes  Appropriate in length
# 44577         NaN         NaN  Appropriate in length
# 51868          No          No  Appropriate in length
# 59937          No         Yes  Appropriate in length
# 71358         NaN         NaN  Appropriate in length
# 37852         NaN         NaN  Appropriate in length
# 49727          No          No  Appropriate in length
# 71619         Yes         Yes  Appropriate in length
# 72190         Yes          No  Appropriate in length
# 51992         Yes         Yes  Appropriate in length
# 63569          No         Yes  Appropriate in length
# 53870          No         Yes  Appropriate in length
# 39102          No          No  Appropriate in length
# 14786         Yes         Yes  Appropriate in length
# 66323          No          No  Appropriate in length
# 68411          No         Yes  Appropriate in length
# 44249         NaN         NaN  Appropriate in length
# 54303         Yes         Yes  Appropriate in length
# ...           ...         ...                    ...
# 61406         NaN         NaN  Appropriate in length
# 61801         Yes         Yes  Appropriate in length
# 62024         NaN         NaN  Appropriate in length
# 63608         NaN         NaN  Appropriate in length
# 63914         NaN         NaN  Appropriate in length
# 64379         NaN         NaN               Too long
# 64649          No         Yes  Appropriate in length
# 65739          No         Yes  Appropriate in length
# 65864          No          No  Appropriate in length
# 65973         NaN         NaN  Appropriate in length
# 66607         NaN         NaN  Appropriate in length
# 67995         NaN         NaN  Appropriate in length
# 68173         NaN         NaN  Appropriate in length
# 68582         NaN         NaN               Too long
# 68665         Yes         Yes  Appropriate in length
# 69512         NaN         NaN  Appropriate in length
# 69642         NaN         NaN               Too long
# 70322         NaN         NaN  Appropriate in length
# 70602         Yes         Yes  Appropriate in length
# 70606         NaN         NaN  Appropriate in length
# 71613         NaN         NaN  Appropriate in length
# 71738         NaN         NaN  Appropriate in length
# 72875         NaN         NaN  Appropriate in length
# 72981         NaN         NaN               Too long
# 73140         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 31989  Neither easy nor difficult               4700.0
# 22167                        Easy             150000.0
# 72625  Neither easy nor difficult             130000.0
# 15470  Neither easy nor difficult            1440000.0
# 25468                        Easy             120000.0
# 50184  Neither easy nor difficult              95000.0
# 37211  Neither easy nor difficult              90000.0
# 37306  Neither easy nor difficult              90000.0
# 44577                        Easy              90000.0
# 51868  Neither easy nor difficult              90000.0
# 59937                        Easy              90000.0
# 71358                        Easy              90000.0
# 37852  Neither easy nor difficult              84000.0
# 49727                        Easy              80000.0
# 71619                        Easy              80000.0
# 72190  Neither easy nor difficult              70000.0
# 51992                        Easy              61136.0
# 63569                        Easy              60000.0
# 53870  Neither easy nor difficult              46000.0
# 39102  Neither easy nor difficult              45000.0
# 14786                        Easy             180000.0
# 66323  Neither easy nor difficult             180000.0
# 68411                        Easy             144000.0
# 44249                        Easy             141600.0
# 54303                        Easy             132000.0
# ...                           ...                  ...
# 61406  Neither easy nor difficult                  NaN
# 61801                        Easy                  NaN
# 62024  Neither easy nor difficult                  NaN
# 63608                        Easy                  NaN
# 63914                        Easy                  NaN
# 64379                        Easy                  NaN
# 64649                        Easy                  NaN
# 65739                        Easy                  NaN
# 65864  Neither easy nor difficult                  NaN
# 65973                        Easy                  NaN
# 66607                        Easy                  NaN
# 67995                        Easy                  NaN
# 68173                        Easy                  NaN
# 68582                        Easy                  NaN
# 68665                        Easy                  NaN
# 69512                        Easy                  NaN
# 69642                        Easy                  NaN
# 70322                        Easy                  NaN
# 70602  Neither easy nor difficult                  NaN
# 70606                        Easy                  NaN
# 71613  Neither easy nor difficult                  NaN
# 71738                        Easy                  NaN
# 72875                        Easy                  NaN
# 72981  Neither easy nor difficult                  NaN
# 73140                        Easy                  NaN
#
# [521 rows x 79 columns]

# %%
filt = dfs['Country'] == 'Argentina'
dfs.loc[filt]['Sexuality'].value_counts()
# Out:
# Sexuality
# Straight / Heterosexual                             443
# Prefer not to say                                    18
# Bisexual                                             15
# Prefer to self-describe:                              8
# Gay or Lesbian                                        7
# Bisexual;Straight / Heterosexual                      6
# Straight / Heterosexual;Prefer to self-describe:      3
# Bisexual;Queer                                        3
# Queer                                                 2
# Gay or Lesbian;Queer                                  2
# Bisexual;Gay or Lesbian                               2
# Bisexual;Straight / Heterosexual;Gay or Lesbian       1
# Name: count, dtype: int64

# %%
country_grp['Sexuality'].value_counts().loc['Argentina']
# Out:
# Sexuality
# Straight / Heterosexual                             443
# Prefer not to say                                    18
# Bisexual                                             15
# Prefer to self-describe:                              8
# Gay or Lesbian                                        7
# Bisexual;Straight / Heterosexual                      6
# Straight / Heterosexual;Prefer to self-describe:      3
# Bisexual;Queer                                        3
# Queer                                                 2
# Gay or Lesbian;Queer                                  2
# Bisexual;Gay or Lesbian                               2
# Bisexual;Straight / Heterosexual;Gay or Lesbian       1
# Name: count, dtype: int64

# %%
country_grp['CompTotal'].median().loc['Argentina']
# Out:
# 110000.0

# %%
country_grp['CompTotal'].agg(['median','mean']).loc['Canada']
# Out:
# median    112000.000000
# mean      125929.087131
# Name: Canada, dtype: float64

# %%
country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageHaveWorkedWith'].apply(
   lambda x: x.str.contains('Python').sum())

# %%
country_respondents = dfs['Country'].value_counts()
country_respondents
# Out:
# Country
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
# France                                                   2328
# Brazil                                                   2109
# Poland                                                   1732
# Netherlands                                              1555
# Spain                                                    1521
# Italy                                                    1514
# Australia                                                1462
# Russian Federation                                       1229
# Turkey                                                   1020
# Sweden                                                   1020
# Switzerland                                               932
# Austria                                                   833
# Israel                                                    795
# Iran, Islamic Republic of...                              723
# Pakistan                                                  711
# Czech Republic                                            692
# China                                                     632
# Belgium                                                   626
# Bangladesh                                                613
# Ukraine                                                   593
#                                                         ...
# Bahamas                                                     4
# Cape Verde                                                  4
# Belize                                                      3
# Haiti                                                       3
# Niger                                                       3
# Chad                                                        3
# Saint Lucia                                                 3
# Antigua and Barbuda                                         2
# Palau                                                       2
# Papua New Guinea                                            2
# Sierra Leone                                                2
# Gambia                                                      2
# Gabon                                                       2
# Mauritania                                                  2
# Fiji                                                        2
# Liberia                                                     2
# Lesotho                                                     2
# Brunei Darussalam                                           1
# Saint Kitts and Nevis                                       1
# San Marino                                                  1
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: count, Length: 180, dtype: int64

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                                               25
# Albania                                                   19
# Algeria                                                   19
# Andorra                                                    4
# Angola                                                     3
# Antigua and Barbuda                                        0
# Argentina                                                180
# Armenia                                                   44
# Australia                                                705
# Austria                                                  385
# Azerbaijan                                                34
# Bahamas                                                    1
# Bahrain                                                    6
# Bangladesh                                               252
# Barbados                                                   3
# Belarus                                                   55
# Belgium                                                  309
# Belize                                                     2
# Benin                                                      7
# Bhutan                                                     2
# Bolivia                                                   19
# Bosnia and Herzegovina                                    35
# Botswana                                                   4
# Brazil                                                   873
# Brunei Darussalam                                          1
#                                                         ...
# Switzerland                                              507
# Syrian Arab Republic                                      12
# Taiwan                                                   132
# Tajikistan                                                 3
# Thailand                                                  79
# The former Yugoslav Republic of Macedonia                 11
# Timor-Leste                                                3
# Togo                                                       3
# Trinidad and Tobago                                        5
# Tunisia                                                   47
# Turkey                                                   460
# Turkmenistan                                               8
# Uganda                                                    28
# Ukraine                                                  224
# United Arab Emirates                                      70
# United Kingdom of Great Britain and Northern Ireland    2082
# United Republic of Tanzania                               14
# United States of America                                7017
# Uruguay                                                   43
# Uzbekistan                                                35
# Venezuela, Bolivarian Republic of...                      52
# Viet Nam                                                 136
# Yemen                                                      4
# Zambia                                                     6
# Zimbabwe                                                  11
# Name: LanguageHaveWorkedWith, Length: 180, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                                     count
# Country
# United States of America                            13543  \
# India                                                6639
# Germany                                              5395
# United Kingdom of Great Britain and Northern Ir...   4190
# Canada                                               2490
# France                                               2328
# Brazil                                               2109
# Poland                                               1732
# Netherlands                                          1555
# Spain                                                1521
# Italy                                                1514
# Australia                                            1462
# Russian Federation                                   1229
# Turkey                                               1020
# Sweden                                               1020
# Switzerland                                           932
# Austria                                               833
# Israel                                                795
# Iran, Islamic Republic of...                          723
# Pakistan                                              711
# Czech Republic                                        692
# China                                                 632
# Belgium                                               626
# Bangladesh                                            613
# Ukraine                                               593
# ...                                                   ...
# Bahamas                                                 4
# Cape Verde                                              4
# Belize                                                  3
# Haiti                                                   3
# Niger                                                   3
# Chad                                                    3
# Saint Lucia                                             3
# Antigua and Barbuda                                     2
# Palau                                                   2
# Papua New Guinea                                        2
# Sierra Leone                                            2
# Gambia                                                  2
# Gabon                                                   2
# Mauritania                                              2
# Fiji                                                    2
# Liberia                                                 2
# Lesotho                                                 2
# Brunei Darussalam                                       1
# Saint Kitts and Nevis                                   1
# San Marino                                              1
# Seychelles                                              1
# Monaco                                                  1
# Solomon Islands                                         1
# Burkina Faso                                            1
# Djibouti                                                1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                              7017
# India                                                                 3081
# Germany                                                               2674
# United Kingdom of Great Britain and Northern Ir...                    2082
# Canada                                                                1272
# France                                                                1204
# Brazil                                                                 873
# Poland                                                                 810
# Netherlands                                                            714
# Spain                                                                  698
# Italy                                                                  699
# Australia                                                              705
# Russian Federation                                                     590
# Turkey                                                                 460
# Sweden                                                                 466
# Switzerland                                                            507
# Austria                                                                385
# Israel                                                                 453
# Iran, Islamic Republic of...                                           309
# Pakistan                                                               280
# Czech Republic                                                         325
# China                                                                  332
# Belgium                                                                309
# Bangladesh                                                             252
# Ukraine                                                                224
# ...                                                                    ...
# Bahamas                                                                  1
# Cape Verde                                                               1
# Belize                                                                   2
# Haiti                                                                    2
# Niger                                                                    1
# Chad                                                                     1
# Saint Lucia                                                              1
# Antigua and Barbuda                                                      0
# Palau                                                                    1
# Papua New Guinea                                                         2
# Sierra Leone                                                             0
# Gambia                                                                   1
# Gabon                                                                    0
# Mauritania                                                               1
# Fiji                                                                     2
# Liberia                                                                  1
# Lesotho                                                                  1
# Brunei Darussalam                                                        1
# Saint Kitts and Nevis                                                    1
# San Marino                                                               0
# Seychelles                                                               0
# Monaco                                                                   0
# Solomon Islands                                                          1
# Burkina Faso                                                             1
# Djibouti                                                                 0
#
# [180 rows x 2 columns]

# %%
python_df.rename(columns={'count':'cantidadRespondieron', 'LanguageHaveWorkedWith':'LosQueSabenPyhon'}, inplace=True)

# %%
python_df
# Out:
#                                                     cantidadRespondieron
# Country
# United States of America                                           13543  \
# India                                                               6639
# Germany                                                             5395
# United Kingdom of Great Britain and Northern Ir...                  4190
# Canada                                                              2490
# France                                                              2328
# Brazil                                                              2109
# Poland                                                              1732
# Netherlands                                                         1555
# Spain                                                               1521
# Italy                                                               1514
# Australia                                                           1462
# Russian Federation                                                  1229
# Turkey                                                              1020
# Sweden                                                              1020
# Switzerland                                                          932
# Austria                                                              833
# Israel                                                               795
# Iran, Islamic Republic of...                                         723
# Pakistan                                                             711
# Czech Republic                                                       692
# China                                                                632
# Belgium                                                              626
# Bangladesh                                                           613
# Ukraine                                                              593
# ...                                                                  ...
# Bahamas                                                                4
# Cape Verde                                                             4
# Belize                                                                 3
# Haiti                                                                  3
# Niger                                                                  3
# Chad                                                                   3
# Saint Lucia                                                            3
# Antigua and Barbuda                                                    2
# Palau                                                                  2
# Papua New Guinea                                                       2
# Sierra Leone                                                           2
# Gambia                                                                 2
# Gabon                                                                  2
# Mauritania                                                             2
# Fiji                                                                   2
# Liberia                                                                2
# Lesotho                                                                2
# Brunei Darussalam                                                      1
# Saint Kitts and Nevis                                                  1
# San Marino                                                             1
# Seychelles                                                             1
# Monaco                                                                 1
# Solomon Islands                                                        1
# Burkina Faso                                                           1
# Djibouti                                                               1
#
#                                                     LosQueSabenPyhon
# Country
# United States of America                                        7017
# India                                                           3081
# Germany                                                         2674
# United Kingdom of Great Britain and Northern Ir...              2082
# Canada                                                          1272
# France                                                          1204
# Brazil                                                           873
# Poland                                                           810
# Netherlands                                                      714
# Spain                                                            698
# Italy                                                            699
# Australia                                                        705
# Russian Federation                                               590
# Turkey                                                           460
# Sweden                                                           466
# Switzerland                                                      507
# Austria                                                          385
# Israel                                                           453
# Iran, Islamic Republic of...                                     309
# Pakistan                                                         280
# Czech Republic                                                   325
# China                                                            332
# Belgium                                                          309
# Bangladesh                                                       252
# Ukraine                                                          224
# ...                                                              ...
# Bahamas                                                            1
# Cape Verde                                                         1
# Belize                                                             2
# Haiti                                                              2
# Niger                                                              1
# Chad                                                               1
# Saint Lucia                                                        1
# Antigua and Barbuda                                                0
# Palau                                                              1
# Papua New Guinea                                                   2
# Sierra Leone                                                       0
# Gambia                                                             1
# Gabon                                                              0
# Mauritania                                                         1
# Fiji                                                               2
# Liberia                                                            1
# Lesotho                                                            1
# Brunei Darussalam                                                  1
# Saint Kitts and Nevis                                              1
# San Marino                                                         0
# Seychelles                                                         0
# Monaco                                                             0
# Solomon Islands                                                    1
# Burkina Faso                                                       1
# Djibouti                                                           0
#
# [180 rows x 2 columns]

# %%
python_df['PerKnowPython'] = (python_df['LosQueSabenPyhon'] / python_df['cantidadRespondieron']) * 100

python_df
# Out:
#                                                     cantidadRespondieron
# Country
# United States of America                                           13543  \
# India                                                               6639
# Germany                                                             5395
# United Kingdom of Great Britain and Northern Ir...                  4190
# Canada                                                              2490
# France                                                              2328
# Brazil                                                              2109
# Poland                                                              1732
# Netherlands                                                         1555
# Spain                                                               1521
# Italy                                                               1514
# Australia                                                           1462
# Russian Federation                                                  1229
# Turkey                                                              1020
# Sweden                                                              1020
# Switzerland                                                          932
# Austria                                                              833
# Israel                                                               795
# Iran, Islamic Republic of...                                         723
# Pakistan                                                             711
# Czech Republic                                                       692
# China                                                                632
# Belgium                                                              626
# Bangladesh                                                           613
# Ukraine                                                              593
# ...                                                                  ...
# Bahamas                                                                4
# Cape Verde                                                             4
# Belize                                                                 3
# Haiti                                                                  3
# Niger                                                                  3
# Chad                                                                   3
# Saint Lucia                                                            3
# Antigua and Barbuda                                                    2
# Palau                                                                  2
# Papua New Guinea                                                       2
# Sierra Leone                                                           2
# Gambia                                                                 2
# Gabon                                                                  2
# Mauritania                                                             2
# Fiji                                                                   2
# Liberia                                                                2
# Lesotho                                                                2
# Brunei Darussalam                                                      1
# Saint Kitts and Nevis                                                  1
# San Marino                                                             1
# Seychelles                                                             1
# Monaco                                                                 1
# Solomon Islands                                                        1
# Burkina Faso                                                           1
# Djibouti                                                               1
#
#                                                     LosQueSabenPyhon
# Country
# United States of America                                        7017  \
# India                                                           3081
# Germany                                                         2674
# United Kingdom of Great Britain and Northern Ir...              2082
# Canada                                                          1272
# France                                                          1204
# Brazil                                                           873
# Poland                                                           810
# Netherlands                                                      714
# Spain                                                            698
# Italy                                                            699
# Australia                                                        705
# Russian Federation                                               590
# Turkey                                                           460
# Sweden                                                           466
# Switzerland                                                      507
# Austria                                                          385
# Israel                                                           453
# Iran, Islamic Republic of...                                     309
# Pakistan                                                         280
# Czech Republic                                                   325
# China                                                            332
# Belgium                                                          309
# Bangladesh                                                       252
# Ukraine                                                          224
# ...                                                              ...
# Bahamas                                                            1
# Cape Verde                                                         1
# Belize                                                             2
# Haiti                                                              2
# Niger                                                              1
# Chad                                                               1
# Saint Lucia                                                        1
# Antigua and Barbuda                                                0
# Palau                                                              1
# Papua New Guinea                                                   2
# Sierra Leone                                                       0
# Gambia                                                             1
# Gabon                                                              0
# Mauritania                                                         1
# Fiji                                                               2
# Liberia                                                            1
# Lesotho                                                            1
# Brunei Darussalam                                                  1
# Saint Kitts and Nevis                                              1
# San Marino                                                         0
# Seychelles                                                         0
# Monaco                                                             0
# Solomon Islands                                                    1
# Burkina Faso                                                       1
# Djibouti                                                           0
#
#                                                     PerKnowPython
# Country
# United States of America                                51.812745
# India                                                   46.407592
# Germany                                                 49.564411
# United Kingdom of Great Britain and Northern Ir...      49.689737
# Canada                                                  51.084337
# France                                                  51.718213
# Brazil                                                  41.394026
# Poland                                                  46.766744
# Netherlands                                             45.916399
# Spain                                                   45.890861
# Italy                                                   46.169089
# Australia                                               48.221614
# Russian Federation                                      48.006509
# Turkey                                                  45.098039
# Sweden                                                  45.686275
# Switzerland                                             54.399142
# Austria                                                 46.218487
# Israel                                                  56.981132
# Iran, Islamic Republic of...                            42.738589
# Pakistan                                                39.381153
# Czech Republic                                          46.965318
# China                                                   52.531646
# Belgium                                                 49.361022
# Bangladesh                                              41.109299
# Ukraine                                                 37.774030
# ...                                                           ...
# Bahamas                                                 25.000000
# Cape Verde                                              25.000000
# Belize                                                  66.666667
# Haiti                                                   66.666667
# Niger                                                   33.333333
# Chad                                                    33.333333
# Saint Lucia                                             33.333333
# Antigua and Barbuda                                      0.000000
# Palau                                                   50.000000
# Papua New Guinea                                       100.000000
# Sierra Leone                                             0.000000
# Gambia                                                  50.000000
# Gabon                                                    0.000000
# Mauritania                                              50.000000
# Fiji                                                   100.000000
# Liberia                                                 50.000000
# Lesotho                                                 50.000000
# Brunei Darussalam                                      100.000000
# Saint Kitts and Nevis                                  100.000000
# San Marino                                               0.000000
# Seychelles                                               0.000000
# Monaco                                                   0.000000
# Solomon Islands                                        100.000000
# Burkina Faso                                           100.000000
# Djibouti                                                 0.000000
#
# [180 rows x 3 columns]

# %%
python_df.sort_values(by='PerKnowPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                            cantidadRespondieron
# Country
# Djibouti                                                      1  \
# Gabon                                                         2
# Sierra Leone                                                  2
# Monaco                                                        1
# San Marino                                                    1
# Antigua and Barbuda                                           2
# Seychelles                                                    1
# Republic of Moldova                                          37
# Somalia                                                      12
# Congo, Republic of the...                                    12
# Namibia                                                       5
# The former Yugoslav Republic of Macedonia                    51
# Bahamas                                                       4
# Cape Verde                                                    4
# Angola                                                       12
# Maldives                                                     12
# Sudan                                                        32
# Andorra                                                      15
# Tajikistan                                                   11
# Jordan                                                       64
# Yemen                                                        14
# Lithuania                                                   212
# Zambia                                                       20
# Dominican Republic                                           83
# Myanmar                                                      53
# El Salvador                                                  45
# Montenegro                                                   19
# Kyrgyzstan                                                   22
# Albania                                                      59
# Togo                                                          9
# Chad                                                          3
# Nicaragua                                                    18
# Niger                                                         3
# Saint Lucia                                                   3
# Bosnia and Herzegovina                                      103
# Syrian Arab Republic                                         35
# Argentina                                                   521
# Bulgaria                                                    364
# Serbia                                                      282
# Paraguay                                                     42
# Afghanistan                                                  69
# Mozambique                                                   11
# Zimbabwe                                                     30
# Cambodia                                                     35
# Croatia                                                     192
# Ukraine                                                     593
# Romania                                                     581
# Kosovo                                                       29
# Egypt                                                       400
# Madagascar                                                   26
#
#                                            LosQueSabenPyhon  PerKnowPython
# Country
# Djibouti                                                  0       0.000000
# Gabon                                                     0       0.000000
# Sierra Leone                                              0       0.000000
# Monaco                                                    0       0.000000
# San Marino                                                0       0.000000
# Antigua and Barbuda                                       0       0.000000
# Seychelles                                                0       0.000000
# Republic of Moldova                                       6      16.216216
# Somalia                                                   2      16.666667
# Congo, Republic of the...                                 2      16.666667
# Namibia                                                   1      20.000000
# The former Yugoslav Republic of Macedonia                11      21.568627
# Bahamas                                                   1      25.000000
# Cape Verde                                                1      25.000000
# Angola                                                    3      25.000000
# Maldives                                                  3      25.000000
# Sudan                                                     8      25.000000
# Andorra                                                   4      26.666667
# Tajikistan                                                3      27.272727
# Jordan                                                   18      28.125000
# Yemen                                                     4      28.571429
# Lithuania                                                63      29.716981
# Zambia                                                    6      30.000000
# Dominican Republic                                       25      30.120482
# Myanmar                                                  16      30.188679
# El Salvador                                              14      31.111111
# Montenegro                                                6      31.578947
# Kyrgyzstan                                                7      31.818182
# Albania                                                  19      32.203390
# Togo                                                      3      33.333333
# Chad                                                      1      33.333333
# Nicaragua                                                 6      33.333333
# Niger                                                     1      33.333333
# Saint Lucia                                               1      33.333333
# Bosnia and Herzegovina                                   35      33.980583
# Syrian Arab Republic                                     12      34.285714
# Argentina                                               180      34.548944
# Bulgaria                                                126      34.615385
# Serbia                                                  100      35.460993
# Paraguay                                                 15      35.714286
# Afghanistan                                              25      36.231884
# Mozambique                                                4      36.363636
# Zimbabwe                                                 11      36.666667
# Cambodia                                                 13      37.142857
# Croatia                                                  72      37.500000
# Ukraine                                                 224      37.774030
# Romania                                                 220      37.865749
# Kosovo                                                   11      37.931034
# Egypt                                                   152      38.000000
# Madagascar                                               10      38.461538

# %%
python_df.loc['Argentina']
# Out:
# cantidadRespondieron    521.000000
# LosQueSabenPyhon        180.000000
# PerKnowPython            34.548944
# Name: Argentina, dtype: float64

# %% [markdown]
# # --------------- END ---------------
