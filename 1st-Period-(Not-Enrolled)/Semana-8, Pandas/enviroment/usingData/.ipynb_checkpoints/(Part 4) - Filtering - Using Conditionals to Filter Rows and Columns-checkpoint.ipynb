# %%
people = {
"first": ["Corey","Jane","Jhon"],
"last": ["Schafer","Doe","Doe"],
"email": ["CoreyMSchager@gmail.com","loco@gamil.com","lineal@gmail.com"],
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 1   Jane      Doe           loco@gamil.com
# 2   Jhon      Doe         lineal@gmail.com

# %%
filt = (df['last'] == 'Schafer') | (df['first'] == 'Jhon')

# %%
# df[filt]
df.loc[-filt, 'email']
# Out:
# 1    loco@gamil.com
# Name: email, dtype: object

# %% [markdown]
# # Second part working with overflow data
# ## Filtering data

# %%
dfs = pd.read_csv('../data/survey_results_public.csv')
schema_dfs = pd.read_csv('../data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows', 79)

# %%
dfs.head()
# Out:
#    ResponseId                                         MainBranch
# 0           1                                      None of these  \
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork
# 0                  NaN                                   NaN  \
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities
# 0                                       NaN  \
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
high_salary = (dfs["CompTotal"] > 90000) & (dfs['Country'] == 'United States of America')

# %%
dfs.loc[high_salary, ['CompTotal','Country', 'CompFreq']]
# Out:
#        CompTotal                   Country CompFreq
# 11      194400.0  United States of America   Yearly
# 14      110000.0  United States of America   Yearly
# 26      106960.0  United States of America   Yearly
# 28      130000.0  United States of America   Yearly
# 31      102000.0  United States of America   Yearly
# ...          ...                       ...      ...
# 73223   200000.0  United States of America   Weekly
# 73226   130000.0  United States of America   Yearly
# 73229   325000.0  United States of America   Yearly
# 73254   115000.0  United States of America   Yearly
# 73264   107000.0  United States of America   Yearly
#
# [7082 rows x 3 columns]

# %%
filt = dfs['LanguageHaveWorkedWith'].str.contains('Python', na=False)
dfs.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 6            C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 11       C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 14             HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 16                                    C#;Java;PHP;Python;R
#                                ...
# 73257                                         C;Python;SQL
# 73261    Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# Name: LanguageHaveWorkedWith, Length: 34155, dtype: object

# %%
filt
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 73263     True
# 73264     True
# 73265     True
# 73266    False
# 73267    False
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: bool

# %%
dfs.loc[filt]
# Out:
#        ResponseId                                         MainBranch
# 2               3  I am not primarily a developer, but I write co...  \
# 6               7                        I code primarily as a hobby
# 11             12  I am not primarily a developer, but I write co...
# 14             15                     I am a developer by profession
# 16             17                     I am a developer by profession
# ...           ...                                                ...
# 73257       73258                              I am learning to code
# 73261       73262                     I am a developer by profession
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
#
#                                               Employment
# 2                                    Employed, full-time  \
# ...
