# %% [markdown]
# # (5): Updating Rows and Columns - Modifying Data Within DataFrames
#
# ##### In this Python Programming, we will be learning how to modify the data within our DataFrames. We will use some of the filtering techniques we learned in the last video to update values conditionally, and we will also be learning how to use the apply, map, and applymap method. Let's get started...

# %%
people = {
"first": ["Corey","Jane","Jhon"],
"last": ["Schafer","Doe","Doe"],
"email": ["CoreyMSchager@gmail.com","loco@gamil.com","lineal@gmail.com"],
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 1   Jane      Doe           loco@gamil.com
# 2   Jhon      Doe         lineal@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns = ['first_name', 'last_name', 'email']

# %%
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchager@gmail.com
# 1       Jane       Doe           loco@gamil.com
# 2       Jhon       Doe         lineal@gmail.com

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchager@gmail.com
# 1       Jane       Doe           loco@gamil.com
# 2       Jhon       Doe         lineal@gmail.com

# %%
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchager@gmail.com
# 1       Jane       Doe           loco@gamil.com
# 2       Jhon       Doe         lineal@gmail.com

# %%
df.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace=True)

# %%
df.loc[2] = ['Imanol', 'Aguer','Imanolaguer1@gmail.com']
df
# Out:
#     first     last                    email
# 0   Corey  Schafer  CoreyMSchager@gmail.com
# 1    Jane      Doe           loco@gamil.com
# 2  Imanol    Aguer   Imanolaguer1@gmail.com

# %%
df.loc[2, ['last','email']] = ['Doe', 'lineal@gmail.com']
df
# Out:
#     first     last                    email
# 0   Corey  Schafer  CoreyMSchager@gmail.com
# 1    Jane      Doe           loco@gamil.com
# 2  Imanol      Doe         lineal@gmail.com

# %%
# This is a Common error  when try to change data
filt = (df['email'] == 'lineal@gmail.com')
df[filt]['last'] = 'Smith'
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6984\2106777164.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filt]['last'] = 'Smith'

# %%
# Asi se soluciona... con la manera correcta de modificar data en el dataframe
filt = (df['email'] == 'lineal@gmail.com')
df.loc[filt, 'last'] = 'Pnachito'

# %%
df['email'] = df['email'].str.lower()
df
# Out:
#     first      last                    email
# 0   Corey   Schafer  coreymschager@gmail.com
# 1    Jane       Doe           loco@gamil.com
# 2  Imanol  Pnachito         lineal@gmail.com

# %% [markdown]
# ### Recuerda estos metodos
# 1- apply 2-map  3-applymap 4-replace

# %% [markdown]
# ## apply method

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    14
# 2    16
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'] = df['email'].apply(update_email)
# df

# %%
df['email'] = df['email'].apply(lambda x: x.lower()) # Esta es una funcion lambda dentro del apply
df
# Out:
#     first      last                    email
# 0   Corey   Schafer  coreymschager@gmail.com
# 1    Jane       Doe           loco@gamil.com
# 2  Imanol  Pnachito         lineal@gmail.com

# %%
df.apply(len) # <--- te dara la cantidad de rows en cada columna
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    coreymschager@gmail.com
# dtype: object

# %% [markdown]
# ### applymap method

# %%
df.applymap(len) # <---- te dara len() de cada elemento individual del DataFrame
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     14
# 2      6     8     16

# %%
df.applymap(str.upper)
# Out:
#     first      last                    email
# 0   COREY   SCHAFER  COREYMSCHAGER@GMAIL.COM
# 1    JANE       DOE           LOCO@GAMIL.COM
# 2  IMANOL  PNACHITO         LINEAL@GMAIL.COM

# %% [markdown]
# ### map method

# %%
df['first'].map({'Corey': 'Chris','Jane': 'Mary'}) #atencion: no pone los cambios pernanentes
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df['first'] = df['first'].replace({'Corey': 'Chris','Jane': 'Mary'}) #Atencion: aqui si los cambios quedan
df
# Out:
#     first      last                    email
# 0   Chris   Schafer  coreymschager@gmail.com
# 1    Mary       Doe           loco@gamil.com
# 2  Imanol  Pnachito         lineal@gmail.com

# %% [markdown]
# # Working with Stackoverflow Data

# %%
dfs = pd.read_csv('../data/survey_results_public.csv')
schema_dfs = pd.read_csv('../data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows', 20)
pd.set_option('display.min_rows', 20)

# %%
dfs.head(20)
# Out:
#     ResponseId                                         MainBranch
# 0            1                                      None of these  \
# 1            2                     I am a developer by profession
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6  I am not primarily a developer, but I write co...
# 6            7                        I code primarily as a hobby
# 7            8                     I am a developer by profession
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12  I am not primarily a developer, but I write co...
# 12          13                     I am a developer by profession
# 13          14                     I am a developer by profession
# 14          15                     I am a developer by profession
# 15          16                     I am a developer by profession
# 16          17                     I am a developer by profession
# 17          18                     I am a developer by profession
# 18          19                     I am a developer by profession
# 19          20                              I am learning to code
#
#                                            Employment
# 0                                                 NaN  \
# 1                                 Employed, full-time
# 2                                 Employed, full-time
# 3                                 Employed, full-time
# 4                                 Employed, full-time
# 5                                  Student, full-time
# 6                                  Student, part-time
# 7                  Not employed, but looking for work
# 8                                 Employed, full-time
# 9   Independent contractor, freelancer, or self-em...
# 10                                Employed, full-time
# 11  Employed, full-time;Independent contractor, fr...
# 12                                Employed, full-time
# 13                                Employed, part-time
# 14  Employed, full-time;Independent contractor, fr...
# 15  Independent contractor, freelancer, or self-em...
# 16                                Employed, full-time
# 17                                Employed, full-time
# 18                                Employed, full-time
# 19                                 Student, full-time
#
#                               RemoteWork
# 0                                    NaN  \
# 1                           Fully remote
# 2   Hybrid (some remote, some in-person)
# 3                           Fully remote
# 4   Hybrid (some remote, some in-person)
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8   Hybrid (some remote, some in-person)
# 9                           Fully remote
# 10  Hybrid (some remote, some in-person)
# 11                          Fully remote
# 12  Hybrid (some remote, some in-person)
# 13                          Fully remote
# 14                          Fully remote
# 15                          Fully remote
# 16  Hybrid (some remote, some in-person)
# 17                          Fully remote
# 18  Hybrid (some remote, some in-person)
# 19                                   NaN
#
#                                      CodingActivities
# 0                                                 NaN  \
# 1            Hobby;Contribute to open-source projects
# 2                                               Hobby
# 3                        I don’t code outside of work
# 4                                               Hobby
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                        I don’t code outside of work
# 9   Hobby;Contribute to open-source projects;Boots...
# 10                       I don’t code outside of work
# 11  Hobby;Contribute to open-source projects;Freel...
# 12                                              Hobby
# 13                                              Hobby
# 14                      Hobby;Freelance/contract work
# 15           Hobby;Contribute to open-source projects
# 16                                              Hobby
# 17                                              Hobby
# 18                                              Hobby
# 19                                                NaN
#
#                                               EdLevel
# 0                                                 NaN  \
# 1                                                 NaN
# 2     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6   Secondary school (e.g. American high school, G...
# 7   Some college/university study without earning ...
# 8     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9   Some college/university study without earning ...
# 10       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 14    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 15       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 16       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 18  Secondary school (e.g. American high school, G...
# 19  Some college/university study without earning ...
#
#                                             LearnCode
# 0                                                 NaN  \
# 1                                                 NaN
# 2   Books / Physical media;Friend or family member...
# 3   Books / Physical media;School (i.e., Universit...
# 4   Other online resources (e.g., videos, blogs, f...
# 5   Books / Physical media;School (i.e., Universit...
# 6   Other online resources (e.g., videos, blogs, f...
# 7                     Online Courses or Certification
# 8                 On the job training;Coding Bootcamp
# 9   Books / Physical media;Other online resources ...
# 10  Books / Physical media;Friend or family member...
# 11  Other online resources (e.g., videos, blogs, f...
# 12            School (i.e., University, College, etc)
# 13  Books / Physical media;School (i.e., Universit...
# 14  Other online resources (e.g., videos, blogs, f...
# 15                             Books / Physical media
# 16  Books / Physical media;Other online resources ...
# 17  Other online resources (e.g., videos, blogs, f...
# 18  Books / Physical media;School (i.e., Universit...
# 19   Books / Physical media;Coding Bootcamp;Colleague
#
#                                       LearnCodeOnline  LearnCodeCoursesCert
# 0                                                 NaN                   NaN  \
# 1                                                 NaN                   NaN
# 2   Technical documentation;Blogs;Programming Game...                   NaN
# 3                                                 NaN                   NaN
# 4   Technical documentation;Blogs;Stack Overflow;O...                   NaN
# 5                                                 NaN                   NaN
# 6           Stack Overflow;Video-based Online Courses                   NaN
# 7                                                 NaN        Coursera;Udemy
# 8                                                 NaN                   NaN
# 9   Technical documentation;Blogs;Written Tutorial...                   NaN
# 10  Technical documentation;Blogs;Written Tutorial...                   NaN
# 11  Technical documentation;Blogs;Written Tutorial...                   NaN
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14  Written Tutorials;Stack Overflow;Video-based O...                   NaN
# 15                                                NaN                   NaN
# 16  Technical documentation;Blogs;Written Tutorial...      Udemy;Codecademy
# 17  Technical documentation;Written Tutorials;Stac...  Coursera;Pluralsight
# 18                                                NaN                   NaN
# 19                                                NaN                   NaN
#
#    YearsCode YearsCodePro                                            DevType
# 0        NaN          NaN                                                NaN  \
# 1        NaN          NaN                                                NaN
# 2         14            5  Data scientist or machine learning specialist;...
# 3         20           17                              Developer, full-stack
# 4          8            3  Developer, front-end;Developer, full-stack;Dev...
# 5         15          NaN                                                NaN
# 6          3          NaN                                                NaN
# 7          1          NaN                      Developer, full-stack;Student
# 8          6            6                                Developer, back-end
# 9         37           30  Developer, desktop or enterprise applications;...
# 10         5            2          Developer, full-stack;Developer, back-end
# 11        12           10                                Engineering manager
# 12        12            5                              Developer, full-stack
# 13        22           15  Developer, front-end;Developer, full-stack;Dev...
# 14        11            5  Developer, full-stack;Academic researcher;DevO...
# 15         4            4                              Developer, full-stack
# 16         7            4                              Developer, full-stack
# 17        13           10                                     Engineer, data
# 18        36           22  Developer, back-end;Developer, desktop or ente...
# 19         2          NaN                                                NaN
#
#                                               OrgSize
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                  20 to 99 employees
# 3                                100 to 499 employees
# 4                                  20 to 99 employees
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                        I don’t know
# 9   Just me - I am a freelancer, sole proprietor, ...
# 10                               100 to 499 employees
# 11                                 20 to 99 employees
# 12                                   2 to 9 employees
# 13                                 20 to 99 employees
# 14                           5,000 to 9,999 employees
# 15  Just me - I am a freelancer, sole proprietor, ...
# 16                                   2 to 9 employees
# 17                           1,000 to 4,999 employees
# 18                               100 to 499 employees
# 19                                                NaN
#
#                    PurchaseInfluence
# 0                                NaN  \
# 1                                NaN
# 2              I have some influence
# 3              I have some influence
# 4              I have some influence
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8      I have little or no influence
# 9   I have a great deal of influence
# 10     I have little or no influence
# 11             I have some influence
# 12  I have a great deal of influence
# 13             I have some influence
# 14     I have little or no influence
# 15  I have a great deal of influence
# 16             I have some influence
# 17             I have some influence
# 18     I have little or no influence
# 19                               NaN
#
#                                            BuyNewTool
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                             Other (please specify):
# 4   Start a free trial;Visit developer communities...
# 5                             Other (please specify):
# 6   Start a free trial;Visit developer communities...
# 7                                  Start a free trial
# 8                                                 NaN
# 9   Start a free trial;Ask developers I know/work ...
# 10  Start a free trial;Visit developer communities...
# 11  Start a free trial;Ask developers I know/work ...
# 12    Visit developer communities like Stack Overflow
# 13  Start a free trial;Ask developers I know/work ...
# 14  Start a free trial;Visit developer communities...
# 15                                 Start a free trial
# 16  Start a free trial;Research companies that hav...
# 17  Start a free trial;Ask developers I know/work ...
# 18  Start a free trial;Visit developer communities...
# 19  Visit developer communities like Stack Overflo...
#
#                                               Country
# 0                                                 NaN  \
# 1                                              Canada
# 2   United Kingdom of Great Britain and Northern I...
# 3                                              Israel
# 4                            United States of America
# 5                                             Germany
# 6                                               India
# 7                                               India
# 8                                         Netherlands
# 9                                             Croatia
# 10  United Kingdom of Great Britain and Northern I...
# 11                           United States of America
# 12                           United States of America
# 13                                          Australia
# 14                           United States of America
# 15                                 Russian Federation
# 16                                     Czech Republic
# 17                                            Austria
# 18                                            Austria
# 19                                             Serbia
#
#                 LocalCurrency  CompTotal CompFreq
# 0                         NaN        NaN      NaN  \
# 1        CAD\tCanadian dollar        NaN      NaN
# 2         GBP\tPound sterling    32000.0   Yearly
# 3     ILS\tIsraeli new shekel    60000.0  Monthly
# 4   USD\tUnited States dollar        NaN      NaN
# 5                         NaN        NaN      NaN
# 6                         NaN        NaN      NaN
# 7                         NaN        NaN      NaN
# 8           EUR European Euro    46000.0   Yearly
# 9          HRK\tCroatian kuna        NaN      NaN
# 10        GBP\tPound sterling    48000.0   Yearly
# 11  USD\tUnited States dollar   194400.0   Yearly
# 12  USD\tUnited States dollar    65000.0   Yearly
# 13     AUD\tAustralian dollar        NaN      NaN
# 14  USD\tUnited States dollar   110000.0   Yearly
# 15         RUB\tRussian ruble        NaN   Weekly
# 16          CZK\tCzech koruna    37000.0  Monthly
# 17          EUR European Euro   190000.0   Yearly
# 18          EUR European Euro     4000.0  Monthly
# 19                        NaN        NaN      NaN
#
#                                LanguageHaveWorkedWith
# 0                                                 NaN  \
# 1                               JavaScript;TypeScript
# 2                   C#;C++;HTML/CSS;JavaScript;Python
# 3                        C#;JavaScript;SQL;TypeScript
# 4         C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# 5                                             C++;Lua
# 6       C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 7                  C;C++;HTML/CSS;Java;JavaScript;SQL
# 8                                                 NaN
# 9                                   Delphi;Java;Swift
# 10   Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;SQL
# 11  C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 12               C;HTML/CSS;Rust;SQL;Swift;TypeScript
# 13  Elixir;Erlang;HTML/CSS;JavaScript;Ruby;SQL;Typ...
# 14        HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 15      Bash/Shell;HTML/CSS;JavaScript;SQL;TypeScript
# 16                               C#;Java;PHP;Python;R
# 17                                         Python;SQL
# 18                                  C#;PowerShell;SQL
# 19                C++;HTML/CSS;Java;JavaScript;Python
#
#                                LanguageWantToWorkWith
# 0                                                 NaN  \
# 1                                     Rust;TypeScript
# 2               C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                                   C#;SQL;TypeScript
# 4          C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# 5                                                 Lua
# 6   C;C#;C++;Elixir;Go;HTML/CSS;Java;JavaScript;Ko...
# 7                 APL;Bash/Shell;Go;Python;TypeScript
# 8                                                 NaN
# 9                                   Delphi;Java;Swift
# 10                                   C#;Go;JavaScript
# 11     C++;Go;HTML/CSS;JavaScript;Lua;Rust;TypeScript
# 12                        Haskell;HTML/CSS;Rust;Swift
# 13  Elixir;Erlang;HTML/CSS;JavaScript;Ruby;SQL;Typ...
# 14                   HTML/CSS;JavaScript;Python;Scala
# 15                 Bash/Shell;HTML/CSS;SQL;TypeScript
# 16    JavaScript;Kotlin;PowerShell;SQL;TypeScript;VBA
# 17                                         Python;SQL
# 18                               C#;F#;PowerShell;SQL
# 19                                HTML/CSS;Python;SQL
#
#                                DatabaseHaveWorkedWith
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                Microsoft SQL Server
# 3                                Microsoft SQL Server
# 4   Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# 5                                                 NaN
# 6   Cloud Firestore;MongoDB;Firebase Realtime Data...
# 7                                       MongoDB;MySQL
# 8                                                 NaN
# 9                                                 NaN
# 10                               Microsoft SQL Server
# 11  Couchbase;CouchDB;Microsoft SQL Server;MongoDB...
# 12                                         PostgreSQL
# 13                                DynamoDB;PostgreSQL
# 14             Elasticsearch;MongoDB;Neo4j;PostgreSQL
# 15  Cloud Firestore;Microsoft SQL Server;MongoDB;M...
# 16                                Elasticsearch;MySQL
# 17                               Cassandra;PostgreSQL
# 18                               Microsoft SQL Server
# 19                                              MySQL
#
#                                DatabaseWantToWorkWith
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                Microsoft SQL Server
# 3                                Microsoft SQL Server
# 4   Cloud Firestore;Elasticsearch;Firebase Realtim...
# 5                                                 NaN
# 6                             MySQL;Oracle;PostgreSQL
# 7                                    Neo4j;PostgreSQL
# 8                                                 NaN
# 9                                                 NaN
# 10                               Microsoft SQL Server
# 11                 Elasticsearch;MongoDB;Redis;SQLite
# 12                                Elasticsearch;Redis
# 13                                         PostgreSQL
# 14             Elasticsearch;MongoDB;Neo4j;PostgreSQL
# 15  Cloud Firestore;Microsoft SQL Server;MongoDB;M...
# 16                   MariaDB;MongoDB;MySQL;PostgreSQL
# 17                               Cassandra;PostgreSQL
# 18                               Microsoft SQL Server
# 19                                              MySQL
#
#               PlatformHaveWorkedWith
# 0                                NaN  \
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4           Firebase;Microsoft Azure
# 5                                NaN
# 6                                NaN
# 7            AWS;Google Cloud;Heroku
# 8                                NaN
# 9              DigitalOcean;Firebase
# 10               AWS;Microsoft Azure
# 11               AWS;Microsoft Azure
# 12                               AWS
# 13                        AWS;Heroku
# 14           AWS;DigitalOcean;Heroku
# 15  AWS;Firebase;Google Cloud;Heroku
# 16               Google Cloud;VMware
# 17                  AWS;Google Cloud
# 18                               NaN
# 19                               NaN
#
#                           PlatformWantToWorkWith
# 0                                            NaN  \
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                       Firebase;Microsoft Azure
# 5                                            NaN
# 6                                            NaN
# 7   DigitalOcean;Firebase;Microsoft Azure;VMware
# 8                                            NaN
# 9                          DigitalOcean;Firebase
# 10                               Microsoft Azure
# 11              AWS;DigitalOcean;Firebase;Linode
# 12                                           AWS
# 13                                           NaN
# 14                                           AWS
# 15              AWS;Firebase;Google Cloud;Heroku
# 16                                           AWS
# 17                              AWS;Google Cloud
# 18                                           NaN
# 19                                           NaN
#
#                                WebframeHaveWorkedWith
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                          Angular.js
# 3                               ASP.NET;ASP.NET Core
# 4        Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# 5                                                 NaN
# 6      Angular;Next.js;Node.js;React.js;Svelte;Vue.js
# 7                                      jQuery;Node.js
# 8                                                 NaN
# 9                                                 NaN
# 10                       ASP.NET;ASP.NET Core ;Vue.js
# 11       ASP.NET;ASP.NET Core ;Express;Node.js;Vue.js
# 12                                           React.js
# 13  jQuery;Next.js;Node.js;Phoenix;React.js;Ruby o...
# 14   Django;Flask;jQuery;Node.js;Ruby on Rails;Vue.js
# 15                      Express;jQuery;Node.js;Vue.js
# 16            Angular;Laravel;Node.js;React.js;Vue.js
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                WebframeWantToWorkWith
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                  Angular;Angular.js
# 3                               ASP.NET;ASP.NET Core
# 4                Angular;ASP.NET Core ;Blazor;Node.js
# 5                                                 NaN
# 6   Django;Flask;Gatsby;jQuery;Next.js;Node.js;Rea...
# 7                   Angular;Angular.js;Next.js;Vue.js
# 8                                                 NaN
# 9                                                 NaN
# 10                       ASP.NET;ASP.NET Core ;Blazor
# 11      ASP.NET Core ;Node.js;Nuxt.js;React.js;Vue.js
# 12                                           React.js
# 13              Phoenix;React.js;Ruby on Rails;Svelte
# 14                     Django;FastAPI;React.js;Vue.js
# 15                             Express;Node.js;Vue.js
# 16  Angular;Next.js;Node.js;Nuxt.js;React.js;Symfo...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                MiscTechHaveWorkedWith
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                              Pandas
# 3                                                .NET
# 4                                                .NET
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                               .NET
# 11  .NET;Keras;NumPy;Pandas;Scikit-learn;TensorFlo...
# 12                                      Torch/PyTorch
# 13                                                NaN
# 14   Apache Kafka;Apache Spark;NumPy;Pandas;Tidyverse
# 15                                                NaN
# 16                              Electron;React Native
# 17                                                NaN
# 18                                               .NET
# 19  Keras;NumPy;Pandas;Scikit-learn;Spring;TensorFlow
#
#                                MiscTechWantToWorkWith
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                .NET
# 3                                                .NET
# 4                                   .NET;Apache Kafka
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 12                                      Torch/PyTorch
# 13                                                NaN
# 14                                             Pandas
# 15                                                NaN
# 16                                           Electron
# 17                                                NaN
# 18                                               .NET
# 19         Keras;NumPy;Pandas;Scikit-learn;TensorFlow
#
#        ToolsTechHaveWorkedWith                      ToolsTechWantToWorkWith
# 0                          NaN                                          NaN  \
# 1                          NaN                                          NaN
# 2                          NaN                                          NaN
# 3                          NaN                                          NaN
# 4                          npm                            Docker;Kubernetes
# 5                     Homebrew                                     Homebrew
# 6                 Homebrew;npm                                          npm
# 7                          npm                                Unity 3D;Yarn
# 8                          NaN                                          NaN
# 9                          NaN                                          NaN
# 10        Docker;npm;Terraform                             Docker;Terraform
# 11  Docker;Homebrew;Kubernetes  Docker;Homebrew;Kubernetes;Pulumi;Terraform
# 12                      Docker                                       Docker
# 13    Docker;Homebrew;npm;Yarn                                  Docker;Yarn
# 14             Docker;npm;Yarn                              Docker;npm;Yarn
# 15                         npm                                          npm
# 16                  Docker;npm                                   Docker;npm
# 17  Docker;Homebrew;Kubernetes         Docker;Homebrew;Kubernetes;Terraform
# 18                         NaN                                          NaN
# 19                         NaN                                          NaN
#
#                          NEWCollabToolsHaveWorkedWith
# 0                                                 NaN  \
# 1                                                 NaN
# 2                             Notepad++;Visual Studio
# 3          Notepad++;Visual Studio;Visual Studio Code
# 4    Notepad++;Visual Studio;Visual Studio Code;Xcode
# 5                            Visual Studio Code;Xcode
# 6   Atom;IntelliJ;Notepad++;PyCharm;Sublime Text;V...
# 7   Atom;CLion;Eclipse;IntelliJ;Notepad++;Visual S...
# 8                                     Emacs;Notepad++
# 9   Android Studio;RAD Studio (Delphi, C++ Builder...
# 10             Rider;Visual Studio;Visual Studio Code
# 11  IPython/Jupyter;Neovim;Visual Studio;Visual St...
# 12                                  Vim;Visual Studio
# 13                                 Visual Studio Code
# 14    IPython/Jupyter;Nano;RStudio;Visual Studio Code
# 15                       Notepad++;Visual Studio Code
# 16              IntelliJ;Notepad++;Visual Studio Code
# 17                                 Visual Studio Code
# 18                   Visual Studio;Visual Studio Code
# 19                        IntelliJ;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith
# 0                                                 NaN  \
# 1                                                 NaN
# 2                             Notepad++;Visual Studio
# 3          Notepad++;Visual Studio;Visual Studio Code
# 4              Rider;Visual Studio;Visual Studio Code
# 5                                  Visual Studio Code
# 6                         Visual Studio Code;Webstorm
# 7   Android Studio;IPython/Jupyter;Sublime Text;Vi...
# 8                                     Emacs;Notepad++
# 9   Android Studio;RAD Studio (Delphi, C++ Builder...
# 10                           Rider;Visual Studio Code
# 11          IPython/Jupyter;Neovim;Visual Studio Code
# 12                                  Vim;Visual Studio
# 13                                 Visual Studio Code
# 14                                 Visual Studio Code
# 15                                 Visual Studio Code
# 16                                 IntelliJ;Notepad++
# 17                         PyCharm;Visual Studio Code
# 18                   Visual Studio;Visual Studio Code
# 19                                 Visual Studio Code
#
#                         OpSysProfessional use
# 0                                         NaN  \
# 1                                       macOS
# 2                                     Windows
# 3                                     Windows
# 4                                     Windows
# 5                           Linux-based;macOS
# 6                                       macOS
# 7                           Linux-based;macOS
# 8                                     Windows
# 9                                     Windows
# 10  Windows;Windows Subsystem for Linux (WSL)
# 11                  Linux-based;macOS;Windows
# 12                                      macOS
# 13                                      macOS
# 14                                      macOS
# 15                                    Windows
# 16                                    Windows
# 17                                      macOS
# 18                                    Windows
# 19                        Linux-based;Windows
#
#                             OpSysPersonal use         VersionControlSystem
# 0                                         NaN                          NaN  \
# 1           Windows Subsystem for Linux (WSL)                          Git
# 2                                     Windows                          Git
# 3                                     Windows                          Git
# 4                               macOS;Windows  Git;Other (please specify):
# 5                                       macOS                          Git
# 6                                       macOS                          Git
# 7                                     Windows                          Git
# 8                                     Windows                          Git
# 9                                     Windows                          Git
# 10                                Linux-based                          Git
# 11                          Linux-based;macOS                          Git
# 12                                Linux-based                          Git
# 13                                      macOS                          Git
# 14                                      macOS                          Git
# 15                                    Windows                          Git
# 16                                    Windows                          Git
# 17  Windows;Windows Subsystem for Linux (WSL)                          Git
# 18                                    Windows                Mercurial;SVN
# 19                        Linux-based;Windows                          Git
#
#                                         VCInteraction  VCHostingPersonal use
# 0                                                 NaN                    NaN  \
# 1                                                 NaN                    NaN
# 2                                         Code editor                    NaN
# 3   Code editor;Command-line;Version control hosti...                    NaN
# 4                                         Code editor                    NaN
# 5   Command-line;Version control hosting service w...                    NaN
# 6                            Code editor;Command-line                    NaN
# 7                                        Command-line                    NaN
# 8   Command-line;Dedicated version control GUI app...                    NaN
# 9   Version control hosting service web GUI;Dedica...                    NaN
# 10                           Code editor;Command-line                    NaN
# 11  Code editor;Dedicated version control GUI appl...                    NaN
# 12                           Code editor;Command-line                    NaN
# 13                                       Command-line                    NaN
# 14  Code editor;Command-line;Version control hosti...                    NaN
# 15                           Code editor;Command-line                    NaN
# 16  Command-line;Dedicated version control GUI app...                    NaN
# 17                                       Command-line                    NaN
# 18  Code editor;Command-line;Dedicated version con...                    NaN
# 19                           Code editor;Command-line                    NaN
#
#     VCHostingProfessional use
# 0                         NaN  \
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
#
#                        OfficeStackAsyncHaveWorkedWith
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                         Jira Work Management;Trello
# 4                                                 NaN
# 5                                          Confluence
# 6                                                 NaN
# 7                                                 NaN
# 8                     Confluence;Jira Work Management
# 9                                                 NaN
# 10                                         Confluence
# 11      Confluence;Jira Work Management;Notion;Trello
# 12                        Jira Work Management;Trello
# 13  Airtable;Confluence;Jira Work Management;Notio...
# 14                  Asana;Jira Work Management;Trello
# 15                                             Trello
# 16                        Jira Work Management;Trello
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#        OfficeStackAsyncWantToWorkWith
# 0                                 NaN  \
# 1                                 NaN
# 2                                 NaN
# 3         Jira Work Management;Trello
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8     Confluence;Jira Work Management
# 9                                 NaN
# 10                                NaN
# 11                      Notion;Trello
# 12        Jira Work Management;Trello
# 13                             Notion
# 14  Asana;Jira Work Management;Trello
# 15                             Trello
# 16               Jira Work Management
# 17                                NaN
# 18                                NaN
# 19                                NaN
#
#                         OfficeStackSyncHaveWorkedWith
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                     Microsoft Teams
# 3                                          Slack;Zoom
# 4                                Microsoft Teams;Zoom
# 5                               Rocketchat;Slack;Zoom
# 6              Google Chat;Microsoft Teams;Slack;Zoom
# 7                    Google Chat;Microsoft Teams;Zoom
# 8                                     Microsoft Teams
# 9                                   Google Chat;Slack
# 10             Google Chat;Microsoft Teams;Slack;Zoom
# 11  Cisco Webex Teams;Google Chat;Microsoft Teams;...
# 12                         Microsoft Teams;Slack;Zoom
# 13                         Microsoft Teams;Slack;Zoom
# 14                         Microsoft Teams;Slack;Zoom
# 15                                                NaN
# 16                              Microsoft Teams;Slack
# 17                                         Slack;Zoom
# 18                               Microsoft Teams;Zoom
# 19                                                NaN
#
#    OfficeStackSyncWantToWorkWith        Blockchain
# 0                            NaN               NaN  \
# 1                            NaN  Very unfavorable
# 2                Microsoft Teams  Very unfavorable
# 3                     Slack;Zoom  Very unfavorable
# 4                            NaN       Unfavorable
# 5          Rocketchat;Slack;Zoom  Very unfavorable
# 6         Google Chat;Slack;Zoom         Favorable
# 7                            NaN    Very favorable
# 8                Microsoft Teams  Very unfavorable
# 9              Google Chat;Slack  Very unfavorable
# 10             Google Chat;Slack       Unfavorable
# 11                         Slack       Unfavorable
# 12         Microsoft Teams;Slack         Favorable
# 13                    Slack;Zoom  Very unfavorable
# 14                    Slack;Zoom       Indifferent
# 15                           NaN       Unfavorable
# 16         Microsoft Teams;Slack       Unfavorable
# 17                    Slack;Zoom       Indifferent
# 18               Microsoft Teams            Unsure
# 19                           NaN       Indifferent
#
#                                            NEWSOSites
# 0                                                 NaN  \
# 1   Collectives on Stack Overflow;Stack Overflow f...
# 2   Collectives on Stack Overflow;Stack Overflow;S...
# 3   Collectives on Stack Overflow;Stack Overflow f...
# 4   Collectives on Stack Overflow;Stack Overflow f...
# 5                       Stack Overflow;Stack Exchange
# 6                                      Stack Overflow
# 7   Collectives on Stack Overflow;Stack Overflow;S...
# 8   Stack Overflow for Teams (private knowledge sh...
# 9   Collectives on Stack Overflow;Stack Overflow;S...
# 10                      Stack Overflow;Stack Exchange
# 11                      Stack Overflow;Stack Exchange
# 12                      Stack Overflow;Stack Exchange
# 13                      Stack Overflow;Stack Exchange
# 14                      Stack Overflow;Stack Exchange
# 15                      Stack Overflow;Stack Exchange
# 16                      Stack Overflow;Stack Exchange
# 17  Stack Overflow for Teams (private knowledge sh...
# 18                      Stack Overflow;Stack Exchange
# 19                                     Stack Overflow
#
#                         SOVisitFreq                SOAccount
# 0                               NaN                      NaN  \
# 1             Daily or almost daily                      Yes
# 2            Multiple times per day                      Yes
# 3             Daily or almost daily                      Yes
# 4            Multiple times per day                      Yes
# 5            Multiple times per day                      Yes
# 6            Multiple times per day                      Yes
# 7              A few times per week                      Yes
# 8   A few times per month or weekly                      Yes
# 9            Multiple times per day                      Yes
# 10  A few times per month or weekly                      Yes
# 11            Daily or almost daily                      Yes
# 12            Daily or almost daily  Not sure/can't remember
# 13           Multiple times per day                      Yes
# 14            Daily or almost daily                      Yes
# 15           Multiple times per day                      Yes
# 16            Daily or almost daily                      Yes
# 17            Daily or almost daily                      Yes
# 18           Multiple times per day                      Yes
# 19            Daily or almost daily                       No
#
#                                            SOPartFreq           SOComm
# 0                                                 NaN              NaN  \
# 1                               Daily or almost daily         Not sure
# 2                              Multiple times per day          Neutral
# 3                                A few times per week  Yes, definitely
# 4                               Daily or almost daily  Yes, definitely
# 5                              Multiple times per day  Yes, definitely
# 6                               Daily or almost daily  Yes, definitely
# 7   I have never participated in Q&A on Stack Over...  Yes, definitely
# 8                 Less than once per month or monthly   No, not at all
# 9                              Multiple times per day  Yes, definitely
# 10                Less than once per month or monthly   No, not really
# 11                    A few times per month or weekly    Yes, somewhat
# 12                                                NaN          Neutral
# 13                              Daily or almost daily  Yes, definitely
# 14                Less than once per month or monthly    Yes, somewhat
# 15                             Multiple times per day  Yes, definitely
# 16                    A few times per month or weekly          Neutral
# 17                Less than once per month or monthly  Yes, definitely
# 18                              Daily or almost daily  Yes, definitely
# 19                                                NaN   No, not really
#
#                    Age                  Gender                   Trans
# 0                  NaN                     NaN                     NaN  \
# 1                  NaN                     NaN                     NaN
# 2      25-34 years old                     Man                      No
# 3      35-44 years old                     Man                      No
# 4      25-34 years old                     NaN                     NaN
# 5      25-34 years old  Or, in your own words:  Or, in your own words:
# 6   Under 18 years old                     Man                      No
# 7      18-24 years old                     Man                      No
# 8      25-34 years old                   Woman                      No
# 9      45-54 years old                   Woman                      No
# 10     18-24 years old                     Man                      No
# 11     35-44 years old                     Man                      No
# 12     25-34 years old                     Man                      No
# 13     35-44 years old                   Woman                      No
# 14     25-34 years old                     Man                      No
# 15     25-34 years old                     Man                      No
# 16     25-34 years old                     Man                      No
# 17     25-34 years old                   Woman                      No
# 18     45-54 years old                     Man                      No
# 19     18-24 years old                     Man                      No
#
#                    Sexuality               Ethnicity           Accessibility
# 0                        NaN                     NaN                     NaN  \
# 1                        NaN                     NaN                     NaN
# 2                   Bisexual                   White       None of the above
# 3    Straight / Heterosexual                   White       None of the above
# 4                        NaN                     NaN                     NaN
# 5   Prefer to self-describe:  Or, in your own words:  Or, in your own words:
# 6                        NaN                  Indian       None of the above
# 7    Straight / Heterosexual                  Indian       None of the above
# 8   Prefer to self-describe:                European  Or, in your own words:
# 9    Straight / Heterosexual          White;European       None of the above
# 10   Straight / Heterosexual                European       None of the above
# 11   Straight / Heterosexual                   White       None of the above
# 12   Straight / Heterosexual                   White       None of the above
# 13   Straight / Heterosexual                   White       None of the above
# 14   Straight / Heterosexual                   White       None of the above
# 15   Straight / Heterosexual                     NaN       None of the above
# 16                  Bisexual                European       None of the above
# 17   Straight / Heterosexual                European       None of the above
# 18   Straight / Heterosexual          White;European       None of the above
# 19                       NaN                   White                     NaN
#
#                                          MentalHealth TBranch
# 0                                                 NaN     NaN  \
# 1                                                 NaN      No
# 2   I have a mood or emotional disorder (e.g., dep...      No
# 3                                   None of the above      No
# 4                                                 NaN      No
# 5                              Or, in your own words:     NaN
# 6                                   None of the above     NaN
# 7                                   None of the above     NaN
# 8                              Or, in your own words:     Yes
# 9                                   None of the above     NaN
# 10                                  None of the above      No
# 11  I have a mood or emotional disorder (e.g., dep...     Yes
# 12                                  None of the above     Yes
# 13  I have a mood or emotional disorder (e.g., dep...     Yes
# 14                                  None of the above     Yes
# 15                                                NaN     NaN
# 16  I have a mood or emotional disorder (e.g., dep...      No
# 17                                  None of the above      No
# 18                                  None of the above      No
# 19                                                NaN     NaN
#
#                      ICorPM  WorkExp                 Knowledge_1
# 0                       NaN      NaN                         NaN  \
# 1                       NaN      NaN                         NaN
# 2                       NaN      NaN                         NaN
# 3                       NaN      NaN                         NaN
# 4                       NaN      NaN                         NaN
# 5                       NaN      NaN                         NaN
# 6                       NaN      NaN                         NaN
# 7                       NaN      NaN                         NaN
# 8   Independent contributor      6.0                       Agree
# 9                       NaN      NaN                         NaN
# 10                      NaN      NaN                         NaN
# 11           People manager     14.0              Strongly agree
# 12  Independent contributor      5.0  Neither agree nor disagree
# 13  Independent contributor     15.0                       Agree
# 14  Independent contributor      5.0                       Agree
# 15                      NaN      NaN                         NaN
# 16                      NaN      NaN                         NaN
# 17                      NaN      NaN                         NaN
# 18                      NaN      NaN                         NaN
# 19                      NaN      NaN                         NaN
#
#                    Knowledge_2                 Knowledge_3
# 0                          NaN                         NaN  \
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# 5                          NaN                         NaN
# 6                          NaN                         NaN
# 7                          NaN                         NaN
# 8                     Disagree                       Agree
# 9                          NaN                         NaN
# 10                         NaN                         NaN
# 11                       Agree                    Disagree
# 12                    Disagree              Strongly agree
# 13                       Agree  Neither agree nor disagree
# 14  Neither agree nor disagree  Neither agree nor disagree
# 15                         NaN                         NaN
# 16                         NaN                         NaN
# 17                         NaN                         NaN
# 18                         NaN                         NaN
# 19                         NaN                         NaN
#
#                    Knowledge_4                 Knowledge_5
# 0                          NaN                         NaN  \
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# 5                          NaN                         NaN
# 6                          NaN                         NaN
# 7                          NaN                         NaN
# 8                        Agree                       Agree
# 9                          NaN                         NaN
# 10                         NaN                         NaN
# 11                       Agree                       Agree
# 12              Strongly agree              Strongly agree
# 13  Neither agree nor disagree  Neither agree nor disagree
# 14  Neither agree nor disagree  Neither agree nor disagree
# 15                         NaN                         NaN
# 16                         NaN                         NaN
# 17                         NaN                         NaN
# 18                         NaN                         NaN
# 19                         NaN                         NaN
#
#                    Knowledge_6                 Knowledge_7       Frequency_1
# 0                          NaN                         NaN               NaN  \
# 1                          NaN                         NaN               NaN
# 2                          NaN                         NaN               NaN
# 3                          NaN                         NaN               NaN
# 4                          NaN                         NaN               NaN
# 5                          NaN                         NaN               NaN
# 6                          NaN                         NaN               NaN
# 7                          NaN                         NaN               NaN
# 8                        Agree                    Disagree  3-5 times a week
# 9                          NaN                         NaN               NaN
# 10                         NaN                         NaN               NaN
# 11                       Agree                       Agree  10+ times a week
# 12                       Agree                    Disagree             Never
# 13                       Agree                       Agree  1-2 times a week
# 14  Neither agree nor disagree  Neither agree nor disagree  1-2 times a week
# 15                         NaN                         NaN               NaN
# 16                         NaN                         NaN               NaN
# 17                         NaN                         NaN               NaN
# 18                         NaN                         NaN               NaN
# 19                         NaN                         NaN               NaN
#
#          Frequency_2       Frequency_3         TimeSearching
# 0                NaN               NaN                   NaN  \
# 1                NaN               NaN                   NaN
# 2                NaN               NaN                   NaN
# 3                NaN               NaN                   NaN
# 4                NaN               NaN                   NaN
# 5                NaN               NaN                   NaN
# 6                NaN               NaN                   NaN
# 7                NaN               NaN                   NaN
# 8   3-5 times a week             Never   15-30 minutes a day
# 9                NaN               NaN                   NaN
# 10               NaN               NaN                   NaN
# 11  10+ times a week  3-5 times a week   30-60 minutes a day
# 12             Never             Never   30-60 minutes a day
# 13  10+ times a week  1-2 times a week  60-120 minutes a day
# 14  3-5 times a week  1-2 times a week   30-60 minutes a day
# 15               NaN               NaN                   NaN
# 16               NaN               NaN                   NaN
# 17               NaN               NaN                   NaN
# 18               NaN               NaN                   NaN
# 19               NaN               NaN                   NaN
#
#                  TimeAnswering      Onboarding
# 0                          NaN             NaN  \
# 1                          NaN             NaN
# 2                          NaN             NaN
# 3                          NaN             NaN
# 4                          NaN             NaN
# 5                          NaN             NaN
# 6                          NaN             NaN
# 7                          NaN             NaN
# 8       Over 120 minutes a day   Somewhat long
# 9                          NaN             NaN
# 10                         NaN             NaN
# 11        60-120 minutes a day      Just right
# 12  Less than 15 minutes a day  Somewhat short
# 13         30-60 minutes a day      Very short
# 14         30-60 minutes a day   Somewhat long
# 15                         NaN             NaN
# 16                         NaN             NaN
# 17                         NaN             NaN
# 18                         NaN             NaN
# 19                         NaN             NaN
#
#                                      ProfessionalTech TrueFalse_1 TrueFalse_2
# 0                                                 NaN         NaN         NaN  \
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                                 NaN         NaN         NaN
# 4                                                 NaN         NaN         NaN
# 5                                                 NaN         NaN         NaN
# 6                                                 NaN         NaN         NaN
# 7                                                 NaN         NaN         NaN
# 8   Innersource initiative;DevOps function;Microse...         Yes         Yes
# 9                                                 NaN         NaN         NaN
# 10                                                NaN         NaN         NaN
# 11  Innersource initiative;DevOps function;Microse...         Yes         Yes
# 12                      DevOps function;Microservices         Yes          No
# 13  Continuous integration (CI) and (more often) c...          No          No
# 14  DevOps function;Continuous integration (CI) an...          No         Yes
# 15                                                NaN         NaN         NaN
# 16                                                NaN         NaN         NaN
# 17                                                NaN         NaN         NaN
# 18                                                NaN         NaN         NaN
# 19                                                NaN         NaN         NaN
#
#    TrueFalse_3           SurveyLength                  SurveyEase
# 0          NaN                    NaN                         NaN  \
# 1          NaN               Too long                   Difficult
# 2          NaN  Appropriate in length  Neither easy nor difficult
# 3          NaN  Appropriate in length                        Easy
# 4          NaN               Too long                        Easy
# 5          NaN  Appropriate in length                        Easy
# 6          NaN  Appropriate in length                        Easy
# 7          NaN  Appropriate in length                        Easy
# 8          Yes  Appropriate in length                        Easy
# 9          NaN  Appropriate in length                        Easy
# 10         NaN  Appropriate in length                        Easy
# 11          No              Too short                        Easy
# 12         Yes  Appropriate in length                        Easy
# 13          No              Too short                        Easy
# 14         Yes  Appropriate in length                        Easy
# 15         NaN                    NaN  Neither easy nor difficult
# 16         NaN  Appropriate in length  Neither easy nor difficult
# 17         NaN  Appropriate in length                        Easy
# 18         NaN  Appropriate in length                        Easy
# 19         NaN  Appropriate in length                        Easy
#
#     ConvertedCompYearly
# 0                   NaN
# 1                   NaN
# 2               40205.0
# 3              215232.0
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8               49056.0
# 9                   NaN
# 10              60307.0
# 11             194400.0
# 12              65000.0
# 13                  NaN
# 14             110000.0
# 15                  NaN
# 16              19224.0
# 17             202623.0
# 18              51192.0
# 19                  NaN

# %%
dfs['Currency']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Currency'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 dfs['Currency']
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'Currency'

# %%
dfs.rename(columns={'Currency': 'LocalCurrency'}, inplace=True)

# %%
dfs['LocalCurrency']
# Out:
# 0                              NaN
# 1             CAD\tCanadian dollar
# 2              GBP\tPound sterling
# 3          ILS\tIsraeli new shekel
# 4        USD\tUnited States dollar
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                EUR European Euro
# 9               HRK\tCroatian kuna
# 10             GBP\tPound sterling
# 11       USD\tUnited States dollar
# 12       USD\tUnited States dollar
# 13          AUD\tAustralian dollar
# 14       USD\tUnited States dollar
# 15              RUB\tRussian ruble
# 16               CZK\tCzech koruna
# 17               EUR European Euro
# 18               EUR European Euro
# 19                             NaN
# 20                             NaN
# 21               EUR European Euro
# 22            CAD\tCanadian dollar
# 23               EUR European Euro
# 24         ILS\tIsraeli new shekel
# 25               EUR European Euro
# 26       USD\tUnited States dollar
# 27                             NaN
# 28       USD\tUnited States dollar
# 29               EUR European Euro
# 30                             NaN
# 31       USD\tUnited States dollar
# 32                             NaN
# 33                             NaN
# 34               PLN\tPolish zloty
# 35                             NaN
# 36            CAD\tCanadian dollar
# 37         ILS\tIsraeli new shekel
# 38                             NaN
# 39               CZK\tCzech koruna
# 40       USD\tUnited States dollar
# 41         ILS\tIsraeli new shekel
# 42                             NaN
# 43                             NaN
# 44                             NaN
# 45               EUR European Euro
# 46                             NaN
# 47       USD\tUnited States dollar
# 48               EUR European Euro
# 49               EUR European Euro
# 50                             NaN
# 51               PLN\tPolish zloty
# 52                             NaN
# 53       USD\tUnited States dollar
# 54            NOK\tNorwegian krone
# 55       USD\tUnited States dollar
# 56          TWD\tNew Taiwan dollar
# 57               EUR European Euro
# 58           HKD\tHong Kong dollar
# 59               EUR European Euro
# 60            CAD\tCanadian dollar
# 61                             NaN
# 62               EUR European Euro
# 63       USD\tUnited States dollar
# 64                             NaN
# 65               INR\tIndian rupee
# 66             BRL\tBrazilian real
# 67                             NaN
# 68                             NaN
# 69             UYU\tUruguayan peso
# 70              RSD\tSerbian dinar
# 71                             NaN
# 72                             NaN
# 73               EUR European Euro
# 74              SEK\tSwedish krona
# 75                             NaN
# 76       USD\tUnited States dollar
# 77                             NaN
# 78              RSD\tSerbian dinar
# 79               EUR European Euro
# 80               DKK\tDanish krone
# 81                             NaN
# 82                             NaN
# 83       USD\tUnited States dollar
# 84             GBP\tPound sterling
# 85       USD\tUnited States dollar
# 86                             NaN
# 87               EUR European Euro
# 88               EUR European Euro
# 89              SEK\tSwedish krona
# 90               EUR European Euro
# 91               EUR European Euro
# 92         ILS\tIsraeli new shekel
# 93       USD\tUnited States dollar
# 94             GBP\tPound sterling
# 95       USD\tUnited States dollar
# 96         ILS\tIsraeli new shekel
# 97       USD\tUnited States dollar
# 98             EGP\tEgyptian pound
# 99               TRY\tTurkish lira
#                    ...
# 73168    USD\tUnited States dollar
# 73169            EUR European Euro
# 73170                          NaN
# 73171       UAH\tUkrainian hryvnia
# 73172            EUR European Euro
# 73173            EUR European Euro
# 73174                          NaN
# 73175            EUR European Euro
# 73176            EUR European Euro
# 73177          GBP\tPound sterling
# 73178            INR\tIndian rupee
# 73179                          NaN
# 73180                          NaN
# 73181    USD\tUnited States dollar
# 73182            EUR European Euro
# 73183            EUR European Euro
# 73184            INR\tIndian rupee
# 73185            EUR European Euro
# 73186                          NaN
# 73187                          NaN
# 73188    USD\tUnited States dollar
# 73189           SEK\tSwedish krona
# 73190            EUR European Euro
# 73191                          NaN
# 73192                          NaN
# 73193                          NaN
# 73194            EUR European Euro
# 73195        BDT\tBangladeshi taka
# 73196            EUR European Euro
# 73197    USD\tUnited States dollar
# 73198            EUR European Euro
# 73199    USD\tUnited States dollar
# 73200        LKR\tSri Lankan rupee
# 73201                          NaN
# 73202            EUR European Euro
# 73203                          NaN
# 73204    USD\tUnited States dollar
# 73205    USD\tUnited States dollar
# 73206    USD\tUnited States dollar
# 73207    USD\tUnited States dollar
# 73208      BOB\tBolivian boliviano
# 73209                          NaN
# 73210    USD\tUnited States dollar
# 73211            EUR European Euro
# 73212    USD\tUnited States dollar
# 73213    USD\tUnited States dollar
# 73214    USD\tUnited States dollar
# 73215                          NaN
# 73216    USD\tUnited States dollar
# 73217                          NaN
# 73218          BRL\tBrazilian real
# 73219            CZK\tCzech koruna
# 73220    USD\tUnited States dollar
# 73221            EUR European Euro
# 73222    USD\tUnited States dollar
# 73223    USD\tUnited States dollar
# 73224                          NaN
# 73225                          NaN
# 73226    USD\tUnited States dollar
# 73227         PHP\tPhilippine peso
# 73228    USD\tUnited States dollar
# 73229    USD\tUnited States dollar
# 73230       AUD\tAustralian dollar
# 73231                          NaN
# 73232          UYU\tUruguayan peso
# 73233           RUB\tRussian ruble
# 73234               THB\tThai baht
# 73235            CZK\tCzech koruna
# 73236                          NaN
# 73237            IRR\tIranian rial
# 73238      ILS\tIsraeli new shekel
# 73239                          NaN
# 73240    USD\tUnited States dollar
# 73241       IDR\tIndonesian rupiah
# 73242                          NaN
# 73243                          NaN
# 73244                          NaN
# 73245                          NaN
# 73246           RUB\tRussian ruble
# 73247                          NaN
# 73248          GBP\tPound sterling
# 73249                          NaN
# 73250           HRK\tCroatian kuna
# 73251            EUR European Euro
# 73252                          NaN
# 73253       AUD\tAustralian dollar
# 73254    USD\tUnited States dollar
# 73255            INR\tIndian rupee
# 73256                          NaN
# 73257                          NaN
# 73258            INR\tIndian rupee
# 73259            PLN\tPolish zloty
# 73260                          NaN
# 73261            EUR European Euro
# 73262                          NaN
# 73263    USD\tUnited States dollar
# 73264    USD\tUnited States dollar
# 73265    USD\tUnited States dollar
# 73266          GBP\tPound sterling
# 73267                          NaN
# Name: LocalCurrency, Length: 73268, dtype: object

# %%
dfs['SurveyEase']
# Out:
# 0                               NaN
# 1                         Difficult
# 2        Neither easy nor difficult
# 3                              Easy
# 4                              Easy
# 5                              Easy
# 6                              Easy
# 7                              Easy
# 8                              Easy
# 9                              Easy
# 10                             Easy
# 11                             Easy
# 12                             Easy
# 13                             Easy
# 14                             Easy
# 15       Neither easy nor difficult
# 16       Neither easy nor difficult
# 17                             Easy
# 18                             Easy
# 19                             Easy
# 20                             Easy
# 21                             Easy
# 22       Neither easy nor difficult
# 23       Neither easy nor difficult
# 24                             Easy
# 25       Neither easy nor difficult
# 26                             Easy
# 27                             Easy
# 28                             Easy
# 29                             Easy
# 30                              NaN
# 31                             Easy
# 32                             Easy
# 33                             Easy
# 34                             Easy
# 35       Neither easy nor difficult
# 36                             Easy
# 37       Neither easy nor difficult
# 38                             Easy
# 39       Neither easy nor difficult
# 40                             Easy
# 41       Neither easy nor difficult
# 42                             Easy
# 43       Neither easy nor difficult
# 44                             Easy
# 45                             Easy
# 46       Neither easy nor difficult
# 47                             Easy
# 48                             Easy
# 49                             Easy
# 50                             Easy
# 51       Neither easy nor difficult
# 52                             Easy
# 53       Neither easy nor difficult
# 54                             Easy
# 55                             Easy
# 56                             Easy
# 57                             Easy
# 58       Neither easy nor difficult
# 59                             Easy
# 60       Neither easy nor difficult
# 61                             Easy
# 62       Neither easy nor difficult
# 63                             Easy
# 64                             Easy
# 65                             Easy
# 66                             Easy
# 67       Neither easy nor difficult
# 68                             Easy
# 69       Neither easy nor difficult
# 70       Neither easy nor difficult
# 71                             Easy
# 72                             Easy
# 73                             Easy
# 74                             Easy
# 75                             Easy
# 76                             Easy
# 77       Neither easy nor difficult
# 78       Neither easy nor difficult
# 79                             Easy
# 80       Neither easy nor difficult
# 81       Neither easy nor difficult
# 82       Neither easy nor difficult
# 83       Neither easy nor difficult
# 84                             Easy
# 85                             Easy
# 86                              NaN
# 87                             Easy
# 88                             Easy
# 89       Neither easy nor difficult
# 90                             Easy
# 91                             Easy
# 92                             Easy
# 93                             Easy
# 94       Neither easy nor difficult
# 95                             Easy
# 96                             Easy
# 97                             Easy
# 98                              NaN
# 99       Neither easy nor difficult
#                     ...
# 73168                          Easy
# 73169                          Easy
# 73170                          Easy
# 73171    Neither easy nor difficult
# 73172                          Easy
# 73173                          Easy
# 73174                          Easy
# 73175                          Easy
# 73176                          Easy
# 73177    Neither easy nor difficult
# 73178    Neither easy nor difficult
# 73179                          Easy
# 73180                          Easy
# 73181    Neither easy nor difficult
# 73182    Neither easy nor difficult
# 73183                          Easy
# 73184                          Easy
# 73185    Neither easy nor difficult
# 73186                          Easy
# 73187                          Easy
# 73188                          Easy
# 73189    Neither easy nor difficult
# 73190                          Easy
# 73191                          Easy
# 73192                          Easy
# 73193                          Easy
# 73194                          Easy
# 73195    Neither easy nor difficult
# 73196    Neither easy nor difficult
# 73197                          Easy
# 73198                          Easy
# 73199    Neither easy nor difficult
# 73200                          Easy
# 73201                           NaN
# 73202    Neither easy nor difficult
# 73203                          Easy
# 73204                          Easy
# 73205                          Easy
# 73206                          Easy
# 73207                          Easy
# 73208                          Easy
# 73209                     Difficult
# 73210    Neither easy nor difficult
# 73211                          Easy
# 73212                          Easy
# 73213                          Easy
# 73214    Neither easy nor difficult
# 73215                           NaN
# 73216    Neither easy nor difficult
# 73217                          Easy
# 73218    Neither easy nor difficult
# 73219    Neither easy nor difficult
# 73220                          Easy
# 73221    Neither easy nor difficult
# 73222    Neither easy nor difficult
# 73223                          Easy
# 73224                          Easy
# 73225    Neither easy nor difficult
# 73226                          Easy
# 73227                          Easy
# 73228                          Easy
# 73229                          Easy
# 73230                          Easy
# 73231                          Easy
# 73232                          Easy
# 73233                          Easy
# 73234    Neither easy nor difficult
# 73235                          Easy
# 73236                     Difficult
# 73237    Neither easy nor difficult
# 73238                          Easy
# 73239                          Easy
# 73240                          Easy
# 73241                          Easy
# 73242                          Easy
# 73243                           NaN
# 73244                          Easy
# 73245                          Easy
# 73246    Neither easy nor difficult
# 73247                          Easy
# 73248                          Easy
# 73249    Neither easy nor difficult
# 73250                          Easy
# 73251                          Easy
# 73252                          Easy
# 73253    Neither easy nor difficult
# 73254    Neither easy nor difficult
# 73255    Neither easy nor difficult
# 73256                          Easy
# 73257                          Easy
# 73258    Neither easy nor difficult
# 73259    Neither easy nor difficult
# 73260                          Easy
# 73261                          Easy
# 73262    Neither easy nor difficult
# 73263                          Easy
# 73264                          Easy
# 73265                          Easy
# 73266                          Easy
# 73267                          Easy
# Name: SurveyEase, Length: 73268, dtype: object

# %%
dfs['SurveyEase'] = dfs['SurveyEase'].map({'Easy': 'Facil', 'Difficult': 'Dificil', 'Neither easy nor difficult': 'ni pedos'})
#A veces es conveniente usar metodo .replace en vez de .map

# %%
dfs.head()
# Out:
#    ResponseId                                         MainBranch
# 0           1                                      None of these  \
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork
# 0                  NaN                                   NaN  \
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities
# 0                                       NaN  \
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel
# 0                                              NaN  \
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode
# 0                                                NaN  \
# 1                                                NaN
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert
# 0                                                NaN                  NaN  \
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
# 4  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode YearsCodePro                                            DevType
# 0       NaN          NaN                                                NaN  \
# 1       NaN          NaN                                                NaN
# 2        14            5  Data scientist or machine learning specialist;...
# 3        20           17                              Developer, full-stack
# 4         8            3  Developer, front-end;Developer, full-stack;Dev...
#
#                 OrgSize      PurchaseInfluence
# 0                   NaN                    NaN  \
# 1                   NaN                    NaN
# 2    20 to 99 employees  I have some influence
# 3  100 to 499 employees  I have some influence
# 4    20 to 99 employees  I have some influence
#
#                                           BuyNewTool
# 0                                                NaN  \
# 1                                                NaN
# 2                                                NaN
# 3                            Other (please specify):
# 4  Start a free trial;Visit developer communities...
#
#                                              Country
# 0                                                NaN  \
# 1                                             Canada
# 2  United Kingdom of Great Britain and Northern I...
# 3                                             Israel
# 4                           United States of America
#
#                LocalCurrency  CompTotal CompFreq
# 0                        NaN        NaN      NaN  \
# 1       CAD\tCanadian dollar        NaN      NaN
# 2        GBP\tPound sterling    32000.0   Yearly
# 3    ILS\tIsraeli new shekel    60000.0  Monthly
# 4  USD\tUnited States dollar        NaN      NaN
#
#                         LanguageHaveWorkedWith
# 0                                          NaN  \
# 1                        JavaScript;TypeScript
# 2            C#;C++;HTML/CSS;JavaScript;Python
# 3                 C#;JavaScript;SQL;TypeScript
# 4  C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#
#                        LanguageWantToWorkWith
# 0                                         NaN  \
# 1                             Rust;TypeScript
# 2       C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                           C#;SQL;TypeScript
# 4  C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
#
#                               DatabaseHaveWorkedWith
# 0                                                NaN  \
# 1                                                NaN
# 2                               Microsoft SQL Server
# 3                               Microsoft SQL Server
# 4  Cloud Firestore;Elasticsearch;Microsoft SQL Se...
#
#                               DatabaseWantToWorkWith
# 0                                                NaN  \
# 1                                                NaN
# 2                               Microsoft SQL Server
# 3                               Microsoft SQL Server
# 4  Cloud Firestore;Elasticsearch;Firebase Realtim...
#
#      PlatformHaveWorkedWith    PlatformWantToWorkWith
# 0                       NaN                       NaN  \
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4  Firebase;Microsoft Azure  Firebase;Microsoft Azure
#
#                          WebframeHaveWorkedWith
# 0                                           NaN  \
# 1                                           NaN
# 2                                    Angular.js
# 3                         ASP.NET;ASP.NET Core
# 4  Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
#
#                  WebframeWantToWorkWith MiscTechHaveWorkedWith
# 0                                   NaN                    NaN  \
# 1                                   NaN                    NaN
# 2                    Angular;Angular.js                 Pandas
# 3                 ASP.NET;ASP.NET Core                    .NET
# 4  Angular;ASP.NET Core ;Blazor;Node.js                   .NET
#
#   MiscTechWantToWorkWith ToolsTechHaveWorkedWith ToolsTechWantToWorkWith
# 0                    NaN                     NaN                     NaN  \
# 1                    NaN                     NaN                     NaN
# 2                   .NET                     NaN                     NaN
# 3                   .NET                     NaN                     NaN
# 4      .NET;Apache Kafka                     npm       Docker;Kubernetes
#
#                        NEWCollabToolsHaveWorkedWith
# 0                                               NaN  \
# 1                                               NaN
# 2                           Notepad++;Visual Studio
# 3        Notepad++;Visual Studio;Visual Studio Code
# 4  Notepad++;Visual Studio;Visual Studio Code;Xcode
#
#                  NEWCollabToolsWantToWorkWith OpSysProfessional use
# 0                                         NaN                   NaN  \
# 1                                         NaN                 macOS
# 2                     Notepad++;Visual Studio               Windows
# 3  Notepad++;Visual Studio;Visual Studio Code               Windows
# 4      Rider;Visual Studio;Visual Studio Code               Windows
#
#                    OpSysPersonal use         VersionControlSystem
# 0                                NaN                          NaN  \
# 1  Windows Subsystem for Linux (WSL)                          Git
# 2                            Windows                          Git
# 3                            Windows                          Git
# 4                      macOS;Windows  Git;Other (please specify):
#
#                                        VCInteraction  VCHostingPersonal use
# 0                                                NaN                    NaN  \
# 1                                                NaN                    NaN
# 2                                        Code editor                    NaN
# 3  Code editor;Command-line;Version control hosti...                    NaN
# 4                                        Code editor                    NaN
#
#    VCHostingProfessional use OfficeStackAsyncHaveWorkedWith
# 0                        NaN                            NaN  \
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN    Jira Work Management;Trello
# 4                        NaN                            NaN
#
#   OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith
# 0                            NaN                           NaN  \
# 1                            NaN                           NaN
# 2                            NaN               Microsoft Teams
# 3    Jira Work Management;Trello                    Slack;Zoom
# 4                            NaN          Microsoft Teams;Zoom
#
#   OfficeStackSyncWantToWorkWith        Blockchain
# 0                           NaN               NaN  \
# 1                           NaN  Very unfavorable
# 2               Microsoft Teams  Very unfavorable
# 3                    Slack;Zoom  Very unfavorable
# 4                           NaN       Unfavorable
#
#                                           NEWSOSites             SOVisitFreq
# 0                                                NaN                     NaN  \
# 1  Collectives on Stack Overflow;Stack Overflow f...   Daily or almost daily
# 2  Collectives on Stack Overflow;Stack Overflow;S...  Multiple times per day
# 3  Collectives on Stack Overflow;Stack Overflow f...   Daily or almost daily
# 4  Collectives on Stack Overflow;Stack Overflow f...  Multiple times per day
#
#   SOAccount              SOPartFreq           SOComm              Age Gender
# 0       NaN                     NaN              NaN              NaN    NaN  \
# 1       Yes   Daily or almost daily         Not sure              NaN    NaN
# 2       Yes  Multiple times per day          Neutral  25-34 years old    Man
# 3       Yes    A few times per week  Yes, definitely  35-44 years old    Man
# 4       Yes   Daily or almost daily  Yes, definitely  25-34 years old    NaN
#
#   Trans                Sexuality Ethnicity      Accessibility
# 0   NaN                      NaN       NaN                NaN  \
# 1   NaN                      NaN       NaN                NaN
# 2    No                 Bisexual     White  None of the above
# 3    No  Straight / Heterosexual     White  None of the above
# 4   NaN                      NaN       NaN                NaN
#
#                                         MentalHealth TBranch ICorPM  WorkExp
# 0                                                NaN     NaN    NaN      NaN  \
# 1                                                NaN      No    NaN      NaN
# 2  I have a mood or emotional disorder (e.g., dep...      No    NaN      NaN
# 3                                  None of the above      No    NaN      NaN
# 4                                                NaN      No    NaN      NaN
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5 Knowledge_6
# 0         NaN         NaN         NaN         NaN         NaN         NaN  \
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Knowledge_7 Frequency_1 Frequency_2 Frequency_3 TimeSearching TimeAnswering
# 0         NaN         NaN         NaN         NaN           NaN           NaN  \
# 1         NaN         NaN         NaN         NaN           NaN           NaN
# 2         NaN         NaN         NaN         NaN           NaN           NaN
# 3         NaN         NaN         NaN         NaN           NaN           NaN
# 4         NaN         NaN         NaN         NaN           NaN           NaN
#
#   Onboarding ProfessionalTech TrueFalse_1 TrueFalse_2 TrueFalse_3
# 0        NaN              NaN         NaN         NaN         NaN  \
# 1        NaN              NaN         NaN         NaN         NaN
# 2        NaN              NaN         NaN         NaN         NaN
# 3        NaN              NaN         NaN         NaN         NaN
# 4        NaN              NaN         NaN         NaN         NaN
#
#             SurveyLength SurveyEase  ConvertedCompYearly
# 0                    NaN        NaN                  NaN
# 1               Too long        NaN                  NaN
# 2  Appropriate in length        NaN              40205.0
# 3  Appropriate in length        NaN             215232.0
# 4               Too long        NaN                  NaN
