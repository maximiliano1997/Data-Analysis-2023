# %%
people = {
    "first": ["Corey", "Jane", "Jhon","Adam"],
    "last": ["Schafer", "Doe", "Doe", "Doe"],
    "email": ["CoreyMSchager@gmail.com", "loco@gamil.com", "lineal@gmail.com", "A@email.com"],
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 1   Jane      Doe           loco@gamil.com
# 2   Jhon      Doe         lineal@gmail.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by='last', ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 1   Jane      Doe           loco@gamil.com
# 2   Jhon      Doe         lineal@gmail.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by=['last','first'], ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 2   Jhon      Doe         lineal@gmail.com
# 1   Jane      Doe           loco@gamil.com
# 3   Adam      Doe              A@email.com

# %%
df.sort_values(by=['last','first'], ascending=[False, True], inplace=True)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 3   Adam      Doe              A@email.com
# 1   Jane      Doe           loco@gamil.com
# 2   Jhon      Doe         lineal@gmail.com

# %%
df.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchager@gmail.com
# 1   Jane      Doe           loco@gamil.com
# 2   Jhon      Doe         lineal@gmail.com
# 3   Adam      Doe              A@email.com

# %%
df['last'].sort_values()
# Out:
# 3        Doe
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: object

# %% [markdown]
# ## Working with Stackoverflow Data

# %%
dfs = pd.read_csv('../data/survey_results_public.csv')
schema_dfs = pd.read_csv('../data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows', 79)
pd.set_option('display.min_rows', 79)
dfs.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.set_option('display.max_columns', 79)
#       2 pd.set_option('display.max_rows', 79)
#       3 pd.set_option('display.min_rows', 79)
#
# NameError: name 'pd' is not defined

# %%
dfs.sort_values(by=['Country', 'Currency','CompTotal'], ascending=[True, False, False], inplace=True)

# %%
dfs[['Country', 'Currency', 'CompTotal']].head(50)
# Out:
#            Country                         Currency   CompTotal
# 55665  Afghanistan        USD\tUnited States dollar       200.0
# 3641   Afghanistan        USD\tUnited States dollar         NaN
# 61617  Afghanistan        USD\tUnited States dollar         NaN
# 6891   Afghanistan                IRR\tIranian rial  55000000.0
# 58077  Afghanistan          BOB\tBolivian boliviano         NaN
# 42122  Afghanistan               BGN\tBulgarian lev         NaN
# 28582  Afghanistan                ALL\tAlbanian lek         NaN
# 38512  Afghanistan              AFN\tAfghan afghani   1200000.0
# 43639  Afghanistan              AFN\tAfghan afghani    700000.0
# 43690  Afghanistan              AFN\tAfghan afghani    100000.0
# 6242   Afghanistan              AFN\tAfghan afghani     40000.0
# 23223  Afghanistan              AFN\tAfghan afghani     40000.0
# 2737   Afghanistan              AFN\tAfghan afghani         0.0
# 4502   Afghanistan              AFN\tAfghan afghani         NaN
# 15607  Afghanistan              AFN\tAfghan afghani         NaN
# 17038  Afghanistan              AFN\tAfghan afghani         NaN
# 24812  Afghanistan              AFN\tAfghan afghani         NaN
# 53960  Afghanistan              AFN\tAfghan afghani         NaN
# 55393  Afghanistan              AFN\tAfghan afghani         NaN
# 56355  Afghanistan              AFN\tAfghan afghani         NaN
# 60146  Afghanistan              AFN\tAfghan afghani         NaN
# 2448   Afghanistan  AED United Arab Emirates dirham     40000.0
# 49273  Afghanistan  AED United Arab Emirates dirham      6000.0
# 3886   Afghanistan  AED United Arab Emirates dirham         1.0
# 5464   Afghanistan  AED United Arab Emirates dirham         1.0
# 6776   Afghanistan  AED United Arab Emirates dirham         1.0
# 17469  Afghanistan  AED United Arab Emirates dirham         1.0
# 67666  Afghanistan  AED United Arab Emirates dirham         0.0
# 1959   Afghanistan  AED United Arab Emirates dirham         NaN
# 21765  Afghanistan  AED United Arab Emirates dirham         NaN
# 23161  Afghanistan  AED United Arab Emirates dirham         NaN
# 33328  Afghanistan  AED United Arab Emirates dirham         NaN
# 34043  Afghanistan  AED United Arab Emirates dirham         NaN
# 42870  Afghanistan  AED United Arab Emirates dirham         NaN
# 48959  Afghanistan  AED United Arab Emirates dirham         NaN
# 51547  Afghanistan  AED United Arab Emirates dirham         NaN
# 55309  Afghanistan  AED United Arab Emirates dirham         NaN
# 61935  Afghanistan  AED United Arab Emirates dirham         NaN
# 64906  Afghanistan  AED United Arab Emirates dirham         NaN
# 3775   Afghanistan                              NaN         NaN
# 7944   Afghanistan                              NaN         NaN
# 8890   Afghanistan                              NaN         NaN
# 10233  Afghanistan                              NaN         NaN
# 10910  Afghanistan                              NaN         NaN
# 13851  Afghanistan                              NaN         NaN
# 19201  Afghanistan                              NaN         NaN
# 22876  Afghanistan                              NaN         NaN
# 25962  Afghanistan                              NaN         NaN
# 26617  Afghanistan                              NaN         NaN
# 28434  Afghanistan                              NaN         NaN

# %%
dfs['CompTotal'].nlargest(10)
# Out:
# 35786    9.000000e+56
# 3068     1.000000e+52
# 70597    1.000000e+22
# 17567    1.000000e+15
# 19244    5.000000e+12
# 24640    1.500070e+12
# 31190    1.000000e+12
# 71603    9.363220e+09
# 34411    7.200000e+09
# 49874    6.438169e+09
# Name: CompTotal, dtype: float64

# %%
dfs.nlargest(10, 'CompTotal')
# Out:
#        ResponseId                                         MainBranch
# 35786       35787                     I am a developer by profession  \
# 3068         3069                     I am a developer by profession
# 70597       70598                     I am a developer by profession
# 17567       17568                     I am a developer by profession
# 19244       19245  I am not primarily a developer, but I write co...
# 24640       24641                     I am a developer by profession
# 31190       31191                     I am a developer by profession
# 71603       71604                     I am a developer by profession
# 34411       34412                     I am a developer by profession
# 49874       49875                     I am a developer by profession
#
#                                               Employment
# 35786            Employed, full-time;Employed, part-time  \
# 3068                                 Employed, full-time
# 70597  Independent contractor, freelancer, or self-em...
# 17567                                Employed, full-time
# 19244  Independent contractor, freelancer, or self-em...
# 24640                                Employed, full-time
# 31190                                Employed, full-time
# 71603                                Employed, part-time
# 34411                                Employed, full-time
# 49874                                Employed, full-time
#
#                                  RemoteWork
# 35786  Hybrid (some remote, some in-person)  \
# 3068   Hybrid (some remote, some in-person)
# 70597                          Fully remote
# 17567  Hybrid (some remote, some in-person)
# 19244                          Fully remote
# 24640                        Full in-person
# 31190  Hybrid (some remote, some in-person)
# 71603                          Fully remote
# 34411  Hybrid (some remote, some in-person)
# 49874                          Fully remote
#
#                                         CodingActivities
# 35786                       I don’t code outside of work  \
# 3068   Hobby;Contribute to open-source projects;Boots...
# 70597           Hobby;Contribute to open-source projects
# 17567  Hobby;Contribute to open-source projects;Freel...
# 19244  Hobby;Contribute to open-source projects;Freel...
# 24640  Hobby;Contribute to open-source projects;Boots...
# 31190                       I don’t code outside of work
# 71603                                              Hobby
# 34411   Bootstrapping a business;Freelance/contract work
# 49874                 Contribute to open-source projects
#
#                                                  EdLevel
# 35786  Secondary school (e.g. American high school, G...  \
# 3068        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 70597       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17567  Secondary school (e.g. American high school, G...
# 19244    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 24640  Secondary school (e.g. American high school, G...
# 31190         Other doctoral degree (Ph.D., Ed.D., etc.)
# 71603                                     Something else
# 34411    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49874                          Primary/elementary school
#
#                                                LearnCode
# 35786                                          Colleague  \
# 3068   School (i.e., University, College, etc);Other ...
# 70597  Books / Physical media;Other online resources ...
# 17567  Other online resources (e.g., videos, blogs, f...
# 19244  Books / Physical media;Friend or family member...
# 24640                             Books / Physical media
# 31190  Books / Physical media;Friend or family member...
# 71603                            Other (please specify):
# 34411  Books / Physical media;Other online resources ...
# 49874  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline
# 35786                                                NaN  \
# 3068                                                 NaN
# 70597  Technical documentation;Blogs;Written Tutorial...
# 17567  Technical documentation;Stack Overflow;Online ...
# 19244  Technical documentation;Programming Games;Writ...
# 24640                                                NaN
# 31190  Technical documentation;Blogs;Programming Game...
# 71603                                                NaN
# 34411  Technical documentation;Blogs;Stack Overflow;V...
# 49874  Technical documentation;Blogs;Programming Game...
#
#                                     LearnCodeCoursesCert YearsCode
# 35786                                                NaN         4  \
# 3068                                                 NaN        10
# 70597                                                NaN        20
# 17567                                                NaN        10
# 19244                                                NaN        15
# 24640                                                NaN         2
# 31190  Coursera;Udemy;Codecademy;Pluralsight;edX;Udac...        10
# 71603                                                NaN         4
# 34411                          Udemy;Pluralsight;Udacity        16
# 49874  Coursera;Udemy;Codecademy;Pluralsight;edX;Udac...        19
#
#            YearsCodePro                                            DevType
# 35786                16          Developer, full-stack;Academic researcher  \
# 3068                  2                      Developer, back-end;Scientist
# 70597                19  Developer, front-end;Developer, full-stack;Dev...
# 17567                 6  Developer, front-end;Developer, full-stack;Dev...
# 19244                10  Developer, front-end;Engineer, data;Developer,...
# 24640               NaN                                    Project manager
# 31190  Less than 1 year  Data scientist or machine learning specialist;...
# 71603               NaN                                          Scientist
# 34411                12  Developer, full-stack;Developer, desktop or en...
# 49874                10  Data scientist or machine learning specialist;...
#
#                                                  OrgSize
# 35786  Just me - I am a freelancer, sole proprietor, ...  \
# 3068                            10,000 or more employees
# 70597  Just me - I am a freelancer, sole proprietor, ...
# 17567                                 10 to 19 employees
# 19244                                 10 to 19 employees
# 24640  Just me - I am a freelancer, sole proprietor, ...
# 31190                                       I don’t know
# 71603  Just me - I am a freelancer, sole proprietor, ...
# 34411                                 20 to 99 employees
# 49874                           1,000 to 4,999 employees
#
#                       PurchaseInfluence
# 35786  I have a great deal of influence  \
# 3068              I have some influence
# 70597  I have a great deal of influence
# 17567             I have some influence
# 19244     I have little or no influence
# 24640  I have a great deal of influence
# 31190  I have a great deal of influence
# 71603     I have little or no influence
# 34411             I have some influence
# 49874     I have little or no influence
#
#                                               BuyNewTool
# 35786    Visit developer communities like Stack Overflow  \
# 3068                                                 NaN
# 70597                            Other (please specify):
# 17567  Visit developer communities like Stack Overflo...
# 19244  Other (please specify):;Visit developer commun...
# 24640  Read ratings or reviews on third party sites l...
# 31190  Other (please specify):;Start a free trial;Vis...
# 71603                                 Start a free trial
# 34411  Start a free trial;Visit developer communities...
# 49874  Other (please specify):;Start a free trial;Vis...
#
#                             Country                   Currency     CompTotal
# 35786                       Ecuador        DOP\tDominican peso  9.000000e+56  \
# 3068       United States of America  USD\tUnited States dollar  1.000000e+52
# 70597      United States of America         ZMW Zambian kwacha  1.000000e+22
# 17567                         Italy          EUR European Euro  1.000000e+15
# 19244                    Kyrgyzstan       KGS\tKyrgyzstani som  5.000000e+12
# 24640                       Nigeria        NGN\tNigerian naira  1.500070e+12
# 31190      United States of America  USD\tUnited States dollar  1.000000e+12
# 71603  Iran, Islamic Republic of...  USD\tUnited States dollar  9.363220e+09
# 34411  Iran, Islamic Republic of...          IRR\tIranian rial  7.200000e+09
# 49874                        Angola          INR\tIndian rupee  6.438169e+09
#
#       CompFreq                             LanguageHaveWorkedWith
# 35786   Weekly                                    APL;COBOL;Scala  \
# 3068    Weekly                    C;C++;Fortran;Java;Python;Scala
# 70597   Yearly        Bash/Shell;HTML/CSS;JavaScript;Perl;PHP;SQL
# 17567  Monthly                        HTML/CSS;JavaScript;PHP;SQL
# 19244   Yearly  Bash/Shell;C++;Go;HTML/CSS;JavaScript;MATLAB;P...
# 24640   Weekly          HTML/CSS;JavaScript;PowerShell;TypeScript
# 31190  Monthly  APL;Assembly;Bash/Shell;C;C#;C++;Clojure;COBOL...
# 71603  Monthly                                                APL
# 34411  Monthly                 C;C#;JavaScript;PHP;SQL;TypeScript
# 49874  Monthly  APL;Assembly;Bash/Shell;C#;C++;Clojure;COBOL;C...
#
#                                   LanguageWantToWorkWith
# 35786                                C++;Dart;MATLAB;VBA  \
# 3068                                   Python;Rust;Scala
# 70597                                                NaN
# 17567  C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;R;SQ...
# 19244  Bash/Shell;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 24640                                                NaN
# 31190  APL;Assembly;Bash/Shell;C;C#;C++;Clojure;COBOL...
# 71603                                                NaN
# 34411            C#;Dart;F#;Go;JavaScript;SQL;TypeScript
# 49874  APL;Assembly;Bash/Shell;C#;C++;Clojure;COBOL;C...
#
#                                   DatabaseHaveWorkedWith
# 35786                                            IBM DB2  \
# 3068                   Cassandra;PostgreSQL;Redis;SQLite
# 70597                                      MariaDB;MySQL
# 17567                       MariaDB;MongoDB;MySQL;SQLite
# 19244  Elasticsearch;MariaDB;MongoDB;MySQL;Oracle;Pos...
# 24640  Cloud Firestore;Microsoft SQL Server;Firebase ...
# 31190  Cassandra;Couchbase;CouchDB;Cloud Firestore;Dy...
# 71603                                          Cassandra
# 34411                  Microsoft SQL Server;MySQL;Oracle
# 49874  Cassandra;Couchbase;Cloud Firestore;DynamoDB;E...
#
#                                   DatabaseWantToWorkWith
# 35786                                        Neo4j;Redis  \
# 3068                   Cassandra;PostgreSQL;Redis;SQLite
# 70597                                                NaN
# 17567                       MariaDB;MongoDB;MySQL;SQLite
# 19244                        Elasticsearch;MariaDB;MySQL
# 24640                                                NaN
# 31190  Cassandra;Couchbase;CouchDB;Cloud Firestore;Dy...
# 71603                                                NaN
# 34411  Cassandra;Elasticsearch;Microsoft SQL Server;P...
# 49874  Cassandra;Couchbase;Cloud Firestore;DynamoDB;E...
#
#                                   PlatformHaveWorkedWith
# 35786                                       DigitalOcean  \
# 3068                                                 AWS
# 70597                                                NaN
# 17567                   AWS;DigitalOcean;Managed Hosting
# 19244  DigitalOcean;Firebase;Google Cloud;Oracle Clou...
# 24640  DigitalOcean;Google Cloud;Microsoft Azure;Open...
# 31190  AWS;Colocation;DigitalOcean;Firebase;Google Cl...
# 71603                                                NaN
# 34411                                                NaN
# 49874  AWS;Colocation;Microsoft Azure;Oracle Cloud In...
#
#                                   PlatformWantToWorkWith
# 35786                                             Heroku  \
# 3068                                                 NaN
# 70597                                                NaN
# 17567  AWS;DigitalOcean;Google Cloud;Managed Hosting;...
# 19244                              DigitalOcean;Firebase
# 24640  DigitalOcean;Google Cloud;Microsoft Azure;Open...
# 31190  AWS;Colocation;DigitalOcean;Firebase;Google Cl...
# 71603                                                NaN
# 34411                                                NaN
# 49874  AWS;Colocation;Microsoft Azure;Oracle Cloud In...
#
#                                   WebframeHaveWorkedWith
# 35786                                            Angular  \
# 3068                                               Flask
# 70597                                             jQuery
# 17567           Angular.js;jQuery;Laravel;Node.js;Vue.js
# 19244  Angular;Django;Drupal;Gatsby;jQuery;Laravel;No...
# 24640                                    ASP.NET;Express
# 31190  Angular;Angular.js;ASP.NET;ASP.NET Core ;Blazo...
# 71603                                                NaN
# 34411  Angular;Angular.js;ASP.NET;ASP.NET Core ;jQuer...
# 49874  Angular;ASP.NET;ASP.NET Core ;Ruby on Rails;Sv...
#
#                                   WebframeWantToWorkWith
# 35786                                      Blazor;Svelte  \
# 3068                                               Flask
# 70597                                                NaN
# 17567  Angular;Angular.js;jQuery;Laravel;Node.js;Reac...
# 19244                                     Angular;Vue.js
# 24640                                                NaN
# 31190  Angular;Angular.js;ASP.NET;ASP.NET Core ;Blazo...
# 71603                                                NaN
# 34411               Angular;ASP.NET Core ;Node.js;Vue.js
# 49874  Angular;ASP.NET Core ;Ruby on Rails;Svelte;Sym...
#
#                                   MiscTechHaveWorkedWith
# 35786                                       Scikit-learn  \
# 3068                           Apache Kafka;Apache Spark
# 70597                                                NaN
# 17567                                                NaN
# 19244  Apache Kafka;Apache Spark;React Native;Torch/P...
# 24640                                       .NET;Flutter
# 31190  .NET;Apache Kafka;Apache Spark;Capacitor;Cordo...
# 71603                                                NaN
# 34411            .NET;Cordova;Ionic;React Native;Xamarin
# 49874  .NET;Capacitor;Electron;Flutter;GTK;Hadoop;Ion...
#
#                                   MiscTechWantToWorkWith
# 35786                                          Tidyverse  \
# 3068                           Apache Kafka;Apache Spark
# 70597                                                NaN
# 17567                                                NaN
# 19244                                                NaN
# 24640                                                NaN
# 31190  .NET;Apache Kafka;Apache Spark;Capacitor;Cordo...
# 71603                                                NaN
# 34411                       .NET;Capacitor;Flutter;Ionic
# 49874  .NET;Capacitor;Electron;Flutter;GTK;Hadoop;Ion...
#
#                                  ToolsTechHaveWorkedWith
# 35786                                             Puppet  \
# 3068                                   Docker;Kubernetes
# 70597                                                NaN
# 17567                                Docker;Homebrew;npm
# 19244                                             Docker
# 24640                                     Flow;Terraform
# 31190  Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;n...
# 71603                                                NaN
# 34411                                           npm;Yarn
# 49874                         Ansible;Unreal Engine;Yarn
#
#                                  ToolsTechWantToWorkWith
# 35786                                               Yarn  \
# 3068                                   Docker;Kubernetes
# 70597                                                NaN
# 17567                                Docker;Homebrew;npm
# 19244  Ansible;Docker;Flow;Kubernetes;npm;Puppet;Unit...
# 24640                                                NaN
# 31190  Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;n...
# 71603                                                NaN
# 34411                         Docker;Kubernetes;npm;Yarn
# 49874                         Ansible;Unreal Engine;Yarn
#
#                             NEWCollabToolsHaveWorkedWith
# 35786                                     Android Studio  \
# 3068                                IntelliJ;PyCharm;Vim
# 70597                                               Nano
# 17567                                  Nano;PhpStorm;Vim
# 19244  Android Studio;Atom;IntelliJ;NetBeans;Neovim;N...
# 24640              Eclipse;NetBeans;Notepad++;Qt Creator
# 31190  Atom;CLion;Eclipse;Emacs;GoLand;IntelliJ;IPyth...
# 71603                                                NaN
# 34411                   Visual Studio;Visual Studio Code
# 49874                           Android Studio;Vim;Xcode
#
#                             NEWCollabToolsWantToWorkWith
# 35786                                     Android Studio  \
# 3068                                IntelliJ;PyCharm;Vim
# 70597                                                NaN
# 17567                                  Nano;PhpStorm;Vim
# 19244                    Atom;Notepad++;PhpStorm;PyCharm
# 24640                                                NaN
# 31190  Atom;CLion;Eclipse;Emacs;GoLand;IntelliJ;IPyth...
# 71603                                                NaN
# 34411                   Visual Studio;Visual Studio Code
# 49874                           Android Studio;Vim;Xcode
#
#                                    OpSysProfessional use
# 35786                                            Windows  \
# 3068                                         Linux-based
# 70597                                    BSD;Linux-based
# 17567                                              macOS
# 19244                                        Linux-based
# 24640                                                NaN
# 31190  BSD;Linux-based;macOS;Windows;Windows Subsyste...
# 71603                            Other (please specify):
# 34411                                            Windows
# 49874              BSD;Windows Subsystem for Linux (WSL)
#
#                                        OpSysPersonal use
# 35786                                                BSD  \
# 3068                                 Linux-based;Windows
# 70597                                        Linux-based
# 17567                                Linux-based;Windows
# 19244  BSD;Linux-based;Windows;Windows Subsystem for ...
# 24640                                            Windows
# 31190  BSD;Linux-based;macOS;Windows;Windows Subsyste...
# 71603                                                NaN
# 34411                                            Windows
# 49874              BSD;Windows Subsystem for Linux (WSL)
#
#                     VersionControlSystem
# 35786  Other (please specify):;Mercurial  \
# 3068                                 Git
# 70597                            Git;SVN
# 17567                                Git
# 19244                                Git
# 24640                    I don't use one
# 31190                    I don't use one
# 71603                                NaN
# 34411                                Git
# 49874                  Git;Mercurial;SVN
#
#                                            VCInteraction
# 35786                                       Command-line  \
# 3068   Command-line;Version control hosting service w...
# 70597                                       Command-line
# 17567                           Code editor;Command-line
# 19244  Code editor;Command-line;Version control hosti...
# 24640                                                NaN
# 31190                                                NaN
# 71603                                       Command-line
# 34411                           Code editor;Command-line
# 49874  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use
# 35786                    NaN                        NaN  \
# 3068                     NaN                        NaN
# 70597                    NaN                        NaN
# 17567                    NaN                        NaN
# 19244                    NaN                        NaN
# 24640                    NaN                        NaN
# 31190                    NaN                        NaN
# 71603                    NaN                        NaN
# 34411                    NaN                        NaN
# 49874                    NaN                        NaN
#
#                           OfficeStackAsyncHaveWorkedWith
# 35786                                           Airtable  \
# 3068                                          Confluence
# 70597                                                NaN
# 17567                                             Trello
# 19244                           Microsoft Planner;Trello
# 24640  Adobe Workfront;Microsoft Planner;Microsoft Lists
# 31190  Adobe Workfront;Airtable;Asana;Cerri;ClickUp;C...
# 71603                                                NaN
# 34411                               Jira Work Management
# 49874  Airtable;Asana;Cerri;ClickUp;Confluence;DingTa...
#
#                           OfficeStackAsyncWantToWorkWith
# 35786                  Planview Projectplace or Clarizen  \
# 3068                                          Confluence
# 70597                                                NaN
# 17567                                                NaN
# 19244                                                NaN
# 24640                           Stack Overflow for Teams
# 31190  Adobe Workfront;Airtable;Asana;Cerri;ClickUp;C...
# 71603                                                NaN
# 34411                               Jira Work Management
# 49874  Airtable;Asana;Cerri;ClickUp;Confluence;DingTa...
#
#                            OfficeStackSyncHaveWorkedWith
# 35786                                        Google Chat  \
# 3068                          Microsoft Teams;Rocketchat
# 70597                                                NaN
# 17567             Google Chat;Microsoft Teams;Slack;Zoom
# 19244         Google Chat;Rocketchat;Slack;Symphony;Zoom
# 24640                                                NaN
# 31190  Cisco Webex Teams;Coolfire Core;Google Chat;Ma...
# 71603                                    Microsoft Teams
# 34411                                    Microsoft Teams
# 49874                             Cisco Webex Teams;Zoom
#
#                            OfficeStackSyncWantToWorkWith      Blockchain
# 35786                                        RingCentral     Indifferent  \
# 3068                                          Rocketchat          Unsure
# 70597                                                NaN     Unfavorable
# 17567             Google Chat;Microsoft Teams;Slack;Zoom     Indifferent
# 19244                                                NaN       Favorable
# 24640                                                NaN     Unfavorable
# 31190  Cisco Webex Teams;Coolfire Core;Google Chat;Ma...  Very favorable
# 71603                  Google Chat;Microsoft Teams;Wickr          Unsure
# 34411                               Microsoft Teams;Zoom       Favorable
# 49874                             Cisco Webex Teams;Zoom     Indifferent
#
#                                               NEWSOSites
# 35786  Stack Overflow for Teams (private knowledge sh...  \
# 3068                       Stack Overflow;Stack Exchange
# 70597                      Stack Overflow;Stack Exchange
# 17567  Collectives on Stack Overflow;Stack Overflow;S...
# 19244                      Stack Overflow;Stack Exchange
# 24640  Stack Overflow for Teams (private knowledge sh...
# 31190  Collectives on Stack Overflow;Stack Overflow f...
# 71603                                     Stack Exchange
# 34411                      Stack Overflow;Stack Exchange
# 49874  I have never visited Stack Overflow or the Sta...
#
#                                SOVisitFreq SOAccount
# 35786                 A few times per week        No  \
# 3068                 Daily or almost daily       Yes
# 70597                 A few times per week       Yes
# 17567               Multiple times per day       Yes
# 19244                Daily or almost daily       Yes
# 24640                 A few times per week        No
# 31190                Daily or almost daily       Yes
# 71603  Less than once per month or monthly        No
# 34411               Multiple times per day       Yes
# 49874                                  NaN       Yes
#
#                                 SOPartFreq           SOComm
# 35786                                  NaN   No, not really  \
# 3068   Less than once per month or monthly   No, not at all
# 70597  Less than once per month or monthly   No, not really
# 17567                 A few times per week    Yes, somewhat
# 19244                Daily or almost daily  Yes, definitely
# 24640                                  NaN          Neutral
# 31190                Daily or almost daily              NaN
# 71603                                  NaN          Neutral
# 34411  Less than once per month or monthly  Yes, definitely
# 49874      A few times per month or weekly    Yes, somewhat
#
#                      Age                                             Gender
# 35786  65 years or older  Man;Woman;Non-binary, genderqueer, or gender n...  \
# 3068     18-24 years old                                                Man
# 70597                NaN                                                NaN
# 17567    25-34 years old                                                Man
# 19244    35-44 years old                         Man;Or, in your own words:
# 24640    18-24 years old                                                Man
# 31190    25-34 years old                             Or, in your own words:
# 71603    35-44 years old                                  Prefer not to say
# 34411    35-44 years old                                                Man
# 49874    45-54 years old  Man;Woman;Non-binary, genderqueer, or gender n...
#
#                         Trans
# 35786                      No  \
# 3068   Or, in your own words:
# 70597                     NaN
# 17567                      No
# 19244  Or, in your own words:
# 24640                      No
# 31190                      No
# 71603                      No
# 34411                      No
# 49874                     Yes
#
#                                                Sexuality
# 35786                            Straight / Heterosexual  \
# 3068                            Prefer to self-describe:
# 70597                                                NaN
# 17567                            Straight / Heterosexual
# 19244   Straight / Heterosexual;Prefer to self-describe:
# 24640                      Straight / Heterosexual;Queer
# 31190                            Straight / Heterosexual
# 71603                                                NaN
# 34411                            Straight / Heterosexual
# 49874  Bisexual;Straight / Heterosexual;Gay or Lesbia...
#
#                                                Ethnicity
# 35786  White;Indian;European;North American;Middle Ea...  \
# 3068                              Or, in your own words:
# 70597                                                NaN
# 17567                                           European
# 19244              White;Asian;Multiracial;Central Asian
# 24640                             African;South American
# 31190  White;Indian;European;North American;Middle Ea...
# 71603                                              Asian
# 34411                                     Middle Eastern
# 49874  White;Indian;European;North American;Middle Ea...
#
#                                            Accessibility
# 35786  I am deaf / hard of hearing;I am blind / have ...  \
# 3068                              Or, in your own words:
# 70597                                                NaN
# 17567                                  None of the above
# 19244  Or, in your own words:;I am deaf / hard of hea...
# 24640                                  None of the above
# 31190                                  Prefer not to say
# 71603                                  None of the above
# 34411                                  None of the above
# 49874  I am deaf / hard of hearing;I am blind / have ...
#
#                                             MentalHealth TBranch
# 35786  I have a mood or emotional disorder (e.g., dep...     Yes  \
# 3068                              Or, in your own words:      No
# 70597                                                NaN     NaN
# 17567                                  None of the above     Yes
# 19244                             Or, in your own words:      No
# 24640                                  None of the above     Yes
# 31190  I have a concentration and/or memory disorder ...     Yes
# 71603                                                NaN     NaN
# 34411                                  None of the above     Yes
# 49874  I have a mood or emotional disorder (e.g., dep...     Yes
#
#                         ICorPM  WorkExp        Knowledge_1
# 35786           People manager     50.0           Disagree  \
# 3068                       NaN      NaN                NaN
# 70597                      NaN      NaN                NaN
# 17567  Independent contributor      8.0     Strongly agree
# 19244                      NaN      NaN                NaN
# 24640  Independent contributor      9.0           Disagree
# 31190           People manager     15.0     Strongly agree
# 71603                      NaN      NaN                NaN
# 34411           People manager     16.0              Agree
# 49874  Independent contributor     45.0  Strongly disagree
#
#                       Knowledge_2        Knowledge_3     Knowledge_4
# 35786  Neither agree nor disagree              Agree  Strongly agree  \
# 3068                          NaN                NaN             NaN
# 70597                         NaN                NaN             NaN
# 17567  Neither agree nor disagree     Strongly agree  Strongly agree
# 19244                         NaN                NaN             NaN
# 24640                       Agree              Agree           Agree
# 31190           Strongly disagree     Strongly agree  Strongly agree
# 71603                         NaN                NaN             NaN
# 34411  Neither agree nor disagree              Agree           Agree
# 49874           Strongly disagree  Strongly disagree        Disagree
#
#           Knowledge_5                 Knowledge_6                 Knowledge_7
# 35786           Agree  Neither agree nor disagree                    Disagree  \
# 3068              NaN                         NaN                         NaN
# 70597             NaN                         NaN                         NaN
# 17567  Strongly agree  Neither agree nor disagree                       Agree
# 19244             NaN                         NaN                         NaN
# 24640           Agree                       Agree                       Agree
# 31190  Strongly agree              Strongly agree              Strongly agree
# 71603             NaN                         NaN                         NaN
# 34411             NaN                       Agree  Neither agree nor disagree
# 49874           Agree  Neither agree nor disagree                       Agree
#
#             Frequency_1       Frequency_2        Frequency_3
# 35786  10+ times a week  10+ times a week   10+ times a week  \
# 3068                NaN               NaN                NaN
# 70597               NaN               NaN                NaN
# 17567             Never             Never              Never
# 19244               NaN               NaN                NaN
# 24640  1-2 times a week               NaN                NaN
# 31190             Never  1-2 times a week   1-2 times a week
# 71603               NaN               NaN                NaN
# 34411  1-2 times a week  1-2 times a week              Never
# 49874             Never  1-2 times a week  6-10 times a week
#
#                 TimeSearching               TimeAnswering      Onboarding
# 35786  Over 120 minutes a day      Over 120 minutes a day      Just right  \
# 3068                      NaN                         NaN             NaN
# 70597                     NaN                         NaN             NaN
# 17567     15-30 minutes a day  Less than 15 minutes a day  Somewhat short
# 19244                     NaN                         NaN             NaN
# 24640  Over 120 minutes a day  Less than 15 minutes a day  Somewhat short
# 31190    60-120 minutes a day        60-120 minutes a day      Very short
# 71603                     NaN                         NaN             NaN
# 34411     30-60 minutes a day         15-30 minutes a day   Somewhat long
# 49874     30-60 minutes a day         30-60 minutes a day  Somewhat short
#
#                                         ProfessionalTech TrueFalse_1
# 35786                  DevOps function;Automated testing         Yes  \
# 3068                                                 NaN         NaN
# 70597                                                NaN         NaN
# 17567  DevOps function;Microservices;Continuous integ...         Yes
# 19244                                                NaN         NaN
# 24640                                    DevOps function         Yes
# 31190  Innersource initiative;DevOps function;Microse...         Yes
# 71603                                                NaN         NaN
# 34411  DevOps function;Microservices;Continuous integ...         Yes
# 49874  Innersource initiative;DevOps function;Microse...         Yes
#
#       TrueFalse_2 TrueFalse_3           SurveyLength
# 35786          No         Yes               Too long  \
# 3068          NaN         NaN  Appropriate in length
# 70597         NaN         NaN                    NaN
# 17567         Yes         Yes               Too long
# 19244         NaN         NaN  Appropriate in length
# 24640         Yes         Yes  Appropriate in length
# 31190         Yes         Yes  Appropriate in length
# 71603         NaN         NaN               Too long
# 34411         Yes         Yes  Appropriate in length
# 49874         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 35786                   Difficult                  NaN
# 3068                    Difficult                  NaN
# 70597                         NaN                  NaN
# 17567  Neither easy nor difficult                  NaN
# 19244  Neither easy nor difficult                  NaN
# 24640  Neither easy nor difficult                  NaN
# 31190  Neither easy nor difficult                  NaN
# 71603  Neither easy nor difficult                  NaN
# 34411                        Easy            2042400.0
# 49874                   Difficult                  NaN

# %%
dfs.nsmallest(10, 'CompTotal')
# Out:
#        ResponseId                                         MainBranch
# 2737         2738                     I am a developer by profession  \
# 67666       67667                     I am a developer by profession
# 22777       22778                     I am a developer by profession
# 58996       58997                     I am a developer by profession
# 27810       27811                     I am a developer by profession
# 57028       57029  I am not primarily a developer, but I write co...
# 64663       64664                     I am a developer by profession
# 30854       30855                     I am a developer by profession
# 15640       15641  I am not primarily a developer, but I write co...
# 51758       51759                     I am a developer by profession
#
#                                               Employment
# 2737                                 Employed, full-time  \
# 67666                                Employed, full-time
# 22777                                Employed, full-time
# 58996  Independent contractor, freelancer, or self-em...
# 27810                                I prefer not to say
# 57028                                            Retired
# 64663  Independent contractor, freelancer, or self-em...
# 30854  Independent contractor, freelancer, or self-em...
# 15640  Independent contractor, freelancer, or self-em...
# 51758  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork
# 2737                           Fully remote  \
# 67666                          Fully remote
# 22777                          Fully remote
# 58996                          Fully remote
# 27810                                   NaN
# 57028                                   NaN
# 64663                          Fully remote
# 30854  Hybrid (some remote, some in-person)
# 15640                          Fully remote
# 51758                          Fully remote
#
#                                         CodingActivities
# 2737   Hobby;Contribute to open-source projects;Freel...  \
# 67666                                                NaN
# 22777  Hobby;Contribute to open-source projects;Freel...
# 58996   Bootstrapping a business;Freelance/contract work
# 27810                                                NaN
# 57028                                                NaN
# 64663                     Hobby;Bootstrapping a business
# 30854                                              Hobby
# 15640  Hobby;Contribute to open-source projects;Boots...
# 51758                            Freelance/contract work
#
#                                                  EdLevel
# 2737     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  \
# 67666                                     Something else
# 22777    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 58996  Some college/university study without earning ...
# 27810  Some college/university study without earning ...
# 57028         Other doctoral degree (Ph.D., Ed.D., etc.)
# 64663       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 30854    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 15640       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51758       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode
# 2737   Books / Physical media;School (i.e., Universit...  \
# 67666  Books / Physical media;Other online resources ...
# 22777  Other online resources (e.g., videos, blogs, f...
# 58996  Books / Physical media;Other online resources ...
# 27810  Books / Physical media;School (i.e., Universit...
# 57028                   Books / Physical media;Colleague
# 64663  Books / Physical media;Other online resources ...
# 30854  School (i.e., University, College, etc);Other ...
# 15640  Other online resources (e.g., videos, blogs, f...
# 51758  Other online resources (e.g., videos, blogs, f...
#
#                                          LearnCodeOnline LearnCodeCoursesCert
# 2737                                                 NaN                  NaN  \
# 67666  Technical documentation;Blogs;Written Tutorial...        Udemy;Udacity
# 22777  Technical documentation;Stack Overflow;Online ...    Udemy;Pluralsight
# 58996             Technical documentation;Stack Overflow                  NaN
# 27810                                                NaN                Other
# 57028                                                NaN                  NaN
# 64663  Technical documentation;Blogs;Written Tutorial...                  NaN
# 30854                                                NaN                  NaN
# 15640  Technical documentation;Blogs;Written Tutorial...                  NaN
# 51758  Technical documentation;Blogs;Stack Overflow;V...   Coursera;Udemy;edX
#
#                 YearsCode YearsCodePro
# 2737                   17           13  \
# 67666                  15          NaN
# 22777                  18           12
# 58996                  22           22
# 27810                  41           41
# 57028  More than 50 years           48
# 64663                  30           15
# 30854                  12            2
# 15640                   5            1
# 51758                   5            4
#
#                                                  DevType
# 2737   Engineer, site reliability;Developer, back-end...  \
# 67666                                                NaN
# 22777                              Developer, full-stack
# 58996  Developer, front-end;Developer, full-stack;Dev...
# 27810                                                NaN
# 57028                                                NaN
# 64663                        Developer, game or graphics
# 30854  Developer, front-end;Developer, QA or test;Dev...
# 15640  Developer, full-stack;Developer, back-end;Proj...
# 51758          Developer, full-stack;Developer, back-end
#
#                                                  OrgSize
# 2737                                100 to 499 employees  \
# 67666                                                NaN
# 22777                           5,000 to 9,999 employees
# 58996                                   2 to 9 employees
# 27810  Just me - I am a freelancer, sole proprietor, ...
# 57028  Just me - I am a freelancer, sole proprietor, ...
# 64663  Just me - I am a freelancer, sole proprietor, ...
# 30854                                   2 to 9 employees
# 15640                                   2 to 9 employees
# 51758  Just me - I am a freelancer, sole proprietor, ...
#
#                       PurchaseInfluence
# 2737              I have some influence  \
# 67666     I have little or no influence
# 22777     I have little or no influence
# 58996  I have a great deal of influence
# 27810  I have a great deal of influence
# 57028  I have a great deal of influence
# 64663  I have a great deal of influence
# 30854  I have a great deal of influence
# 15640  I have a great deal of influence
# 51758  I have a great deal of influence
#
#                                               BuyNewTool      Country
# 2737   Start a free trial;Ask developers I know/work ...  Afghanistan  \
# 67666                                 Start a free trial  Afghanistan
# 22777    Visit developer communities like Stack Overflow    Argentina
# 58996  Start a free trial;Ask developers I know/work ...    Australia
# 27810  Start a free trial;Visit developer communities...    Australia
# 57028  Start a free trial;Ask developers I know/work ...    Australia
# 64663  Start a free trial;Visit developer communities...    Australia
# 30854  Start a free trial;Visit developer communities...      Belgium
# 15640  Start a free trial;Visit developer communities...       Brazil
# 51758  Start a free trial;Visit developer communities...       Brazil
#
#                               Currency  CompTotal CompFreq
# 2737               AFN\tAfghan afghani        0.0  Monthly  \
# 67666  AED United Arab Emirates dirham        0.0      NaN
# 22777              ARS\tArgentine peso        0.0  Monthly
# 58996        USD\tUnited States dollar        0.0   Yearly
# 27810           AUD\tAustralian dollar        0.0   Yearly
# 57028           AUD\tAustralian dollar        0.0   Yearly
# 64663           AUD\tAustralian dollar        0.0   Yearly
# 30854                EUR European Euro        0.0      NaN
# 15640              BRL\tBrazilian real        0.0  Monthly
# 51758              BRL\tBrazilian real        0.0   Yearly
#
#                                   LanguageHaveWorkedWith
# 2737   Assembly;Bash/Shell;C;C#;C++;Java;JavaScript;K...  \
# 67666                   HTML/CSS;Java;JavaScript;PHP;SQL
# 22777                                    Java;JavaScript
# 58996   C++;JavaScript;Kotlin;Perl;PHP;SAS;SQL;Swift;VBA
# 27810                                      Delphi;Python
# 57028                                             Delphi
# 64663                                        C#;HTML/CSS
# 30854                         HTML/CSS;JavaScript;Python
# 15640                   JavaScript;Python;SQL;TypeScript
# 51758                              HTML/CSS;JavaScript;R
#
#                                   LanguageWantToWorkWith
# 2737   Assembly;Bash/Shell;C;C#;C++;Java;JavaScript;K...  \
# 67666                   HTML/CSS;Java;JavaScript;PHP;SQL
# 22777                                    Java;JavaScript
# 58996                                                NaN
# 27810                                                NaN
# 57028                                             Delphi
# 64663                                    C#;C++;HTML/CSS
# 30854                   C;C++;HTML/CSS;JavaScript;Python
# 15640           Go;JavaScript;Python;Rust;SQL;TypeScript
# 51758                                       JavaScript;R
#
#                                   DatabaseHaveWorkedWith
# 2737               Elasticsearch;PostgreSQL;Redis;SQLite  \
# 67666                                      MariaDB;MySQL
# 22777  Couchbase;CouchDB;Microsoft SQL Server;MySQL;O...
# 58996                 MariaDB;Microsoft SQL Server;MySQL
# 27810                                       MySQL;SQLite
# 57028                                                NaN
# 64663                                                NaN
# 30854                                         PostgreSQL
# 15640             Elasticsearch;MongoDB;PostgreSQL;Redis
# 51758                           MongoDB;PostgreSQL;Redis
#
#                       DatabaseWantToWorkWith
# 2737   Elasticsearch;PostgreSQL;Redis;SQLite  \
# 67666                          MariaDB;MySQL
# 22777                 MySQL;PostgreSQL;Redis
# 58996                                    NaN
# 27810                                    NaN
# 57028                                    NaN
# 64663                                    NaN
# 30854            DynamoDB;MongoDB;PostgreSQL
# 15640     Couchbase;CouchDB;PostgreSQL;Redis
# 51758               MongoDB;PostgreSQL;Redis
#
#                   PlatformHaveWorkedWith   PlatformWantToWorkWith
# 2737   AWS;DigitalOcean;Google Cloud;OVH             Google Cloud  \
# 67666                                NaN                      NaN
# 22777            AWS;Google Cloud;Heroku  AWS;Google Cloud;Heroku
# 58996      Linode;Managed Hosting;VMware                      NaN
# 27810                                NaN                      NaN
# 57028                                NaN                      NaN
# 64663                    Microsoft Azure          Microsoft Azure
# 30854                                AWS                      AWS
# 15640      AWS;DigitalOcean;Google Cloud   DigitalOcean;OpenStack
# 51758                                AWS                      AWS
#
#                  WebframeHaveWorkedWith
# 2737      Angular;FastAPI;Flask;Node.js  \
# 67666                    jQuery;Symfony
# 22777               Angular.js;React.js
# 58996                            Drupal
# 27810                            jQuery
# 57028                               NaN
# 64663                            Blazor
# 30854                   Django;React.js
# 15640            FastAPI;Flask;React.js
# 51758  Express;Next.js;Node.js;React.js
#
#                       WebframeWantToWorkWith
# 2737   Angular;FastAPI;Flask;Next.js;Node.js  \
# 67666                                Symfony
# 22777                               React.js
# 58996                                    NaN
# 27810                                    NaN
# 57028                                    NaN
# 64663                                 Blazor
# 30854                        Django;React.js
# 15640               FastAPI;Node.js;React.js
# 51758                   Deno;Next.js;Node.js
#
#                   MiscTechHaveWorkedWith             MiscTechWantToWorkWith
# 2737   Apache Kafka;Qt;Spring;TensorFlow  Apache Kafka;Qt;Spring;TensorFlow  \
# 67666                                NaN                                NaN
# 22777           .NET;React Native;Spring                React Native;Spring
# 58996                                NaN                                NaN
# 27810                               .NET                                NaN
# 57028                                NaN                                NaN
# 64663                               .NET                               .NET
# 30854                                NaN                                NaN
# 15640                             Pandas       Apache Kafka;Electron;Pandas
# 51758                          Tidyverse               Tidyverse;TensorFlow
#
#                                  ToolsTechHaveWorkedWith
# 2737        Docker;Homebrew;Kubernetes;npm;Unreal Engine  \
# 67666                                         Docker;npm
# 22777                    Docker;Homebrew;Kubernetes;Yarn
# 58996                                                NaN
# 27810                                                NaN
# 57028                                                NaN
# 64663                                      Unreal Engine
# 30854                                        Docker;Yarn
# 15640  Ansible;Docker;Homebrew;Kubernetes;Terraform;Yarn
# 51758                                         Docker;npm
#
#                                  ToolsTechWantToWorkWith
# 2737        Docker;Homebrew;Kubernetes;npm;Unreal Engine  \
# 67666                                         Docker;npm
# 22777                    Docker;Homebrew;Kubernetes;Yarn
# 58996                                                NaN
# 27810                                                NaN
# 57028                                                NaN
# 64663                                      Unreal Engine
# 30854                                        Docker;Yarn
# 15640  Ansible;Docker;Homebrew;Kubernetes;Terraform;Yarn
# 51758                              Docker;Kubernetes;npm
#
#                             NEWCollabToolsHaveWorkedWith
# 2737   Android Studio;Atom;CLion;IntelliJ;Vim;Visual ...  \
# 67666  IntelliJ;NetBeans;Notepad++;PhpStorm;Visual St...
# 22777  Eclipse;IntelliJ;NetBeans;Notepad++;Sublime Te...
# 58996     Android Studio;Eclipse;Notepad++;Visual Studio
# 27810                                                NaN
# 57028                   RAD Studio (Delphi, C++ Builder)
# 64663                                      Visual Studio
# 30854               Notepad++;PyCharm;Visual Studio Code
# 15640  IntelliJ;IPython/Jupyter;PyCharm;Sublime Text;...
# 51758                                 Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith
# 2737   Android Studio;Atom;CLion;IntelliJ;Qt Creator;...  \
# 67666                        IntelliJ;Notepad++;PhpStorm
# 22777     IntelliJ;Sublime Text;Visual Studio Code;Xcode
# 58996                                                NaN
# 27810                                                NaN
# 57028                   RAD Studio (Delphi, C++ Builder)
# 64663                                      Visual Studio
# 30854         CLion;Notepad++;PyCharm;Visual Studio Code
# 15640                 IPython/Jupyter;Visual Studio Code
# 51758                         RStudio;Visual Studio Code
#
#                            OpSysProfessional use
# 2737                   Linux-based;macOS;Windows  \
# 67666                        Linux-based;Windows
# 22777                  Linux-based;macOS;Windows
# 58996                                        NaN
# 27810                                        NaN
# 57028                                    Windows
# 64663                                    Windows
# 30854  Windows;Windows Subsystem for Linux (WSL)
# 15640                                      macOS
# 51758          Windows Subsystem for Linux (WSL)
#
#                                        OpSysPersonal use VersionControlSystem
# 2737                                               macOS                  Git  \
# 67666                                Linux-based;Windows                  Git
# 22777                          Linux-based;macOS;Windows                  Git
# 58996                          Linux-based;macOS;Windows      I don't use one
# 27810  Linux-based;macOS;Windows;Other (please specify):      I don't use one
# 57028                                            Windows      I don't use one
# 64663                                            Windows      I don't use one
# 30854          Windows;Windows Subsystem for Linux (WSL)                  Git
# 15640                                              macOS                  Git
# 51758                                            Windows                  Git
#
#                                            VCInteraction
# 2737                            Code editor;Command-line  \
# 67666                           Code editor;Command-line
# 22777                                       Command-line
# 58996                                                NaN
# 27810                                                NaN
# 57028                                                NaN
# 64663                                                NaN
# 30854  Version control hosting service web GUI;Dedica...
# 15640                           Code editor;Command-line
# 51758                                       Command-line
#
#        VCHostingPersonal use  VCHostingProfessional use
# 2737                     NaN                        NaN  \
# 67666                    NaN                        NaN
# 22777                    NaN                        NaN
# 58996                    NaN                        NaN
# 27810                    NaN                        NaN
# 57028                    NaN                        NaN
# 64663                    NaN                        NaN
# 30854                    NaN                        NaN
# 15640                    NaN                        NaN
# 51758                    NaN                        NaN
#
#                           OfficeStackAsyncHaveWorkedWith
# 2737                  Jira Work Management;Notion;Trello  \
# 67666                                                NaN
# 22777                      Airtable;Jira Work Management
# 58996                                                NaN
# 27810                                                NaN
# 57028                                                NaN
# 64663                                                NaN
# 30854                                             Trello
# 15640  Asana;ClickUp;Jira Work Management;monday.com;...
# 51758                                                NaN
#
#       OfficeStackAsyncWantToWorkWith
# 2737     Jira Work Management;Notion  \
# 67666                            NaN
# 22777  Airtable;Jira Work Management
# 58996                            NaN
# 27810                            NaN
# 57028                            NaN
# 64663                            NaN
# 30854                         Trello
# 15640    Jira Work Management;Notion
# 51758                            NaN
#
#                            OfficeStackSyncHaveWorkedWith
# 2737        Cisco Webex Teams;Microsoft Teams;Slack;Zoom  \
# 67666                                              Slack
# 22777  Cisco Webex Teams;Google Chat;Microsoft Teams;...
# 58996                                               Zoom
# 27810                                                NaN
# 57028                                                NaN
# 64663                                                NaN
# 30854                                              Slack
# 15640  Cisco Webex Teams;Google Chat;Microsoft Teams;...
# 51758                                                NaN
#
#                            OfficeStackSyncWantToWorkWith        Blockchain
# 2737                                          Slack;Zoom         Favorable  \
# 67666                                                NaN       Unfavorable
# 22777  Cisco Webex Teams;Google Chat;Microsoft Teams;...       Indifferent
# 58996                                                NaN  Very unfavorable
# 27810                                                NaN  Very unfavorable
# 57028                                                NaN       Unfavorable
# 64663                                                NaN       Unfavorable
# 30854                                              Slack         Favorable
# 15640                                   Rocketchat;Slack    Very favorable
# 51758                                                NaN         Favorable
#
#                                               NEWSOSites
# 2737                       Stack Overflow;Stack Exchange  \
# 67666                      Stack Overflow;Stack Exchange
# 22777       Collectives on Stack Overflow;Stack Overflow
# 58996                      Stack Overflow;Stack Exchange
# 27810                                     Stack Overflow
# 57028  I have never visited Stack Overflow or the Sta...
# 64663                                     Stack Overflow
# 30854                                     Stack Overflow
# 15640                      Stack Overflow;Stack Exchange
# 51758                      Stack Overflow;Stack Exchange
#
#                                SOVisitFreq SOAccount
# 2737                  A few times per week       Yes  \
# 67666                 A few times per week       Yes
# 22777                 A few times per week       Yes
# 58996      A few times per month or weekly       Yes
# 27810      A few times per month or weekly       Yes
# 57028                                  NaN        No
# 64663  Less than once per month or monthly       Yes
# 30854                 A few times per week       Yes
# 15640                Daily or almost daily       Yes
# 51758                Daily or almost daily       Yes
#
#                                               SOPartFreq          SOComm
# 2737                 Less than once per month or monthly         Neutral  \
# 67666                Less than once per month or monthly        Not sure
# 22777                Less than once per month or monthly   Yes, somewhat
# 58996                Less than once per month or monthly  No, not at all
# 27810                Less than once per month or monthly         Neutral
# 57028                                                NaN  No, not really
# 64663                Less than once per month or monthly  No, not at all
# 30854  I have never participated in Q&A on Stack Over...  No, not really
# 15640                    A few times per month or weekly   Yes, somewhat
# 51758                               A few times per week   Yes, somewhat
#
#                      Age                  Gender                   Trans
# 2737     25-34 years old                     Man                     NaN  \
# 67666  Prefer not to say  Or, in your own words:  Or, in your own words:
# 22777    35-44 years old                     Man                      No
# 58996  65 years or older                     Man                      No
# 27810  65 years or older                     Man                      No
# 57028  65 years or older                     Man                      No
# 64663    35-44 years old                     Man                      No
# 30854    25-34 years old                     Man                      No
# 15640    35-44 years old                     Man                      No
# 51758    25-34 years old                     Man                      No
#
#                       Sexuality             Ethnicity
# 2737                        NaN                   NaN  \
# 67666  Prefer to self-describe:        White;European
# 22777   Straight / Heterosexual  Hispanic or Latino/a
# 58996   Straight / Heterosexual                 White
# 27810   Straight / Heterosexual        White;European
# 57028   Straight / Heterosexual              European
# 64663   Straight / Heterosexual        White;European
# 30854   Straight / Heterosexual        White;European
# 15640   Straight / Heterosexual                 White
# 51758   Straight / Heterosexual           Multiracial
#
#                                            Accessibility
# 2737                                                 NaN  \
# 67666                                  Prefer not to say
# 22777                                  None of the above
# 58996                                  None of the above
# 27810  I am unable to / find it difficult to walk or ...
# 57028                                  None of the above
# 64663                                  None of the above
# 30854                                  None of the above
# 15640                                  None of the above
# 51758                                  None of the above
#
#                  MentalHealth TBranch                   ICorPM  WorkExp
# 2737                      NaN      No                      NaN      NaN  \
# 67666       Prefer not to say     Yes  Independent contributor      NaN
# 22777       None of the above     Yes  Independent contributor     12.0
# 58996       None of the above     Yes           People manager     50.0
# 27810  Or, in your own words:     NaN                      NaN      NaN
# 57028       None of the above     NaN                      NaN      NaN
# 64663       None of the above     NaN                      NaN      NaN
# 30854       None of the above     Yes  Independent contributor      3.0
# 15640       None of the above      No                      NaN      NaN
# 51758       None of the above     NaN                      NaN      NaN
#
#           Knowledge_1                 Knowledge_2                 Knowledge_3
# 2737              NaN                         NaN                         NaN  \
# 67666             NaN                         NaN                         NaN
# 22777             NaN                         NaN                         NaN
# 58996           Agree  Neither agree nor disagree  Neither agree nor disagree
# 27810             NaN                         NaN                         NaN
# 57028             NaN                         NaN                         NaN
# 64663             NaN                         NaN                         NaN
# 30854  Strongly agree           Strongly disagree                       Agree
# 15640             NaN                         NaN                         NaN
# 51758             NaN                         NaN                         NaN
#
#           Knowledge_4     Knowledge_5 Knowledge_6        Knowledge_7
# 2737              NaN             NaN         NaN                NaN  \
# 67666             NaN             NaN         NaN                NaN
# 22777             NaN             NaN         NaN                NaN
# 58996           Agree           Agree       Agree              Agree
# 27810             NaN             NaN         NaN                NaN
# 57028             NaN             NaN         NaN                NaN
# 64663             NaN             NaN         NaN                NaN
# 30854  Strongly agree  Strongly agree    Disagree  Strongly disagree
# 15640             NaN             NaN         NaN                NaN
# 51758             NaN             NaN         NaN                NaN
#
#             Frequency_1       Frequency_2 Frequency_3        TimeSearching
# 2737                NaN               NaN         NaN                  NaN  \
# 67666               NaN               NaN         NaN                  NaN
# 22777               NaN               NaN         NaN                  NaN
# 58996  1-2 times a week  1-2 times a week       Never  15-30 minutes a day
# 27810               NaN               NaN         NaN                  NaN
# 57028               NaN               NaN         NaN                  NaN
# 64663               NaN               NaN         NaN                  NaN
# 30854             Never  3-5 times a week       Never  15-30 minutes a day
# 15640               NaN               NaN         NaN                  NaN
# 51758               NaN               NaN         NaN                  NaN
#
#                     TimeAnswering     Onboarding
# 2737                          NaN            NaN  \
# 67666                         NaN            NaN
# 22777                         NaN            NaN
# 58996  Less than 15 minutes a day  Somewhat long
# 27810                         NaN            NaN
# 57028                         NaN            NaN
# 64663                         NaN            NaN
# 30854  Less than 15 minutes a day  Somewhat long
# 15640                         NaN            NaN
# 51758                         NaN            NaN
#
#                                         ProfessionalTech TrueFalse_1
# 2737                                                 NaN         NaN  \
# 67666                                                NaN         NaN
# 22777  Microservices;Continuous integration (CI) and ...          No
# 58996                                      None of these         Yes
# 27810                                                NaN         NaN
# 57028                                                NaN         NaN
# 64663                                                NaN         NaN
# 30854                             Innersource initiative         Yes
# 15640                                                NaN         NaN
# 51758                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength
# 2737          NaN         NaN               Too long  \
# 67666         NaN         NaN               Too long
# 22777          No          No               Too long
# 58996         Yes         Yes  Appropriate in length
# 27810         NaN         NaN               Too long
# 57028         NaN         NaN  Appropriate in length
# 64663         NaN         NaN  Appropriate in length
# 30854         Yes         Yes  Appropriate in length
# 15640         NaN         NaN  Appropriate in length
# 51758         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 2737                         Easy                  NaN
# 67666                   Difficult                  NaN
# 22777  Neither easy nor difficult                  NaN
# 58996  Neither easy nor difficult                  NaN
# 27810                        Easy                  NaN
# 57028  Neither easy nor difficult                  NaN
# 64663  Neither easy nor difficult                  NaN
# 30854  Neither easy nor difficult                  NaN
# 15640  Neither easy nor difficult                  NaN
# 51758                        Easy                  NaN
